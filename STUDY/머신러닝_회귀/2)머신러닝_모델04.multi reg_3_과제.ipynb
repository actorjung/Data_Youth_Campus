# %% [markdown]
# ### 다중선형회귀분석

# %% [markdown]
# - #### CRIM, RM, LSTAT, B, TAX, AGE, ZN, NOX, INDUS 변수로 데이터를 분할하여 회귀 모형 생성 후 성능확인
# - #### 다중공선성을 확인하여 변수 제거 후 모형의 성능 높이기

# %% [markdown]
# ### 3. 다중공선성과 회귀모델 성능 확인
# - #### CRIM, RM, LSTAT, B, TAX, AGE, ZN, NOX, INDUS 변수로 데이터를 분할하여 회귀 모형 생성 후 성능확인
#
# - 이때, 다중공선성을 확인하여 변수 제거 후 성능 비교
#
# - Boston 주택 가격데이터 이용

# %% [markdown]
# - #### CRIM, RM, LSTAT, B, TAX, AGE, ZN, NOX, INDUS 변수를 통한 다중선형회귀분석

# %% [markdown]
# - #### 상관계수/산점도를 통해 다중공선성 확인

# %% [markdown]
# - #### VIF를 통한 다중공선성 확인

# %% [markdown]
# - #### 학습 / 검증데이터 분할

# %% [markdown]
# - #### MSE를 통한 검증데이터에 대한 성능비교
