# %% [markdown]
# ## 코인데스크 기사 크롤링

# %% [markdown]
# ### 라이브러리 Import

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ### 크롤링 URL 주소

# %%
base_url = 'http://www.coindeskkorea.com'
uri = '/news/articleList.html?view_type=sm'
url = base_url + uri

# %%
url
# Out:
# 'http://www.coindeskkorea.com/news/articleList.html?view_type=sm'

# %% [markdown]
# ### 세션 연결

# %%
session = requests.session()
session

# %% [markdown]
# ### 응답받기

# %%
response = session.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# ### HTML을 parsing

# %%
html = response.text
html
# Out:
# '<!doctype html>\n<html class="no-js" lang="ko" dir="ltr">\n<head>\n<meta charset="utf-8">\n<meta http-equiv="x-ua-compatible" content="ie=edge">\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n<meta name="theme-color" content="#f8c400">\n<!-- 메타태그정보 //-->\n<meta name="description" content="코인데스크코리아"/>\n<meta property="og:title" content="코인데스크코리아 "/>\n<meta property="og:site_name" content="코인데스크코리아 "/>\n<meta property="og:image" content="http://www.coindeskkorea.com/image/logo/snslogo_20191211100329.jpg" />\n<meta property="og:url"\tcontent="http://www.coindeskkorea.com" />\n<meta property="og:description" content="코인데스크코리아" />\n<meta name="twitter:card" content="summary"/>\n<meta name="twitter:title" content="코인데스크코리아 "/>\n<meta name="twitter:description" content="코인데스크코리아"/>\n<meta name="twitter:image:src" content="http://www.coindeskkorea.com/image/logo/snslogo_20191211100329.jpg"/>\n<!--// 메타태그정보 -->\n<title>CoinDesk Korea 신뢰 그 이상의 가치</title>\n<link rel="apple-touch-icon-precomposed" href="/image/logo/snslogo_20191211100329.jpg" />\n<link rel="stylesheet" href="/css/jquery-ui.min.css">\n<link rel="stylesheet" href="/css/foundation.min.css">\n<link rel="stylesheet" href="/css/custom.foundation.min.css">\n<link rel="stylesheet" href="/css/slick.min.css">\n<link rel="stylesheet" href="/css/webfonts.min.css">\n<link rel="stylesheet" href="/css/aos.min.css">\n<link rel="stylesheet" href="/css/style.min.css">\n<link rel="stylesheet" href="/css/design.style.css">\n<link rel="stylesheet" href="/menuskin/md_01/menubar.css">\n<link rel="shortcut icon" href="/image/logo/favicon_20191211100547.ico">\n<script src="/script/jquery.min.js"></script>\n<script src="/script/jquery-ui.min.js"></script>\n<script src="/script/slick.min.js"></script>\n<script src="/script/jquery.rwdImageMaps.min.js"></script>\n<script src="/script/what-input.js"></script>\n<script src="/script/foundation.min.js"></script>\n<script src="/menuskin/md_01/menubar.js"></script>\n<script src="/script/user.style.js"></script>\n<script src="/script/clipboard.min.js"></script>\n<script src="/script/jquery.tabslet.min.js"></script>\n<script src="/script/aos.min.js"></script>\n<script src="/script/aos.nd.js"></script>\n<script src="/script/common.js"></script>\n\n<script type="text/javascript">\n\n\t// 이미지맵\n\t$(document).ready(function(e) {\n\t\t$(\'img[usemap]\').rwdImageMaps();\n\n\t\tbannerpop.banner(".banner_event_box");\t\t\t\t\t// 기능성배너 이벤트\n\t\tbannerpopMulti.bannerLoad();                            // 멀티 기능성 배너 이벤트\n\n\t\t// 기사뷰 이미지관련\n\t\t\t});\n\n\t// domain\n\tvar SITE_DOMAIN = \'http://www.coindeskkorea.com\'\n\t,___currentTime\t= 1593670077;\n\n</script>\n<style type="text/css">\n/* 사이트 기본 색 */\n.user-point,a.user-point,\n.poll-columns .poll-state.going,\n.auto-hr04-2 .auto-nav .slick-slide.slick-current .auto-fontA,.auto-hr05 .auto-nav .slick-slide.slick-current .auto-fontA,\n.info-social .fonts-option-panel li input[type="radio"]:checked + label\n{color:#f8c400 !important}\n.user-bg,.user-bg:hover,.user-bg:active,.user-bg:focus,li[id*="slick-"].slick-active button[data-role],.checkbox-group > input[type="radio"]:checked + label, .checkbox-group > input[type="checkbox"]:checked + label,\n.radio-group > input[type="radio"]:checked + label, .radio-group > input[type="checkbox"]:checked + label,\n.article-list .article-list-content.type-tm .list-block .links:hover,.tabs .tabs-title.is-active a,\n.poll-view .poll-view-state.going,.poll-view .poll-radio input[type="radio"]:checked + label::before,.poll-view .poll-radio input[type="checkbox"]:checked + label::before,\n.auto-dl04 .auto-column::after,.auto-mr01::before,.auto-hp02 a:hover .photo-titbg,.auto-hr04 .auto-nav .slick-slide.slick-current,.auto-hr04-1 .auto-nav .slick-slide.slick-current,\n.nd-switch.user-bg input[type="checkbox"]:checked + label,.nd-switch.user-bg input[type="radio"]:checked + label,\n.nd-switch.user-bg input[type="checkbox"]:checked + label::before,.nd-switch.user ...

# %%
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" dir="ltr" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="#f8c400" name="theme-color"/>
# <!-- 메타태그정보 //-->
# <meta content="코인데스크코리아" name="description">
# <meta content="코인데스크코리아 " property="og:title">
# <meta content="코인데스크코리아 " property="og:site_name">
# <meta content="http://www.coindeskkorea.com/image/logo/snslogo_20191211100329.jpg" property="og:image">
# <meta content="http://www.coindeskkorea.com" property="og:url"/>
# <meta content="코인데스크코리아" property="og:description"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="코인데스크코리아 " name="twitter:title"/>
# <meta content="코인데스크코리아" name="twitter:description"/>
# <meta content="http://www.coindeskkorea.com/image/logo/snslogo_20191211100329.jpg" name="twitter:image:src"/>
# <!--// 메타태그정보 -->
# <title>CoinDesk Korea 신뢰 그 이상의 가치</title>
# <link href="/image/logo/snslogo_20191211100329.jpg" rel="apple-touch-icon-precomposed"/>
# <link href="/css/jquery-ui.min.css" rel="stylesheet"/>
# <link href="/css/foundation.min.css" rel="stylesheet"/>
# <link href="/css/custom.foundation.min.css" rel="stylesheet"/>
# <link href="/css/slick.min.css" rel="stylesheet"/>
# <link href="/css/webfonts.min.css" rel="stylesheet"/>
# <link href="/css/aos.min.css" rel="stylesheet"/>
# <link href="/css/style.min.css" rel="stylesheet"/>
# <link href="/css/design.style.css" rel="stylesheet"/>
# <link href="/menuskin/md_01/menubar.css" rel="stylesheet"/>
# <link href="/image/logo/favicon_20191211100547.ico" rel="shortcut icon"/>
# <script src="/script/jquery.min.js"></script>
# <script src="/script/jquery-ui.min.js"></script>
# <script src="/script/slick.min.js"></script>
# <script src="/script/jquery.rwdImageMaps.min.js"></script>
# <script src="/script/what-input.js"></script>
# <script src="/script/foundation.min.js"></script>
# <script src="/menuskin/md_01/menubar.js"></script>
# <script src="/script/user.style.js"></script>
# <script src="/script/clipboard.min.js"></script>
# <script src="/script/jquery.tabslet.min.js"></script>
# <script src="/script/aos.min.js"></script>
# <script src="/script/aos.nd.js"></script>
# <script src="/script/common.js"></script>
# <script type="text/javascript">
#
# 	// 이미지맵
# 	$(document).ready(function(e) {
# 		$('img[usemap]').rwdImageMaps();
#
# 		bannerpop.banner(".banner_event_box");					// 기능성배너 이벤트
# 		bannerpopMulti.bannerLoad();                            // 멀티 기능성 배너 이벤트
#
# 		// 기사뷰 이미지관련
# 			});
#
# 	// domain
# 	var SITE_DOMAIN = 'http://www.coindeskkorea.com'
# 	,___currentTime	= 1593670077;
#
# </script>
# <style type="text/css">
# /* 사이트 기본 색 */
# .user-point,a.user-point,
# .poll-columns .poll-state.going,
# .auto-hr04-2 .auto-nav .slick-slide.slick-current .auto-fontA,.auto-hr05 .auto-nav .slick-slide.slick-current .auto-fontA,
# .info-social .fonts-option-panel li input[type="radio"]:checked + label
# {color:#f8c400 !important}
# .user-bg,.user-bg:hover,.user-bg:active,.user-bg:focus,li[id*="slick-"].slick-active button[data-role],.checkbox-group > input[type="radio"]:checked + label, .checkbox-group > input[type="checkbox"]:checked + label,
# .radio-group > input[type="radio"]:checked + label, .radio-group > input[type="checkbox"]:checked + label,
# .article-list .article-list-content.type-tm .list-block .links:hover,.tabs .tabs-title.is-active a,
# .poll-view .poll-view-state.going,.poll-view .poll-radio input[type="radio"]:checked + label::before,.poll-view .poll-radio input[type="checkbox"]:checked + label::before,
# .auto-dl04 .auto-column::after,.auto-mr01::before,.auto-hp02 a:hover .photo-titbg,.auto-hr04 .auto-nav .slick-slide.slick-current,.auto-hr04-1 .auto-nav .slick-slide.slick-current,
# .nd-switch.user-bg input[type="checkbox"]:checked + label,.nd-switch.user-bg input[type="radio"]:checked + label,
# .nd-switch.user-bg input[type="checkbox"]:checked + label::before,.nd-switch.user-bg input[type="radio"]:checked + label::before,
# .switch-group.user-bg > .nd-switch input[type="checkbox"]:checked + label,.switch-group.user-bg > .nd-switch input[type="radio"]:checked + label,
# .switch-group.user-bg > .nd-switch input[type="checkbox"]:checked + label::before,.switch-group.user-bg > .nd-switch input[type="radio"]:checked + label::before,
# .switch-group.for-ios > .nd-switch.user-bg input[type="checkbox"]:checked + label,.switch-group.for-ios > .nd-switch.user-bg input[type="radio"]:checked + label,
# .switch-group.for-ios > .nd-switch.user-bg input[type="checkbox"]:checked + label::before,.switch-group.for-ios > .nd-switch.user-bg input[type="radio"]:checked + label::before
# {background-color:#f8c400 !important}
# .user-border,.button.user-bg,
# .poll-view .poll-radio input[type="radio"] + label:hover strong::before,.poll-view .poll-radio input[type="checkbox"] + label:hover strong::before,
# .poll-view .poll-radio input[type="radio"]:checked + label  strong::before,.poll-view .poll-radio input[type="checkbox"]:checked + label  strong::before,
# .auto-pa01 .auto-nav .slick-current .auto-images::before,.auto-hr05-1 .auto-content a:hover .auto-images.line::before,
# #gallery-wrap .gallery-content.view-page .gallery-thumb .nav-content.slick-current::before,
# .info-social .fonts-option-panel li input[type="radio"]:checked + label
# {border-color:#f8c400 !important}
# .user-border-top {border-top-color:#f8c400 !important}
# .user-border-bottom {border-bottom-color:#f8c400 !important}
# .user-border-left {border-left-color:#f8c400 !important}
# .user-border-right {border-right-color:#f8c400 !important}
# .mobile-tabs .tabs .is-active a {color:#f8c400 !important;background:#fff !important}
# </style>
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#   window.googletag = window.googletag || {cmd: []};
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/21699126583/Coindesk_Apage_top_RightRail', [300, 250], 'div-gpt-ad-1579684795977-0').addService(googletag.pubads());
#     googletag.defineSlot('/21699126583/Coindesk_Apage_top_Leaderboard', [[728, 90], [970, 90]], 'div-gpt-ad-1579685034481-0').addService(googletag.pubads());
# 	googletag.defineSlot('/21699126583/Coindesk_Apage_Right_Skyscraper', [160, 600], 'div-gpt-ad-1579685096730-0').addService(googletag.pubads());
# 	googletag.defineSlot('/21699126583/Coindesk_Bpage_article_Middle', [300, 250], 'div-gpt-ad-1579685131805-0').addService(googletag.pubads());
# 	googletag.defineSlot('/21699126583/Coindesk_Bpage_Right_Skyscraper', [160, 600], 'div-gpt-ad-1579685161281-0').addService(googletag.pubads());
# 	googletag.defineSlot('/21699126583/Coindesk_Bpage_top_Leaderboard', [[728, 90], [970, 90]], 'div-gpt-ad-1579685182114-0').addService(googletag.pubads());
# 	googletag.defineSlot('/21699126583/Coindesk_Bpage_top_RightRail', [300, 250], 'div-gpt-ad-1579685216165-0').addService(googletag.pubads());
# 	googletag.defineSlot('/21699126583/Coindesk_Mobile_Apage_Leaderboard', [320, 50], 'div-gpt-ad-1579685239708-0').addService(googletag.pubads());
# 	googletag.defineSlot('/21699126583/Coindesk_Mobile_Bpage_article_Middle', [300, 250], 'div-gpt-ad-1579685262086-0').addService(googletag.pubads());
# 	googletag.defineSlot('/21699126583/Coindesk_Mobile_Bpage_Leaderboard', [320, 50], 'div-gpt-ad-1579685298003-0').addService(googletag.pubads());
# 	googletag.defineSlot('/21699126583/Coindesk_Mobile_footer_Leaderboard', [320, 50], 'div-gpt-ad-1579685319293-0').addService(googletag.pubads());
# 	googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# <script async="" src="https://www.google-analytics.com/plugins/ua/linkid.js" type="text/javascript"></script>
# <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script>
# <!-- <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-NSNFWH9"></script> -->
# <!-- Dable 스크립트 시작 / 문의 support@dable.io -->
# <script>
# (function(d,a,b,l,e,_) {
# d[b]=d[b]||function(){(d[b].q=d[b].q||[]).push(arguments)};e=a.createElement(l);
# e.async=1;e.charset='utf-8';e.src='//static.dable.io/dist/plugin.min.js';
# _=a.getElementsByTagName(l)[0];_.parentNode.insertBefore(e,_);
# })(window,document,'dable','script');
# dable('setService', 'coindeskkorea.com');
# dable('sendLog');
# </script>
# <!-- Dable 스크립트 종료 / 문의 support@dable.io -->
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-156669016-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-156669016-1');
# </script>
# <!-- Facebook Pixel Code -->
# <script>
#   !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '2012614539007426');
#   fbq('track', 'PageView');
# </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=2012614539007426&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- Naver Analytics -->
# <script src="https://wcs.naver.net/wcslog.js" type="text/javascript"></script>
# <script type="text/javascript">
# if(!wcs_add) var wcs_add = {};
# wcs_add["wa"] = "11c6340f97fbc";
# wcs_do();
# </script>
# </meta></meta></meta></meta></head>
# <body>
# <!-- wrap //-->
# <div class="mobile" data-effect="fade-up" data-effect-time="300" id="user-wrap">
# <div class="row expanded">
# <style type="text/css">
# #header-wrapper.basic, #header-wrapper .mode-inner {width:1250px}
# #header-wrapper #user-nav .mode-inner {width:100%}
#
# @media screen and (max-width: 78.125em) {
# 	#header-wrapper .mode-inner {width:100%;padding-left:1.25rem;padding-right:1.25rem}
# }
#
# /* 1차 */
# #user-nav .user-menu .secline > a.a-active,
# #m-nav-box .user-all-menu .secline > a.a-active {color:#f8c400}
# #user-nav .user-menu .secline.is-sub > a.a-active::after {border-bottom-color:#f8c400}
# #user-nav .user-menu .secline > a[href*="MOBILE_12"],
# #m-nav-box .user-all-menu .secline > a[href*="MOBILE_12"] {background-color:#f8c400}
#
# /* 2차 */
# #nav-header .sub-fixed .sub-inner {width:1250px}
# #nav-header .sub-fixed .sub > a::before {background-color:#f8c400}
#
# /* 2차 - 배경 slideDown */
# #header-wrapper.horizon #user-nav.active::before {background-color:#f8c400}
#
# /* 2차 - vertical & use autobox */
# #header-wrapper.vertical.nav-autobox #user-nav .user-menu .secline > ul {width:1250px;padding-right:calc(1250px - 300px);border-color:#f8c400}
# #header-wrapper.vertical.nav-autobox #user-nav .user-menu .secline .sub > a.a-sub-hover,
# #header-wrapper.vertical.nav-autobox #user-nav .user-menu .secline .sub > a:hover {color:#fff;background-color:#f8c400}
#
# /* 모바일 메뉴 */
# #m-nav-box .user-all-menu .secline > a::after {color:#f8c400}
# #m-nav-box .user-all-menu .secline ul > li::before {background-color:#f8c400}
# </style>
# <!-- 메뉴시작 //-->
# <div class="vertical full left" data-main-code="/news/articleList.html" data-serial-code="/news/articleList.html" data-sub-code="/news/articleList.html" id="header-wrapper">
# <!-- 최종편집
# 	<div class="user-intro">UPDATED. 2020-07-02 15:05 (목) </div> -->
# <header id="nav-header">
# <div id="user-top">
# <div class="mode-inner">
# <!-- sns //-->
# <div class="user-sns">
# <a data-tooltip="" href="https://t.me/coindesk_korea" target="_blank" title="텔레그램"><i class="fa fa-telegram"></i></a>
# <a data-tooltip="" href="http://www.facebook.com/coindeskkorea" target="_blank" title="페이스북"><i class="icon-facebook"></i></a>
# <a data-tooltip="" href="https://www.youtube.com/channel/UCzxDMBaqJHhTHphiFxCCgxQ" target="_blank" title="유튜브"><i class="icon-youtube"></i></a>
# <a data-tooltip="" href="https://twitter.com/coindeskkorea" target="_blank" title="트위터"><i class="icon-twitter"></i></a>
# </div>
# <!--// sns -->
# <!-- 해외사이트 //-->
# <div id="m-drop-site">
# <ul class="no-bullet" id="drop-menu-all">
# <li>
# <a class="drop-tit">한국 <i aria-hidden="true" class="fa fa-caret-down"></i></a>
# <ul class="no-bullet" id="drop-menu">
# <li><a href="http://www.coindesk.com" target="_blank">English</a></li>
# <li><a href="http://www.coindeskchinese.com" target="_blank">Chinese</a></li>
# <li><a href="http://www.coindeskjapan.com" target="_blank">Japanese</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <script type="text/javascript">
# $(function(){
#
# 	$("ul#drop-menu-all > li").each(function(idx, ele){
#
# 		// 1차 클릭
# 		$(ele).children("a").on("click", function(e){
#
# 			if($(ele).find("ul > li").length <= 0) return;	// 2차 메뉴가 없으면 return
#
# 			e.preventDefault();		// 링크기능 제거
#
# 			if($(this).hasClass("sub-active")){
# 				$(ele).children("a").removeClass("sub-active");
# 				$(ele).children("ul").slideUp();
# 			} else {
# 				$("ul#user-all-menu > li > a").removeClass("sub-active");
# 				$(ele).children("a").addClass("sub-active");
# 				$("ul#user-all-menu > li > ul").slideUp();
# 				$(ele).children("ul").slideDown();
# 			}
# 		});
#
# 	});
#
# });
# </script> <!--// 해외사이트 -->
# <!-- 이전검색위치 -->
# <div class="search-menu user-menu" id="user-menu">
# <!-- 검색 //-->
# <div class="secline sub-active search">
# <a class="search-btn"><i class="s7-search"></i></a>
# <div class="sub-fixed">
# <div class="sub-inner">
# <button class="sub-close" onclick="subClose(this)" type="button"><img src="/menuskin/md_01/close-btn.png"/></button>
# <fieldset class="user-search-form">
# <form action="/news/articleList.html" method="post" name="head-search">
# <input name="sc_area" type="hidden" value="A"/>
# <input name="view_type" type="hidden" value="sm"/>
# <label class="show-for-sr" for="search">기사검색</label>
# <input id="search" name="sc_word" onkeydown="if(event.keyCode==13){if(this.form.sc_word.value != ''){this.form.submit();}else{alert('검색어를 입력해주세요');return false;}}" placeholder="Search" title="Search" type="text"/>
# <button onclick="if(this.form.sc_word.value != ''){this.form.submit();}else{alert('검색어를 입력해주세요');this.form.sc_word.focus();return false;}" title="기사검색" type="button"><i class="s7-search"></i><span class="show-for-sr">검색</span></button>
# </form>
# </fieldset>
# <!-- follow us11 //-->
# <div class="for-menu">
# <iframe frameborder="0" height="420" noresize="" src="http://www.coindeskkorea.com/menuskin/md_01/followus.php" width="525"></iframe>
# </div>
# <!--// follow us -->
# </div>
# </div>
# </div>
# <!--// 검색 -->
# </div>
# </div>
# </div>
# <!--// 최상단영역 -->
# <div class="mode-inner">
# <!-- logo //-->
# <div class="user-logo text-left"><a href="http://www.coindeskkorea.com" target="_top"><img alt="코인데스크코리아 " src="/image/logo/mobilelogo_20191211103546.png"/></a></div>
# <!--// logo -->
# <nav class="user-nav" id="user-nav">
# <!-- 1차 섹션 //-->
# <ul class="user-menu no-bullet" id="user-menu">
# <li class="secline">
# <a data-code="sm" href="/news/articleList.html?view_type=sm" target="_top">News</a>
# <div class="sub-fixed">
# <div class="sub-inner">
# <button class="sub-close" type="button"><img src="/menuskin/md_01/close-btn.png"/></button>
# <!-- follow us22 //-->
# <div class="for-menu">
# <iframe frameborder="0" height="420" noresize="" src="https://www.coindeskkorea.com/menuskin/md_01/followus.php" width="525"></iframe>
# </div>
# <!--// follow us -->
# </div>
# </div>
# </li>
# <li class="secline">
# <a data-code="K" href="/news/articleList.html?sc_area=K&amp;sc_word=에디터스픽&amp;view_type=sm" target="_blank">Editor’s Pick</a>
# <div class="sub-fixed">
# <div class="sub-inner">
# <button class="sub-close" type="button"><img src="/menuskin/md_01/close-btn.png"/></button>
# <!-- follow us22 //-->
# <div class="for-menu">
# <iframe frameborder="0" height="420" noresize="" src="https://www.coindeskkorea.com/menuskin/md_01/followus.php" width="525"></iframe>
# </div>
# <!--// follow us -->
# </div>
# </div>
# </li>
# <li class="secline">
# <a data-code="https://events.bizzabo.com/daxpo" href="https://events.bizzabo.com/daxpo" target="_blank"><span style="background-color:#f8c400;color:#000;padding:10px">Events</span></a>
# <div class="sub-fixed">
# <div class="sub-inner">
# <button class="sub-close" type="button"><img src="/menuskin/md_01/close-btn.png"/></button>
# <!-- follow us22 //-->
# <div class="for-menu">
# <iframe frameborder="0" height="420" noresize="" src="https://www.coindeskkorea.com/menuskin/md_01/followus.php" width="525"></iframe>
# </div>
# <!--// follow us -->
# </div>
# </div>
# </li>
# <div class="menu-line user-menu" id="user-menu">
# <!-- 검색 //-->
# <div class="secline sub-active search">
# <a class="search-btn"><i class="s7-search"></i></a>
# <div class="sub-fixed">
# <div class="sub-inner">
# <button class="sub-close" onclick="subClose(this)" type="button"><img src="/menuskin/md_01/close-btn.png"/></button>
# <fieldset class="user-search-form">
# <form action="/news/articleList.html" method="post" name="head-search">
# <input name="sc_area" type="hidden" value="A"/>
# <input name="view_type" type="hidden" value="sm"/>
# <label class="show-for-sr" for="search">기사검색</label>
# <input id="search" name="sc_word" onkeydown="if(event.keyCode==13){if(this.form.sc_word.value != ''){this.form.submit();}else{alert('검색어를 입력해주세요');return false;}}" placeholder="Search" title="Search" type="text"/>
# <button onclick="if(this.form.sc_word.value != ''){this.form.submit();}else{alert('검색어를 입력해주세요');this.form.sc_word.focus();return false;}" title="기사검색" type="button"><i class="s7-search"></i><span class="show-for-sr">검색</span></button>
# </form>
# </fieldset>
# <!-- follow us11 //-->
# <div class="for-menu">
# <iframe frameborder="0" height="420" noresize="" src="http://www.coindeskkorea.com/menuskin/md_01/followus.php" width="525"></iframe>
# </div>
# <!--// follow us -->
# </div>
# </div>
# </div>
# <!--// 검색 -->
# </div>
# <!-- 해외사이트 //-->
# <!--// 해외사이트 -->
# </ul>
# <!--// 섹션 -->
# </nav>
# <!--// 메뉴바 -->
# <!-- menu button //-->
# <button class="menu-btn" id="menu-btn" type="button"><i class="s7-search"></i><span class="sr-only">메뉴</span></button>
# <!--// menu button -->
# <!-- mobile nav //-->
# <div id="m-nav-box">
# <!-- 검색 //-->
# <fieldset class="user-search-form">
# <form action="/news/articleList.html" method="post" name="head-search">
# <input name="sc_area" type="hidden" value="A"/>
# <input name="view_type" type="hidden" value="sm"/>
# <label class="show-for-sr" for="search">기사검색</label>
# <input id="search" name="sc_word" onkeydown="if(event.keyCode==13){if(this.form.sc_word.value != ''){this.form.submit();}else{alert('검색어를 입력해주세요');return false;}}" placeholder="Search" title="Search" type="text"/>
# <button onclick="if(this.form.sc_word.value != ''){this.form.submit();}else{alert('검색어를 입력해주세요');this.form.sc_word.focus();return false;}" title="기사검색" type="button"><i class="s7-search"></i><span class="show-for-sr">검색</span></button>
# </form>
# </fieldset>
# <!--// 검색 -->
# <!-- 섹션 //-->
# <ul class="user-all-menu" id="user-all-menu">
# <li class="secline">
# <a data-code="sm" href="/news/articleList.html?view_type=sm" target="_top">News</a>
# <ul class="no-bullet">
# </ul>
# </li>
# <li class="secline">
# <a data-code="K" href="/news/articleList.html?sc_area=K&amp;sc_word=에디터스픽&amp;view_type=sm" target="_blank">Editor’s Pick</a>
# <ul class="no-bullet">
# </ul>
# </li>
# <li class="secline">
# <a data-code="https://events.bizzabo.com/daxpo" href="https://events.bizzabo.com/daxpo" target="_blank"><span style="background-color:#f8c400;color:#000;padding:10px">Events</span></a>
# <ul class="no-bullet">
# </ul>
# </li>
# </ul>
# <!--// 섹션 -->
# <button class="nav-all-close" id="nav-all-close" type="button"><img src="/menuskin/md_01/close-btn.png"/></button>
# </div>
# <script type="text/javascript">
# $(function(){
# 	var userAllNav = $(".user-all-nav");
#
# 	/* 전체메뉴 버튼 클릭
# 	navAllBtn.on("click", function(){
# 		if(navAllBox.css("display") == "none"){
# 			navAllBtn.addClass("close");
# 			navAllBox.slideDown();
# 		} else {
# 			navAllBtn.removeClass("close");
# 			navAllBox.slideUp();
# 		}
# 	});
#
# 	// 전체메뉴 영역 외 클릭시 감추기
# 	$(document).mouseup(function(e) {
# 		if (!userAllNav.is(e.target) && userAllNav.has(e.target).length === 0) {
# 			navAllBtn.removeClass("close");
# 			navAllBox.css("left", "-300px");
# 		}
# 	});
# 	*/
#
# 	$("ul#user-all-menu > li").each(function(idx, ele){
#
# 		// 2차가 있을 경우 클래스추가
# 		if($(ele).find("ul > li").length > 0) {
# 			$(ele).addClass("is-sub");
# 		}
#
# 		// 1차 클릭
# 		$(ele).children("a").on("click", function(e){
#
# 			if($(ele).find("ul > li").length <= 0) return;	// 2차 메뉴가 없으면 return
#
# 			e.preventDefault();		// 링크기능 제거
#
# 			if($(this).hasClass("sub-active")){
# 				$(ele).children("a").removeClass("sub-active");
# 				$(ele).children("ul").slideUp();
# 			} else {
# 				$("ul#user-all-menu > li > a").removeClass("sub-active");
# 				$(ele).children("a").addClass("sub-active");
# 				$("ul#user-all-menu > li > ul").slideUp();
# 				$(ele).children("ul").slideDown();
# 			}
# 		});
#
# 	});
#
# });
# </script> <!--// mobile nav -->
# </div>
# <!-- 하단영역 /
# 		<div id="user-gnb">
# 			<div class="mode-inner">
#
# 				<div class="coindesk-area">
# 					<strong class="tit-area">코인데스크 BPI</strong><span class="point-area"> $8,662.80 -0.41</span>
# 				</div>
# 			</div>
# 		</div>
# 		//-->
# <div id="user-gnb">
# <div class="mode-inner">
# <!-- 코인시세 //-->
# <div class="coindesk-area">
# <a href="https://www.coindesk.com/price/bitcoin" target="_blank"><strong class="tit-area">Bitcoin</strong><span class="point-area"> $9,196.24</span></a>
# </div>
# <!-- 수동롤링 -->
# <div class="livenews-wrap">
# <style type="text/css">
# #skin-bbs_2_MOBILE_TR04-3 {overflow:hidden;position:relative;padding:10px 8px}
# #skin-bbs_2_MOBILE_TR04-3::after {content:'';position:absolute;z-index:1;right:0;top:0;width:50%;height:100%}
# #skin-bbs_2_MOBILE_TR04-3 .auto-btns, #skin-bbs_2_MOBILE_TR04-3 .container {float:left;position:relative;z-index:2}
# #skin-bbs_2_MOBILE_TR04-3 .auto-btns {overflow:hidden;width:60px;height:27px;line-height:27px;letter-spacing:-.05em;color:#e73f72;background-color:rgba(255,255,255,.9);border-radius:32px;text-align:center}
# #skin-bbs_2_MOBILE_TR04-3 .container {width:calc(100% - 60px);padding-left:12px}
# #skin-bbs_2_MOBILE_TR04-3 .auto-titles {overflow:hidden;height:25px;line-height:25px;text-overflow:ellipsis;white-space:nowrap}
# </style>
# <div class="auto-article" id="skin-bbs_2_MOBILE_TR04-3">
# <div class="container" id="roll-bbs_2_MOBILE_TR04-3">
# <div class="item dis-none">
# <a class="auto-titles size-14 auto-fontF" href="https://bit.ly/2yN8FRR" target="_blank">DAXPO 2020 | 부산 파라다이스 호텔, 2020년 9월 3-4일</a>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# (function() {
#
# 	$('#roll-bbs_2_MOBILE_TR04-3').slick({
# 		arrows: false, // 화살표표시
# 		dots: false, // pager
# 		vertical: true, // 세로방향
# 		verticalSwiping: true, // 세로swiping
# 		infinite: true, // 무한넘기기
# 		autoplay: true, // 자동전환
# 		//autoplaySpeed: 4000, // 자동전환속도
# 		speed: 600, // 넘기는 속도
# 	});
#
# })();
# </script>
# </div>
# </div>
# </div>
# </header>
# </div>
# <!--// 메뉴 끝 -->
# <script type="text/javascript">
# <!--
# //메뉴 스타일 불러옴 : 메뉴 /script/menubar.js 와 같이 사용되어야 함
# //submenuStyle	: 서브메뉴 펼침 스타일 (horizon : 가로로, vertical : 세로 슬라이딩)
# var menuIndexHold = false,
# menuOverHold = true,
# submenuStyle = "vertical",
# sizeMode = "full",
# subShow = "hold",
# submenuPosi = "left",
# effectSwitch = "on",
# subSlideSpeed = 150,
# subFadeSpeed = 150;
#
# $(document).ready(function(){
#
# 	// 메뉴바 스크롤 시 fixed
#
# 	var nowScrool = $(document).scrollTop(); //현재 스크롤값
#
# 	$(window).scroll(function(){
# 		var navHeight = $("#nav-header").outerHeight();
# 		if($(document).scrollTop() > navHeight){
# 			if(nowScrool > $(document).scrollTop()){
# 				$("#nav-header").addClass("scroll");
# 				//$("#user-gnb").css("display","block");
# 			} else {
# 				$("#nav-header").removeClass("scroll");
# 			}
# 			nowScrool = $(document).scrollTop();
# 			$("#nav-header").addClass("scroll");
# 		}else{
# 			$("#nav-header").removeClass("scroll");
# 		}
# 	});
#
# 	// 1차 클릭 (2차 펼침)
# 	$("#user-menu > .secline.sub-active > a").on("click",function(){
# 		if($(this).siblings(".sub-fixed").css("display") == "none") {
# 			$(".sub-fixed").hide();
# 			$("#user-menu > .secline > a").removeClass("a-active");
# 			$(this).addClass("a-active");
# 			$(this).siblings(".sub-fixed").slideDown();
# 			$('body, html').css('overflow','hidden');
# 		} else {
# 			$(this).removeClass("a-active");
# 			$(this).siblings(".sub-fixed").slideUp();
# 			$('body, html').css('overflow','initial');
# 		}
# 	});
#
# 	// 2차 닫기
# 	var subCloseBtn = $(".sub-close");
# 	subCloseBtn.on("click", function(){
# 		$(this).parent().parent(".sub-fixed").slideUp();
# 		$("#user-menu > .secline > a").removeClass("a-active");
# 		$('body, html').css('overflow','initial');
# 	});
#
#
# 	// 모바일 메뉴 open
# 	$("#menu-btn").on("click", function(){
# 		if($("#m-nav-box").css("display") == "none"){
# 			$("#m-nav-box").slideDown();
# 			$('body, html').css('overflow','hidden');
# 		} else {
# 			$("#m-nav-box").slideUp();
# 			$('body, html').css('overflow','initial');
# 		}
# 	});
#
# 	// 모바일 메뉴 close
# 	$("#nav-all-close").on("click", function(){
# 		$("#m-nav-box").slideUp();
# 		$('body, html').css('overflow','initial');
# 	});
#
# });
# //-->
# </script>
# <!-- container //-->
# <section id="user-container">
# <!-- layer popup position  -->
# <div id="layer-popups"></div>
# <!-- 플로팅 좌우 HTML //-->
# <div class="floating-banner-layout posi-re float-center width-1250"></div> <!--// 플로팅 좌우 HTML -->
# <div class="float-center custom-m mobile template list max-width-1250">
# <!-- 편집패널 //-->
# <div class="clearfix">
# </div>
# <!--// 편집패널 -->
# <!-- article view wrapper //-->
# <div class="user-content">
# <!-- 기사본문 좌측 //-->
# <aside class="custom-aside">
# </aside>
# <!--// 기사본문 좌측 -->
# <!-- 기사본문 내용 //-->
# <section class="custom-snb">
# <!-- contents //-->
# <article class="article-veiw-body">
# <!-- 편집패널 //-->
# <div class="clearfix">
# <div class="box-margins height-20"></div>
# </div>
# <!--// 편집패널 -->
# <div class="text-center">
# <div class="float-center">
# <div class="search-box">
# <form action="/news/articleList.html" method="get" name="search_form">
# <input name="sc_area" type="hidden" value="A"/>
# <input name="view_type" type="hidden" value="sm"/>
# <div class="input-box">
# <fieldset class="row expanded small-collapse medium-uncollapse">
# <div class="small-12 medium-8 large-9 columns"><input class="top-input" name="sc_word" type="text" value=""/></div>
# <div class="small-12 medium-4 large-3 columns"><button class="search-btn2" style="cursor:pointer" type="submit">검색</button></div>
# </fieldset>
# </div>
# <div class="category float-left">
# <div class="data">
# <div class="small-12 width-180 columns">
# <span>정렬</span>
# <select class="width-100 auto-marbtm-1" name="sc_order_by">
# <option selected="" value="E">최신순
# 								<option value="ER">오래된순
# 							</option></option></select>
# </div>
# <div class="small-12">
# <a class="date-link" href="/news/articleList.html?sc_day=&amp;sc_word=&amp;sc_area=&amp;view_type=sm&amp;sc_order_by=E">전체</a>
# <a class="date-link" href="/news/articleList.html?sc_day=1&amp;sc_word=&amp;sc_area=&amp;view_type=sm&amp;sc_order_by=E">1일</a>
# <a class="date-link" href="/news/articleList.html?sc_day=7&amp;sc_word=&amp;sc_area=&amp;view_type=sm&amp;sc_order_by=E">1주</a>
# <a class="date-link" href="/news/articleList.html?sc_day=30&amp;sc_word=&amp;sc_area=&amp;view_type=sm&amp;sc_order_by=E">1개월</a>
# <a class="date-link" href="/news/articleList.html?sc_day=365&amp;sc_word=&amp;sc_area=&amp;view_type=sm&amp;sc_order_by=E">1년</a>
# <a class="date-link" href="javascript:;" id="date-input-box-view">직접입력</a>
# </div>
# </div>
# <div class="small-12 medium-9 large-10 columns dis-none" id="date-input-box">
# <div class="row expanded collapse small-up-1 medium-up-2">
# <div class="columns">
# <label class="show-for-sr" for="sc_sdate">시작 년월일</label>
# <div class="input-group small-width-calc-1 auto-marbtm-1">
# <input class="input-group-field" id="sc_sdate" name="sc_sdate" placeholder="2011-01-01" title="시작 년월일" type="text" value=""/>
# <span class="input-group-label">부터</span>
# </div>
# </div>
# <div class="columns">
# <label class="show-for-sr" for="sc_edate">마지막 년월일</label>
# <div class="input-group">
# <input class="input-group-field" id="sc_edate" name="sc_edate" placeholder="2017-01-01" title="마지막 년월일" type="text" value=""/>
# <span class="input-group-label">까지</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# <script>
# 	//datepicker
# 	$.datepicker.setDefaults($.datepicker.regional['ko']);
# 	$('#sc_sdate, #sc_edate').datepicker({
# 		dateFormat : "yy-mm-dd"
# 	});
#
# 	$('#date-input-box-view').click(function(e){
# 		if($('#date-input-box').hasClass("dis-none")){
# 			$('#date-input-box').removeClass("dis-none");
# 		} else {
# 			$('#date-input-box').addClass("dis-none");
# 		}
# 	});
# </script>
# <div class="box-margins height-20"></div>
# <!-- 기사리스트 //-->
# <div class="article-list">
# <!-- 웹진형 //-->
# <section class="article-list-content type-sm text-left">
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202007/71169_7506_344_v150.jpg)">
# <a href="/news/articleView.html?idxno=71169" target="_top">
# <span class="show-for-sr">FATF, 개발자 포함하는 고위 라운드테이블 꾸린다</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=자금이동규칙&amp;view_type=sm" target="_top">#자금이동규칙</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71169" target="_top"><strong>FATF, 개발자 포함하는 고위 라운드테이블 꾸린다</strong></a></div>
# <div class="list-dated"><strong class="list-name">김병철</strong> 2020-07-02 13:00</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71169" target="_top">
# 					국제자금세탁방지기구(FATF)는 기술발전 속도를 볼 때 암호화폐 등 가상자산도 자금이동규칙(트래블룰)을 지킬 수 있다고 보고 기존 가이드라인을 유지했다.FATF는 지난 24일 온라인에서 열린 31기 3차 총회에서 "회원국의 법제 도입 및 민간의 트래블룰 이행을 위한 기술개발 등을 비춰 볼 때 민·관 모두 발전이 있었으며, 현 시점에서 추가 개정은 불필요하다고 판단했다"고 밝혔다. 한국 정부에서 FATF 관련 사항을 담당하는 금융위원회 금융정보분석원(FIU) 관계자는 "관련 기술의 진전이 있어서 가상자산도 자금이동규칙을 지킬 수 있다					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202007/71168_7505_267_v150.jpg)">
# <a href="/news/articleView.html?idxno=71168" target="_top">
# <span class="show-for-sr">7/2 아침브리핑: 탈중앙금융·탈중앙거래소 선전, 비트코인 채굴 난이도 외</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=블록체인 바이트&amp;view_type=sm" target="_top">#블록체인 바이트</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71168" target="_top"><strong>7/2 아침브리핑: 탈중앙금융·탈중앙거래소 선전, 비트코인 채굴 난이도 외</strong></a></div>
# <div class="list-dated"><strong class="list-name">Daniel Kuhn</strong> 2020-07-02 09:30</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71168" target="_top">
# 					주요 소식탈중앙금융 '농업 혁명'에 탈중앙거래소 거래량도 늘었다탈중앙금융(DeFi) 거래가 급증하면서 탈중앙거래소도 급속히 성장하고 있다. 파라피 캐피털의 벤 포만은 탈중앙 암호화폐 대출 플랫폼 컴파운드(Compound)가 탈중앙 금융 시장을 선도하고 있다고 말했다.“컴파운드는 이른바 새로운 농업 혁명을 촉발했다. 이들 농부는 중앙 금융(CeFi) 거래소 대신 자동화 시스템을 통해 농산물을 거래한다. 물론 이상적인 모습이라고는 볼 수 없다. 그러나 기존 중앙 금융 거래를 이용하던 사람들이 효율성과 수익을 좇아 빠른 속도로 탈중앙금융					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202007/71167_7503_5653_v150.jpg)">
# <a href="/news/articleView.html?idxno=71167" target="_top">
# <span class="show-for-sr">온더, 이더리움 최적화시키는 '튜닝숍'을 꿈꾼다</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=인터뷰&amp;view_type=sm" target="_top">#인터뷰</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71167" target="_top"><strong>온더, 이더리움 최적화시키는 '튜닝숍'을 꿈꾼다</strong></a></div>
# <div class="list-dated"><strong class="list-name">박근모 기자</strong> 2020-07-02 09:10</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71167" target="_top">
# 					많은 블록체인 기업들이 '크립토겨울'을 지나며, 로드맵을 이리저리 바꾸는 와중에서도 3년째 한 우물만 파는 블록체인 스타트업이 있다. 온더가 그 주인공이다.온더는 2017년 창업자 정순형 대표가 이더리움 블록체인의 기술 개발을 위해 만든 기업이다. 업계의 불황에도 불구하고 온더는 매년 지치지 않은 성장세를 기록했다. 정 대표는 그 원동력으로 '이더리움의 가능성'에 방점을 찍었다. 그리고 곧 완벽한 결과물을 공개할 계획이라고 강조했다. 온더가 개발 중인 이더리움 확장 솔루션 '토카막 네트워크(Tokamak network)'에 대한 이					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202007/71166_7501_72_v150.jpg)">
# <a href="/news/articleView.html?idxno=71166" target="_top">
# <span class="show-for-sr">암호화폐 트래블룰, 화이트리스트 방안으로 풀자</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=특금법&amp;view_type=sm" target="_top">#특금법</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71166" target="_top"><strong>암호화폐 트래블룰, 화이트리스트 방안으로 풀자</strong></a></div>
# <div class="list-dated"><strong class="list-name">김동환 기자</strong> 2020-07-02 08:00</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71166" target="_top">
# 					암호화폐 거래소 등 가상자산사업자(VASP)들이 암호화폐의 송금인과 수취인을 모두 파악하도록 요구하는 국제자금세탁기구(FATF)의 자금이동규칙(travel rule) 준수 요구와 관련해, 실제 소유주 신원 확인이 완료된 지갑끼리의 전송만 허용하는 화이트리스트 방안이 논의되고 있다. 자금세탁 방지 차원에서 규제당국이 국내 거래소 계좌의 암호화폐가 국외 전송을 통제할 필요가 있다는 주장도 제기됐다.법무법인 태평양의 윤주호 변호사는 1일 열린 '특금법(특정금융정보법) 컨퍼런스' 행사에서, "지금의 암호화폐(가상자산) 거래소는 거래소 지갑					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202007/71164_7495_1017_v150.jpg)">
# <a href="/news/articleView.html?idxno=71164" target="_top">
# <span class="show-for-sr">‘못다 핀 꽃’ 리브라 1년</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=리브라&amp;view_type=sm" target="_top">#리브라</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71164" target="_top"><strong>‘못다 핀 꽃’ 리브라 1년</strong></a></div>
# <div class="list-dated"><strong class="list-name">김외현</strong> 2020-07-02 06:00</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71164" target="_top">
# 					페이스북이 주도한 암호화폐 프로젝트 ‘리브라’는 애초 약속을 지키지 못했다. 1년 전인 2019년 6월18일 발표된 리브라 ‘백서’는 2020년 상반기 서비스 시작을 기약했지만 실현되지 않았다. 인프라 부족 등 원인으로 은행 계좌가 없는 전세계 금융소외층 17억명을 위해, 나아가 새로운 ‘글로벌 통화’를 위해 블록체인 기반 암호화폐를 만들겠다던 리브라의 꿈은 아직 유보된 상태다. 가장 큰 이유는 각국 규제 당국의 반대였다. 국제 질서는 통화 패권과 맞물려 있었고, 각국 국내 정치에서도 통화 정책은 민감했다. 국적 없는 새로운 통화의					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202007/71165_7499_1755_v150.jpg)">
# <a href="/news/articleView.html?idxno=71165" target="_top">
# <span class="show-for-sr">7/1 오후브리핑: 이더리움 수수료 개선안, 삼성SDS</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=오후브리핑&amp;view_type=sm" target="_top">#오후브리핑</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71165" target="_top"><strong>7/1 오후브리핑: 이더리움 수수료 개선안, 삼성SDS</strong></a></div>
# <div class="list-dated"><strong class="list-name">김동환 기자</strong> 2020-07-01 22:13</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71165" target="_top">
# 					이더리움 “높은 거래 수수료 낮출 새로운 수수료 모델 고려”최근 이더리움의 높은 수수료가 문제로 등장하면서 채굴 수수료 방식을 변경하는 '이더리움 개선제안서(EIP) 1559 코드'가 주목받고 있다. 이더리움 이용자들이 네트워크에 정해진 기본료(base fee)를 내고, 채굴자들에게는 팁(tip)을 주는 방식으로 수수료 정책을 바꾸는 게 이 코드의 내용이다. 삼성SDS, 블록체인·AI 등 혁신기술 체험용 무료 솔루션 공개삼성SDS가 1일 고객의 디지털 트랜스포메이션(전환)을 지원하기 위한 클라우드 기반 엔진 체계를 공개하며 무료 체					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202007/71163_7494_5244_v150.jpg)">
# <a href="/news/articleView.html?idxno=71163" target="_top">
# <span class="show-for-sr">삼성SDS, 블록체인·AI 등 혁신기술 체험용 무료 솔루션 공개</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=삼성SDS&amp;view_type=sm" target="_top">#삼성SDS</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71163" target="_top"><strong>삼성SDS, 블록체인·AI 등 혁신기술 체험용 무료 솔루션 공개</strong></a></div>
# <div class="list-dated"><strong class="list-name">정인선 기자</strong> 2020-07-01 10:00</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71163" target="_top">
# 					삼성SDS가 1일 고객의 디지털 트랜스포메이션(전환)을 지원하기 위한 클라우드 기반 엔진 체계를 소개하고, 무료 체험 서비스 ‘마이트라이얼’을 공개했다. 삼성SDS에 따르면 디지털 트랜스포메이션 엔진은 크게 네 가지 플랫폼 및 서비스로 구성됐다. 블록체인: 신원인증, 결제, 유통이력 관리 등 분야에 적용 가능한 넥스레저(Nexledger)	인공지능(AI) 및 사물인터넷(IoT): 데이터 수집 및 정제를 위한 사물인터넷 플랫폼 브라이틱스(Brightics) IoT, 수집된 데이터의 분석 및 지능화를 위한 통합 AI 플랫폼 브라이틱스A					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202007/71162_7493_3624_v150.jpg)">
# <a href="/news/articleView.html?idxno=71162" target="_top">
# <span class="show-for-sr">7/1 아침브리핑: 디지털달러, 이더리움 수수료, 호주 증권거래소 외</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=블록체인 바이트&amp;view_type=sm" target="_top">#블록체인 바이트</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71162" target="_top"><strong>7/1 아침브리핑: 디지털달러, 이더리움 수수료, 호주 증권거래소 외</strong></a></div>
# <div class="list-dated"><strong class="list-name">Daniel Kuhn</strong> 2020-07-01 09:45</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71162" target="_top">
# 					주요 소식미국 상원 “현금과 결제 수단의 디지털화” 주제로 청문회 개최미국 상원 은행·주택·도시위원회가 “현금과 결제 수단의 디지털화”를 주제로 청문회를 연다. 청문회에는 크리스토퍼 장칼로 전 상품선물거래위원회(CFTC) 위원장, 찰스 카스카릴라 팩소스(Paxos) CEO가 증인으로 출석해 중앙은행이 발행하는 디지털 화폐(CBDC)와 스테이블코인 개발에 관해 증언할 예정이다.국제결제은행(BIS)이 혁신허브센터(Innovation Hub Centre)를 토론토, 스톡홀름, 런던에 추가로 설립한다. 파리와 프랑크푸르트에는 공동 센터를					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202007/71161_7492_4346_v150.jpg)">
# <a href="/news/articleView.html?idxno=71161" target="_top">
# <span class="show-for-sr">이더리움 “높은 거래 수수료 낮출 새로운 수수료 모델 고려”</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=이더리움&amp;view_type=sm" target="_top">#이더리움</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71161" target="_top"><strong>이더리움 “높은 거래 수수료 낮출 새로운 수수료 모델 고려”</strong></a></div>
# <div class="list-dated"><strong class="list-name">William Foxley</strong> 2020-07-01 09:00</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71161" target="_top">
# 					요약:	이더리움(Ethereum) 블록체인의 거래 수요가 늘면서 거래 수수료도 엄청난 수준으로 증가했다.	역동적인 방식으로 가격을 책정하는 신기술의 등장으로 높은 수수료 문제를 해결할 수 있게 됐다.	이더리움 개선제안서(EIP) 1559 코드는 이더리움 이용자들이 네트워크에 정해진 기본료(base fee)를 내고, 채굴자들에게는 팁(tip)을 주는 방식이다.	한 기술 애널리스트는 이를 “모든 블록체인을 통틀어, 네트워크 출시 이후 생긴 변화 중 가장 큰 변화”라고 평가했다. 이더리움 네트워크를 이용하는 비용이 지난 4월 이후 500					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71159_7491_89_v150.jpg)">
# <a href="/news/articleView.html?idxno=71159" target="_top">
# <span class="show-for-sr">6/30 오후브리핑: 특금법 토론회, 러시아 투표 해킹</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=오후브리핑&amp;view_type=sm" target="_top">#오후브리핑</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71159" target="_top"><strong>6/30 오후브리핑: 특금법 토론회, 러시아 투표 해킹</strong></a></div>
# <div class="list-dated"><strong class="list-name">김동환 기자</strong> 2020-06-30 21:18</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71159" target="_top">
# 					러시아 개헌 블록체인 투표에 해킹 시도 확인27일(현지시각) 러시아 타스통신에 따르면 러시아 개헌 국민투표에 사용되고 있는 블록체인 투표 시스템에 해킹 시도가 있었던 것으로 확인됐다. 러시아 측은 블록체인의 감시 노드가 해킹 타깃이 됐으나 투표는 방해받지 않고 있다고 밝혔다. 블록체인의 투명성을 모두 좋아할까?블록체인 업계에서는 퍼블릭 블록체인의 투명성을 장점으로 생각한다. 그러나 블록체인에 관심이 없는 일반 소비자들은 코인을 이용한 자신의 거래 내역을 타인이 들여다볼 수 있다는 것에 기분나쁨을 느끼는 경우도 많다. 최근 일부 블록					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71158_7485_1331_v150.jpg)">
# <a href="/news/articleView.html?idxno=71158" target="_top">
# <span class="show-for-sr">업비트 "암호화폐 거래소도 주민번호 수집 가능해야"</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=특금법&amp;view_type=sm" target="_top">#특금법</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71158" target="_top"><strong>업비트 "암호화폐 거래소도 주민번호 수집 가능해야"</strong></a></div>
# <div class="list-dated"><strong class="list-name">김병철</strong> 2020-06-30 21:00</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71158" target="_top">
# 					암호화폐 거래소 등 가상자산사업자(VASP)도 금융기관처럼 주민등록번호를 수집할 수 있어야 한다는 주장이 나왔다. 주민등록번호 수집기관은 매우 높은 수준의 보안과 내부통제가 필요해 암호화폐 업계에서도 논란이 될 것으로 보인다.황순호 두나무 대외협력팀장은 30일 국회에서 열린 '가상자산(암호화폐) 거래 투명화를 위한 특금법 시행령 토론회'에서 VASP의 주민등록번호 수집 필요성을 제기했다.발표자로 참가한 황 팀장은 "금융기관과 달리 (암호화폐) 거래소는 현행 법령에 따라 회원의 주민등록번호 수집이 불가능하다"면서 "고객 정보 수집의					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71151_7490_387_v150.jpg)">
# <a href="/news/articleView.html?idxno=71151" target="_top">
# <span class="show-for-sr">'2020년의 절반' 상반기 인기기사 Top 10</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=2020년 상반기&amp;view_type=sm" target="_top">#2020년 상반기</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71151" target="_top"><strong>'2020년의 절반' 상반기 인기기사 Top 10</strong></a></div>
# <div class="list-dated"><strong class="list-name">박근모 기자</strong> 2020-06-30 21:00</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71151" target="_top">
# 					편집자 주. 2020년 상반기에는 코로나19의 대유행으로 CBDC에 대한 논의가 본격적으로 이뤄졌고, 개정 특금법이 국회를 통과하면서 블록체인 기술과 제도의 만남을 고민하게 했습니다. 암호화폐 유튜버 스펑키의 피습 사건과 성착취 동영상을 유통시킨 'n번방', '박사방' 사건도 암호화폐 업계를 달궜습니다. 코인데스크코리아의 상반기 기사 가운데 가장 많은 조회수를 기록한 기사는 김태원 글로스퍼 대표의 안타까운 소식이었습니다. 올 상반기 코인데스크코리아에서 가장 많은 관심을 받은 기사 10개를 살펴봅니다. 1. 김태원 글로스퍼 대표 사망					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71149_7448_1740_v150.jpg)">
# <a href="/news/articleView.html?idxno=71149" target="_top">
# <span class="show-for-sr">6/30 아침브리핑: 언스트앤영의 부실 회계감사, 비트코인 익명 개발자들 외</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=블록체인 바이트&amp;view_type=sm" target="_top">#블록체인 바이트</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71149" target="_top"><strong>6/30 아침브리핑: 언스트앤영의 부실 회계감사, 비트코인 익명 개발자들 외</strong></a></div>
# <div class="list-dated"><strong class="list-name">Daniel Kuhn</strong> 2020-06-30 09:30</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71149" target="_top">
# 					주요 소식밸런서 풀, 플래시론 공격으로 토큰 6억원어치 도난당해스마트계약의 허점을 이용한 해킹 사건이 또다시 발생했다. 탈중앙 금융 유동성 제공업체 밸런서 풀(Balancer Pool)은 29일 “범인은 스마트 계약의 허점을 악용해 50만달러, 약 6억원어치의 토큰을 빼돌렸다”며, “dYdX에서 플래시론을 통해 WETH 토큰 2300만달러어치를 빌린 뒤 이것을 다양한 투자 등급의 스트라테라(Stratera) 토큰으로 교환하는 수법을 사용했다”고 밝혔다. 지난 2월에는 bZx 거래소가 플래시론 공격을 당한 바 있다. 이런 공격 방식은					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71148_7447_172_v150.jpg)">
# <a href="/news/articleView.html?idxno=71148" target="_top">
# <span class="show-for-sr">러시아 개헌 블록체인 투표에 해킹 시도 확인</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=블록체인투표&amp;view_type=sm" target="_top">#블록체인투표</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71148" target="_top"><strong>러시아 개헌 블록체인 투표에 해킹 시도 확인</strong></a></div>
# <div class="list-dated"><strong class="list-name">Daniel Palmer</strong> 2020-06-30 09:30</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71148" target="_top">
# 					러시아의 개헌 국민투표에 쓰이고 있는 블록체인 투표 시스템에 해킹 시도가 있었던 것으로 확인됐다.27일(현지시각) 러시아 타스통신에 따르면, 아르템 코스티르코 모스크바 정보기술부 장관은 블록체인의 감시 노드가 타깃이 됐으나 작동에는 이상이 없다고 밝혔다. 코스티르코 장관은 “현재로선 보안 모드가 강화됐으며, 투표는 방해받지 않고 있다”며 “모든 투표는 정확히 전달돼 블록체인에 기록되고 있다”고 말했다.해당 기사는 해커의 공격 의도가 무엇인지, 침입이 얼마나 성공했는지 등에서는 언급하지 않고 있다. 코스티르코는 공격받은 노드는 현재					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71147_7446_2451_v150.jpg)">
# <a href="/news/articleView.html?idxno=71147" target="_top">
# <span class="show-for-sr">'채굴기 제조사' 이방, 암호화폐 거래소 설립 추진</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=이방&amp;view_type=sm" target="_top">#이방</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71147" target="_top"><strong>'채굴기 제조사' 이방, 암호화폐 거래소 설립 추진</strong></a></div>
# <div class="list-dated"><strong class="list-name">Paddy Baker</strong> 2020-06-30 08:30</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71147" target="_top">
# 					중국의 비트코인 채굴기 제조사 이방(Ebang)이 역외에 암호화폐 거래소 설립을 추진하고 있다. 이를 통해 2022년까지 매출을 2배 증대시키겠다는 계산이다.중국 항저우에 기반한 이방의 재무총괄(CFO) 천레이(陈磊)는 29일(현지시각) 블룸버그BNN과의 인터뷰에서, 중국 이외의 지역에서 규제에 부합하는 암호화폐 거래소를 설립할 계획이라고 밝혔다. 중국 정부는 국내 암호화폐 거래소 운영을 강하게 금지하고 있다.이방으로서는 지속적인 수입원 확보를 위해 현금화 통로를 확보해야 할 수요가 있는 게 사실이다. 그러나 그 밖에 이방의 거래소					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71146_7445_4241_v150.jpg)">
# <a href="/news/articleView.html?idxno=71146" target="_top">
# <span class="show-for-sr">블록체인의 투명성을 모두 좋아할까?</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=&amp;view_type=sm" target="_top">#</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71146" target="_top"><strong>블록체인의 투명성을 모두 좋아할까?</strong></a></div>
# <div class="list-dated"><strong class="list-name">김병철</strong> 2020-06-30 08:00</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71146" target="_top">
# 					제 주변엔 각종 할인혜택을 찾아내 최저가로 결제하는 데 탁월한 능력을 보여주는 지인이 한 명 있습니다. 문화상품권부터 머지포인트까지 섭렵한 그는 일찌감치 티몬 등에서 '차이(Chai)'로 결제하면서 많은 할인을 받고 있었습니다. 그러던 그가 최근 차이스캔(Chaiscan) 이미지와 함께 "이거 문제가 많아 보이는데요?"라는 메시지를 보냈습니다. 차이스캔은 테라 블록체인에 모두 기록된 차이 결제내역을 보기 쉽게 시각화하고, 검색기능도 제공하는 서비스입니다. 그가 지적한 건 검색만으로도 자신의 지갑주소를 찾을 수 있었고, 결제내역이 모					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# ...
# </div>
# <!--// 편집패널 -->
# </div>
# </section>
# <!--// container -->
# <!-- 모바일 하단 -->
# <!-- footer //-->
# <style type="text/css">
# #user-footer.skin-9 {position:relative;overflow:hidden;padding:0;padding-top:80px;background:#172341;border-top:none}
# #user-footer.skin-9 .footer-menu {margin-bottom:0}
# #user-footer.skin-9 .has-tip {border-bottom:none}
# #user-footer.skin-9 .footer-columns {padding:0 585px 75px 80px;vertical-align:bottom}
#
# /* logo */
# #user-footer.skin-9 .user-logo {float:inherit;margin-bottom:30px}
#
# /* nav */
# #user-footer.skin-9 .user-nav {display:block;margin-bottom:20px;font-size:16px;font-weight:400}
# #user-footer.skin-9 .user-nav a {font-size:15px;color:#fefefe}
# #user-footer.skin-9 .user-nav a::before {border-left:none;border-color:rgba(255,255,255,.15)}
#
# /* address */
# #user-footer.skin-9 .user-address ul li,#user-footer.skin-9 .user-address ul li a {color:rgba(255,255,255,.5)}
# #user-footer.skin-9 .user-address ul li.bars::before {color:rgba(255,255,255,.25)}
# #user-footer.skin-9 .user-address ul li {line-height:1.75em}
# #user-footer.skin-9 .user-address ul li.copy-p {max-width:660px}
#
# /* 해외사이트 */
# #user-footer.skin-9 #footer-drop-site {position:relative;display:inline-block;vertical-align:middle}
# #user-footer.skin-9 #footer-drop-site #footer-drop {margin:0}
# #user-footer.skin-9 #footer-drop-site .drop-tit {position:relative;overflow:hidden;display:block;font-size:15px;font-weight:400;color:#fff;line-height:1;text-decoration:none;text-align:center;white-space:nowrap}
# #user-footer.skin-9 #footer-drop-site #drop-menu {display:none;z-index:10;position:absolute;top:30px;min-width:100%;padding:4px 0;max-height:215px;background-color:#161f36;overflow-y:auto;overflow-x:hidden}
# #user-footer.skin-9 #footer-drop-site #drop-menu > li > a {width:100%;display:inline-block;padding:8px 17px;font-size:14px;line-height:1;white-space:nowrap;text-overflow:ellipsis;color:#fff;text-align:left;text-decoration:none;opacity:.4;cursor:pointer}
# #user-footer.skin-9 #footer-drop-site #drop-menu > li > a:hover {opacity:1}
#
# /**********************************************
# note : Follow us
# **********************************************/
# #user-footer.skin-9 .footer-columns.footer-sns {position:absolute;right:0;bottom:0;padding:36px 40px;height:355px;width:585px;background:#fcc117;vertical-align:middle}
# #user-footer.skin-9 .footer-sns header {display:inline-block;margin-bottom:13px;font-size:24px;font-weight:700;color:#161f36;letter-spacing:-.03em}
#
# /* sns */
# #user-footer.skin-9 .footer-sns .user-sns {margin-bottom:18px}
# #user-footer.skin-9 .footer-sns .user-sns section {display:inline-block;margin-left:20px}
# #user-footer.skin-9 .footer-sns .user-sns a {display:inline-block;margin-left:15px;font-size:20px;color:#161f36}
# #user-footer.skin-9 .footer-sns .user-sns a:first-child {margin-left:0}
# #user-footer.skin-9 .footer-sns .user-sns a > i {vertical-align:middle}
#
# /* letter */
# #user-footer.skin-9 .footer-sns .user-letter {width:465px;margin-top:10px}
# #user-footer.skin-9 .footer-sns .user-letter .input-group {margin-bottom:19px}
# #user-footer.skin-9 .footer-sns .user-letter .nd-checked {font-weight:300;text-align:left;color:#161f36}
# #user-footer.skin-9 .footer-sns .user-letter .nd-checked::before {float:left;margin:10px 10px 20px 0}
#
# #user-footer.skin-9 .footer-sns .user-letter-form {margin:10px 0}
# #user-footer.skin-9 .footer-sns .user-letter-form input {float:left;width:70%;height:40px;margin:0;font-size:13px;border:0;box-shadow:0}
# #user-footer.skin-9 .footer-sns .user-letter-form input::-webkit-input-placeholder {color:rgba(0,0,0,.6)} /* 크롬 4–56 */
# #user-footer.skin-9 .footer-sns .user-letter-form input:-moz-placeholder {color:rgba(0,0,0,.6)} /* 파이어폭스 4–18 */
# #user-footer.skin-9 .footer-sns .user-letter-form input::-moz-placeholder {color:rgba(0,0,0,.6)} /* 파이어폭스 19–50 */
# #user-footer.skin-9 .footer-sns .user-letter-form input:-ms-input-placeholder {color:rgba(0,0,0,.6)} /* 인터넷 익스플로러 10+ */
# #user-footer.skin-9 .footer-sns .user-letter-form input::placeholder {color:rgba(0,0,0,.6)} /* 파이어폭스 51+, 크롬 57+ */
# #user-footer.skin-9 .footer-sns .user-letter-form button {float:left;width:30%;height:40px;font-size:13px;font-weight:500;color:#fff;letter-spacing:-.06em;background-color:#19284d;font-family: 'Roboto','Noto Sans KR', sans-serif;cursor:pointer}
# .nd-checkbox input[type="checkbox"] ~ .nd-checked::before {border:none}
# .nd-checkbox.check-dark input[type="checkbox"]:checked ~ .nd-checked::before {background-color:#161f36}
#
# @media screen and (max-width: 63.9375em) {
# 	#user-footer.skin-9 {padding-top:30px}
# 	#user-footer.skin-9 .footer-columns {display:block;padding:30px 20px;width:100%;vertical-align:top;text-align:center}
# 	#user-footer.skin-9 .user-nav {display:inline-block;text-align:center}
# 	#user-footer.skin-9 .user-address ul {text-align:center}
# 	#user-footer.skin-9 .user-address ul li {display:inline-block;float:inherit}
# 	#user-footer.skin-9 .user-address ul li.copy {display:block}
# 	#user-footer.skin-9 .user-address ul li.m-none {display:none}
# 	#user-footer.skin-9 .user-address ul li.m-top-0 {margin-top:0 !important}
# 	#user-footer.skin-9 .user-address {position:inherit}
# 	#user-footer.skin-9 .ndsoft {position:absolute;right:20px;bottom:20px}
# 	#user-footer.skin-9 .footer-columns.footer-sns {position:relative;height:auto;text-align:center;width:100%;border-left:none}
# 	#user-footer.skin-9 .footer-sns .user-letter {width:100%}
# 	#user-footer.skin-9 .footer-sns .user-letter .nd-checked::before {float:none;margin-bottom:0}
# 	#user-footer.skin-9 .footer-sns .user-letter-form {float:inherit;width:100%;margin:0 auto}
# }
#
# @media screen and (max-width: 39.9375em) {
# 	#user-footer.skin-9 .user-nav {display:inline-block;text-align:center}
# 	#user-footer.skin-9 .user-nav a {padding:0 5px;float:inherit;text-align:center}
# 	#user-footer.skin-9 .user-nav a::before,#user-footer.skin-9 .user-nav a::after,#user-footer.skin-9 .user-nav a.m-none {display:none}
# 	#user-footer.skin-9 .footer-sns .user-letter .nd-checked::before {float:left;margin-bottom:20px}
# </style>
# <!-- footer //-->
# <footer class="skin-9 font-noto" id="user-footer">
# <div class="float-center">
# <div class="footer-menu">
# <!-- footer sns //-->
# <div class="footer-columns footer-sns">
# <!-- sns //-->
# <div class="user-sns">
# <header>Follow us</header>
# <section>
# <!--<a href="#" target="_blank" title="인스타그램" data-tooltip><i class="icon-instagram"></i></a>
# 						 <a href="#" target="_blank" title="핀터레스트" data-tooltip><i class="icon-pinterest"></i></a>
# 						<a href="#" target="_blank" title="네이버포스트" data-tooltip><i class="size-19 icon-naver"></i></a>-->
# <a data-tooltip="" href="https://t.me/coindesk_korea" target="_blank" title="텔레그램"><i class="fa fa-telegram"></i></a>
# <a data-tooltip="" href="http://www.facebook.com/coindeskkorea" target="_blank" title="페이스북"><i class="icon-facebook"></i></a>
# <a data-tooltip="" href="https://www.youtube.com/channel/UCzxDMBaqJHhTHphiFxCCgxQ" target="_blank" title="유튜브"><i class="icon-youtube"></i></a>
# <a data-tooltip="" href="https://twitter.com/coindeskkorea" target="_blank" title="트위터"><i class="icon-twitter"></i></a>
# </section>
# </div>
# <!--// sns -->
# <!--
# 				<div class="user-letter">
# 					<header>코인데스크 뉴스레터</header>
# 					<section>
# 						<label class="nd-checkbox check-dark" for="useagree">
# 							<input type="checkbox" id="useagree" name="useagree">
# 							<span class="nd-checked">뉴스레터 발송을 위한 이메일주소를 수집하는데 동의하며, 수집된 이메일주소는 뉴스레터 구독 취소하는 즉시 삭제됩니다.</span>
# 						</label>
# 						<fieldset class="user-letter-form" id="newsletterForm">
# 							<input type="text" name="email" id="email" placeholder="이메일주소 입력" title="뉴스레터신청">
# 							<button type="button" title="신청" id="btn_newsletter_reg" data-tooltip>구독</button>
# 						</fieldset>
# 					</section>
# 				</div>
# 				-->
# <!-- letter //-->
# <div class="user-letter" id="mc_embed_signup">
# <div id="mc_embed_signup_scroll">
# <header>뉴스레터 신청하기</header>
# <label class="nd-checkbox check-dark" for="usercheck">
# <input id="usercheck" name="usercheck" type="checkbox" value="1"/>
# <span class="nd-checked">뉴스레터 발송을 위한 이메일 주소 수집에 동의합니다. 구독 취소시 삭제됩니다.</span>
# </label>
# <form action="https://coindeskkorea.us20.list-manage.com/subscribe/post?u=021280a65c5335b9e3f0f48d6&amp;id=fd0800c586" class="validate" id="mc-embedded-subscribe-form" method="post" name="mc-embedded-subscribe-form" novalidate="" target="_blank">
# <div class="mc-field-group input-group">
# <fieldset class="user-letter-form" id="newsletterForm" style="display: none; ">
# <input class="required email" id="MERGE1" name="MERGE1" placeholder="이름 입력" type="text" value=""/>
# <input class="required email" id="mce-EMAIL" name="EMAIL" placeholder="이메일주소 입력" type="email" value=""/>
# <button class="button" id="mc-embedded-subscribe" name="subscribe" type="submit" value="Subscribe">구독</button>
# </fieldset>
# <div class="clear" id="mce-responses">
# <div class="response" id="mce-error-response" style="display:none"></div>
# <div class="response" id="mce-success-response" style="display:none"></div>
# </div> <!-- real people should not fill this in and expect good things - do not remove this or risk form bot signups-->
# <div aria-hidden="true" style="position: absolute; left: -5000px;"><input name="b_021280a65c5335b9e3f0f48d6_fd0800c586" tabindex="-1" type="text" value=""/></div>
# <div aria-hidden="true" style="position: absolute; left: -5000px;"><input name="b_021280a65c5335b9e3f0f48d6_fd0800c586" tabindex="-1" type="text" value=""/></div>
# </div>
# </form>
# </div>
# <script src="//s3.amazonaws.com/downloads.mailchimp.com/js/mc-validate.js" type="text/javascript"></script>
# <script type="text/javascript">(function($) {window.fnames = new Array(); window.ftypes = new Array();fnames[0]='EMAIL';ftypes[0]='email';}(jQuery));var $mcj = jQuery.noConflict(true);</script>
# </div>
# <!--// letter -->
# <script type="text/javascript">
# 				$(document).ready(function(){
# 					$("#usercheck").attr("checked", false);
#
# 					$("#usercheck").change(function(){
# 						if($("#usercheck").is(":checked")){
# 							$("#newsletterForm").slideToggle(600);
# 						} else {
# 							$("#newsletterForm").slideToggle(600);
# 						}
# 					});
# 				});
# 				</script>
# </div>
# <!--// footer sns -->
# <div class="footer-columns">
# <!-- logo //-->
# <div class="user-logo"><img alt="코인데스크코리아 " src="/image/logo/downlogo_20191211103545.png"/></div>
# <!--// logo -->
# <!-- nav //-->
# <nav class="user-nav">
# <a class="deco-none m-none" href="/rss/" target="_blank">RSS</a>
# <a class="deco-none" href="/com/com-1.html" target="_blank">회사소개</a>
# <a class="deco-none" href="/com/com-4.html" target="_blank">편집원칙</a>
# <a class="deco-none" href="https://www.coindeskkorea.com/com/ad.html" target="_blank">문의</a>
# <a class="deco-none" href="/com/privacy.html" target="_blank">개인정보처리방침</a>
# <a class="deco-none m-none" href="/com/service.html" target="_blank">이용약관</a>
# <a class="deco-none m-none" href="/com/com-3.html" target="_blank">채용</a>
# <!--<a href="#" class="deco-none m-none">Contact Us</a>
# 					<a href="https://www.coindeskkorea.com/com/jh.html" class="deco-none m-none">제휴문의</a>
# 					<a href="/com/youthpolicy.html" class="deco-none">청소년보호정책</a>
# 					 <a href="/com/copyright.html" class="deco-none">저작권보호정책</a>
# 					<a href="/com/emailno.html" class="deco-none">이메일무단수집거부</a>-->
# <div id="footer-drop-site">
# <ul class="no-bullet" id="footer-drop">
# <li>
# <a class="drop-tit">한국 <i aria-hidden="true" class="fa fa-caret-down"></i></a>
# <ul class="no-bullet" id="drop-menu">
# <li><a href="http://www.coindesk.com" target="_blank">English</a></li>
# <li><a href="http://www.coindeskchinese.com" target="_blank">Chinese</a></li>
# <li><a href="http://www.coindeskjapan.com" target="_blank">Japanese</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <script type="text/javascript">
# 					$(function(){
#
# 						$("ul#footer-drop > li").each(function(idx, ele){
#
# 							// 1차 클릭
# 							$(ele).children("a").on("click", function(e){
#
# 								if($(ele).find("ul > li").length <= 0) return;	// 2차 메뉴가 없으면 return
#
# 								e.preventDefault();		// 링크기능 제거
#
# 								if($(this).hasClass("sub-active")){
# 									$(ele).children("a").removeClass("sub-active");
# 									$(ele).children("ul").slideUp();
# 								} else {
# 									$("ul#user-all-menu > li > a").removeClass("sub-active");
# 									$(ele).children("a").addClass("sub-active");
# 									$("ul#user-all-menu > li > ul").slideUp();
# 									$(ele).children("ul").slideDown();
# 								}
# 							});
#
# 						});
#
# 					});
# 					</script>
# </nav>
# <!--// nav  -->
# <!-- address //-->
# <address class="user-address">
# <ul class="no-bullet">
# <li class="bars m-none">22세기미디어㈜   </li>
# <li class="bars m-none">서울특별시 서초구 강남대로 311, 1010호</li>
# <li class="m-none">등록번호 : 서울, 자00548  </li>
# <li class="clear bars m-none">등록일 : 2018-02-26</li>
# <li class="bars m-none">발행인 : 유신재</li>
# <li class="m-none">편집인 : 김외현</li>
# <li class="clear bars m-none">개인정보보호책임자 : 김외현</li>
# <li class="bars m-none">청소년보호책임자 : 김외현</li>
# <li class="m-none">대표 전화 : 070-7774-7906</li>
# <!-- <li class="bars m-none">팩스 : 02-520-1589</li>
# 						<li class="m-none">대표 메일 : <a href="mailto:master@coindeskkorea.com" class="deco-none">master@coindeskkorea.com</a></li>
# 						<li class="m-none">제호 : 코인데스크코리아 </li>
# 						<li class="m-none">발행일 : 2018-02-26</li> -->
# <li class="clear copy-p auto-martop-20 m-top-0">Coindesk Korea™️ is owned and operated by 22nd Century Media Co., subsidiary of Hankyoreh Co., Ltd., in collaboration with Coindesk, Inc., the leading digital news, events and information services company for the crypto asset and blockchain technology.</li>
# <li class="clear copy">C<a class="deco-none" href="https://www.coindeskkorea.com/admin/adminLoginForm.html">o</a>pyright
# 												<a class="deco-none" href="https://www.coindeskkorea.com/member/login.html">©</a>
# 												2020 22nd Century Media. <a href="http://www.coindeskkorea.com/news/articleList.html?view_type=sm" onclick="setCookie('view_pc', 'n', 1);">All</a> rights reserved.</li>
# </ul>
# <a class="ndsoft" href="http://www.ndsoft.co.kr/" target="_blank"><img alt="ND소프트" src="/image/ndsoft.gif"/></a>
# </address>
# <!--// address -->
# </div>
# </div>
# </div>
# </footer>
# <!--// footer -->
# <!--// footer -->
# </div>
# </div>
# <!--// wrap -->
# <!-- back to the top //-->
# <button class="back-to-top for-mobile" id="back-to-top" title="위로" type="button"><i class="s7-angle-up"><span class="show-for-sr">위로</span></i></button>
# <!--// back to the top -->
# <script type="text/javascript">
# <!--
# // back to the top
# $(document).scroll(function(){
# 	var sDocumentHeight = $(document).height() - $(window).height();
# 	if($(document).scrollTop() > 0){
# 		$('#back-to-top').fadeIn();
# 	}else{
# 		$('#back-to-top').fadeOut();
# 	}
# });
#
# $('#back-to-top').click(function(){
# 	$('html, body').animate( {scrollTop:0}, 100);
# });
# //-->
# </script>
# <script>
# // Popup Json
# var ___popup = [];
# bannerpop.popup();
# </script>
# <!-- 구글 애드센스 S -->
# <script src="/adManager/js/lab.js"></script>
# <script>
# jQuery(function($) {
# 	setTimeout(function() {
# 		$LAB
# 		.script("//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js")
# 		.wait(function () {
# 			var adn = jQuery('.adsbygoogle').length;
# 			if (adn > 0) {
# 				for (var i = 0; i < adn; i++) {
# 					(adsbygoogle = window.adsbygoogle || []).push({});
# 				}
# 			}
# 		});
# 	}, 1000);
# });
# </script>
# <!-- 구글 애드센스 E -->
# <link href="/adManager/css/adManager.css" rel="stylesheet"/>
# <script src="/library/isND/" type="text/javascript"></script>
# <script>
# $(document).ready(function(){
# 	// 닫기 버튼 자동 노출
# 	$('.ad-template.ad-close .ad-view').each(function(){
# 		$(this).append('<div class="ad-close-btn"><i class="fa fa-close"></i></div>');
# 	})
#
# 	// 닫기 버튼 클릭 시 이벤트
# 	$('body').on('click', '.ad-close-btn', function(){
# 		$(this).closest('.ad-view').slideUp();
# 	})
#
#
# 	if(____is_nd) {
#
# 				// ND IP만 광고 ID 보이기
# 		$('.ad-template').each(function(){
# 			$(this).append('<div class="ad-code-id">'+$(this).attr('id')+'</div>');
# 		})
#
# 				// 광고 ID 자동 숨김 설정 시
# 		$('.ad-code-id').hide();
#
# 		$('.ad-template').mouseenter(function(){
# 			$(this).find('.ad-code-id').show();
# 		}).mouseleave(function(){
# 			$(this).find('.ad-code-id').hide();
# 		})
#
#
# 			}
#
# 	})
# </script>
# </body>
# </html>

# %% [markdown]
# ### 기사 List 가져오기

# %%
soup.select('div.text-block > div.list-titles > a > strong')
# Out:
# [<strong>FATF, 개발자 포함하는 고위 라운드테이블 꾸린다</strong>,
#  <strong>7/2 아침브리핑: 탈중앙금융·탈중앙거래소 선전, 비트코인 채굴 난이도 외</strong>,
#  <strong>온더, 이더리움 최적화시키는 '튜닝숍'을 꿈꾼다</strong>,
#  <strong>암호화폐 트래블룰, 화이트리스트 방안으로 풀자</strong>,
#  <strong>‘못다 핀 꽃’ 리브라 1년</strong>,
#  <strong>7/1 오후브리핑: 이더리움 수수료 개선안, 삼성SDS</strong>,
#  <strong>삼성SDS, 블록체인·AI 등 혁신기술 체험용 무료 솔루션 공개</strong>,
#  <strong>7/1 아침브리핑: 디지털달러, 이더리움 수수료, 호주 증권거래소 외</strong>,
#  <strong>이더리움 “높은 거래 수수료 낮출 새로운 수수료 모델 고려”</strong>,
#  <strong>6/30 오후브리핑: 특금법 토론회, 러시아 투표 해킹</strong>,
#  <strong>업비트 "암호화폐 거래소도 주민번호 수집 가능해야"</strong>,
#  <strong>'2020년의 절반' 상반기 인기기사 Top 10</strong>,
#  <strong>6/30 아침브리핑: 언스트앤영의 부실 회계감사, 비트코인 익명 개발자들 외</strong>,
#  <strong>러시아 개헌 블록체인 투표에 해킹 시도 확인</strong>,
#  <strong>'채굴기 제조사' 이방, 암호화폐 거래소 설립 추진</strong>,
#  <strong>블록체인의 투명성을 모두 좋아할까?</strong>,
#  <strong>6/29 오후브리핑: 특금법 시행령, 키젠 해킹, ㅇㅇ페이 안전?</strong>,
#  <strong>쏟아지는 OO페이, 간편결제 안전한가?</strong>,
#  <strong>부산 블록체인특구 추가사업자 최종 심의 오른 기업은 누구?</strong>,
#  <strong>크랙·키젠 깔았던 내 컴퓨터, 타인의 채굴기 된다</strong>]

# %%
soup.select('div.text-block > div.list-titles > a > strong')
# Out:
# [<strong>FATF, 개발자 포함하는 고위 라운드테이블 꾸린다</strong>,
#  <strong>7/2 아침브리핑: 탈중앙금융·탈중앙거래소 선전, 비트코인 채굴 난이도 외</strong>,
#  <strong>온더, 이더리움 최적화시키는 '튜닝숍'을 꿈꾼다</strong>,
#  <strong>암호화폐 트래블룰, 화이트리스트 방안으로 풀자</strong>,
#  <strong>‘못다 핀 꽃’ 리브라 1년</strong>,
#  <strong>7/1 오후브리핑: 이더리움 수수료 개선안, 삼성SDS</strong>,
#  <strong>삼성SDS, 블록체인·AI 등 혁신기술 체험용 무료 솔루션 공개</strong>,
#  <strong>7/1 아침브리핑: 디지털달러, 이더리움 수수료, 호주 증권거래소 외</strong>,
#  <strong>이더리움 “높은 거래 수수료 낮출 새로운 수수료 모델 고려”</strong>,
#  <strong>6/30 오후브리핑: 특금법 토론회, 러시아 투표 해킹</strong>,
#  <strong>업비트 "암호화폐 거래소도 주민번호 수집 가능해야"</strong>,
#  <strong>'2020년의 절반' 상반기 인기기사 Top 10</strong>,
#  <strong>6/30 아침브리핑: 언스트앤영의 부실 회계감사, 비트코인 익명 개발자들 외</strong>,
#  <strong>러시아 개헌 블록체인 투표에 해킹 시도 확인</strong>,
#  <strong>'채굴기 제조사' 이방, 암호화폐 거래소 설립 추진</strong>,
#  <strong>블록체인의 투명성을 모두 좋아할까?</strong>,
#  <strong>6/29 오후브리핑: 특금법 시행령, 키젠 해킹, ㅇㅇ페이 안전?</strong>,
#  <strong>쏟아지는 OO페이, 간편결제 안전한가?</strong>,
#  <strong>부산 블록체인특구 추가사업자 최종 심의 오른 기업은 누구?</strong>,
#  <strong>크랙·키젠 깔았던 내 컴퓨터, 타인의 채굴기 된다</strong>]

# %%
soup.select('div.text-block > div.list-titles > a > strong')[0]
# Out:
# <strong>FATF, 개발자 포함하는 고위 라운드테이블 꾸린다</strong>

# %%
subject = soup.select('div.text-block > div.list-titles > a > strong')[0].get_text().strip()
subject
# Out:
# 'FATF, 개발자 포함하는 고위 라운드테이블 꾸린다'

# %% [markdown]
# ### 기사 요약 가져오기

# %%
soup.select('div.text-block > p > a')
# Out:
# [<a class="line-height-4-2x" href="/news/articleView.html?idxno=71169" target="_top">
#  					국제자금세탁방지기구(FATF)는 기술발전 속도를 볼 때 암호화폐 등 가상자산도 자금이동규칙(트래블룰)을 지킬 수 있다고 보고 기존 가이드라인을 유지했다.FATF는 지난 24일 온라인에서 열린 31기 3차 총회에서 "회원국의 법제 도입 및 민간의 트래블룰 이행을 위한 기술개발 등을 비춰 볼 때 민·관 모두 발전이 있었으며, 현 시점에서 추가 개정은 불필요하다고 판단했다"고 밝혔다. 한국 정부에서 FATF 관련 사항을 담당하는 금융위원회 금융정보분석원(FIU) 관계자는 "관련 기술의 진전이 있어서 가상자산도 자금이동규칙을 지킬 수 있다					</a>,
#  <a class="line-height-4-2x" href="/news/articleView.html?idxno=71168" target="_top">
#  					주요 소식탈중앙금융 '농업 혁명'에 탈중앙거래소 거래량도 늘었다탈중앙금융(DeFi) 거래가 급증하면서 탈중앙거래소도 급속히 성장하고 있다. 파라피 캐피털의 벤 포만은 탈중앙 암호화폐 대출 플랫폼 컴파운드(Compound)가 탈중앙 금융 시장을 선도하고 있다고 말했다.“컴파운드는 이른바 새로운 농업 혁명을 촉발했다. 이들 농부는 중앙 금융(CeFi) 거래소 대신 자동화 시스템을 통해 농산물을 거래한다. 물론 이상적인 모습이라고는 볼 수 없다. 그러나 기존 중앙 금융 거래를 이용하던 사람들이 효율성과 수익을 좇아 빠른 속도로 탈중앙금융					</a>,
#  <a class="line-height-4-2x" href="/news/articleView.html?idxno=71167" target="_top">
#  					많은 블록체인 기업들이 '크립토겨울'을 지나며, 로드맵을 이리저리 바꾸는 와중에서도 3년째 한 우물만 파는 블록체인 스타트업이 있다. 온더가 그 주인공이다.온더는 2017년 창업자 정순형 대표가 이더리움 블록체인의 기술 개발을 위해 만든 기업이다. 업계의 불황에도 불구하고 온더는 매년 지치지 않은 성장세를 기록했다. 정 대표는 그 원동력으로 '이더리움의 가능성'에 방점을 찍었다. 그리고 곧 완벽한 결과물을 공개할 계획이라고 강조했다. 온더가 개발 중인 이더리움 확장 솔루션 '토카막 네트워크(Tokamak network)'에 대한 이					</a>,
#  <a class="line-height-4-2x" href="/news/articleView.html?idxno=71166" target="_top">
#  					암호화폐 거래소 등 가상자산사업자(VASP)들이 암호화폐의 송금인과 수취인을 모두 파악하도록 요구하는 국제자금세탁기구(FATF)의 자금이동규칙(travel rule) 준수 요구와 관련해, 실제 소유주 신원 확인이 완료된 지갑끼리의 전송만 허용하는 화이트리스트 방안이 논의되고 있다. 자금세탁 방지 차원에서 규제당국이 국내 거래소 계좌의 암호화폐가 국외 전송을 통제할 필요가 있다는 주장도 제기됐다.법무법인 태평양의 윤주호 변호사는 1일 열린 '특금법(특정금융정보법) 컨퍼런스' 행사에서, "지금의 암호화폐(가상자산) 거래소는 거래소 지갑					</a>,
#  <a class="line-height-4-2x" href="/news/articleView.html?idxno=71164" target="_top">
#  					페이스북이 주도한 암호화폐 프로젝트 ‘리브라’는 애초 약속을 지키지 못했다. 1년 전인 2019년 6월18일 발표된 리브라 ‘백서’는 2020년 상반기 서비스 시작을 기약했지만 실현되지 않았다. 인프라 부족 등 원인으로 은행 계좌가 없는 전세계 금융소외층 17억명을 위해, 나아가 새로운 ‘글로벌 통화’를 위해 블록체인 기반 암호화폐를 만들겠다던 리브라의 꿈은 아직 유보된 상태다. 가장 큰 이유는 각국 규제 당국의 반대였다. 국제 질서는 통화 패권과 맞물려 있었고, 각국 국내 정치에서도 통화 정책은 민감했다. 국적 없는 새로운 통화의					</a>,
#  <a class="line-height-4-2x" href="/news/articleView.html?idxno=71165" target="_top">
#  					이더리움 “높은 거래 수수료 낮출 새로운 수수료 모델 고려”최근 이더리움의 높은 수수료가 문제로 등장하면서 채굴 수수료 방식을 변경하는 '이더리움 개선제안서(EIP) 1559 코드'가 주목받고 있다. 이더리움 이용자들이 네트워크에 정해진 기본료(base fee)를 내고, 채굴자들에게는 팁(tip)을 주는 방식으로 수수료 정책을 바꾸는 게 이 코드의 내용이다. 삼성SDS, 블록체인·AI 등 혁신기술 체험용 무료 솔루션 공개삼성SDS가 1일 고객의 디지털 트랜스포메이션(전환)을 지원하기 위한 클라우드 기반 엔진 체계를 공개하며 무료 체					</a>,
#  <a class="line-height-4-2x" href="/news/articleView.html?idxno=71163" target="_top">
#  					삼성SDS가 1일 고객의 디지털 트랜스포메이션(전환)을 지원하기 위한 클라우드 기반 엔진 체계를 소개하고, 무료 체험 서비스 ‘마이트라이얼’을 공개했다. 삼성SDS에 따르면 디지털 트랜스포메이션 엔진은 크게 네 가지 플랫폼 및 서비스로 구성됐다. 블록체인: 신원인증, 결제, 유통이력 관리 등 분야에 적용 가능한 넥스레저(Nexledger)	인공지능(AI) 및 사물인터넷(IoT): 데이터 수집 및 정제를 위한 사물인터넷 플랫폼 브라이틱스(Brightics) IoT, 수집된 데이터의 분석 및 지능화를 위한 통합 AI 플랫폼 브라이틱스A					</a>,
#  <a class="line-height-4-2x" href="/news/articleView.html?idxno=71162" target="_top">
#  					주요 소식미국 상원 “현금과 결제 수단의 디지털화” 주제로 청문회 개최미국 상원 은행·주택·도시위원회가 “현금과 결제 수단의 디지털화”를 주제로 청문회를 연다. 청문회에는 크리스토퍼 장칼로 전 상품선물거래위원회(CFTC) 위원장, 찰스 카스카릴라 팩소스(Paxos) CEO가 증인으로 출석해 중앙은행이 발행하는 디지털 화폐(CBDC)와 스테이블코인 개발에 관해 증언할 예정이다.국제결제은행(BIS)이 혁신허브센터(Innovation Hub Centre)를 토론토, 스톡홀름, 런던에 추가로 설립한다. 파리와 프랑크푸르트에는 공동 센터를					</a>,
#  <a class="line-height-4-2x" href="/news/articleView.html?idxno=71161" target="_top">
#  					요약:	이더리움(Ethereum) 블록체인의 거래 수요가 늘면서 거래 수수료도 엄청난 수준으로 증가했다.	역동적인 방식으로 가격을 책정하는 신기술의 등장으로 높은 수수료 문제를 해결할 수 있게 됐다.	이더리움 개선제안서(EIP) 1559 코드는 이더리움 이용자들이 네트워크에 정해진 기본료(base fee)를 내고, 채굴자들에게는 팁(tip)을 주는 방식이다.	한 기술 애널리스트는 이를 “모든 블록체인을 통틀어, 네트워크 출시 이후 생긴 변화 중 가장 큰 변화”라고 평가했다. 이더리움 네트워크를 이용하는 비용이 지난 4월 이후 500					</a>,
#  <a class="line-height-4-2x" href="/news/articleView.html?idxno=71159" target="_top">
#  					러시아 개헌 블록체인 투표에 해킹 시도 확인27일(현지시각) 러시아 타스통신에 따르면 러시아 개헌 국민투표에 사용되고 있는 블록체인 투표 시스템에 해킹 시도가 있었던 것으로 확인됐다. 러시아 측은 블록체인의 감시 노드가 해킹 타깃이 됐으나 투표는 방해받지 않고 있다고 밝혔다. 블록체인의 투명성을 모두 좋아할까?블록체인 업계에서는 퍼블릭 블록체인의 투명성을 장점으로 생각한다. 그러나 블록체인에 관심이 없는 일반 소비자들은 코인을 이용한 자신의 거래 내역을 타인이 들여다볼 수 있다는 것에 기분나쁨을 느끼는 경우도 많다. 최근 일부 블록					</a>,
#  <a class="line-height-4-2x" href="/news/articleView.html?idxno=71158" target="_top">
#  					암호화폐 거래소 등 가상자산사업자(VASP)도 금융기관처럼 주민등록번호를 수집할 수 있어야 한다는 주장이 나왔다. 주민등록번호 수집기관은 매우 높은 수준의 보안과 내부통제가 필요해 암호화폐 업계에서도 논란이 될 것으로 보인다.황순호 두나무 대외협력팀장은 30일 국회에서 열린 '가상자산(암호화폐) 거래 투명화를 위한 특금법 시행령 토론회'에서 VASP의 주민등록번호 수집 필요성을 제기했다.발표자로 참가한 황 팀장은 "금융기관과 달리 (암호화폐) 거래소는 현행 법령에 따라 회원의 주민등록번호 수집이 불가능하다"면서 "고객 정보 수집의					</a>,
#  <a class="line-height-4-2x" href="/news/articleView.html?idxno=71151" target="_top">
#  					편집자 주. 2020년 상반기에는 코로나19의 대유행으로 CBDC에 대한 논의가 본격적으로 이뤄졌고, 개정 특금법이 국회를 통과하면서 블록체인 기술과 제도의 만남을 고민하게 했습니다. 암호화폐 유튜버 스펑키의 피습 사건과 성착취 동영상을 유통시킨 'n번방', '박사방' 사건도 암호화폐 업계를 달궜습니다. 코인데스크코리아의 상반기 기사 가운데 가장 많은 조회수를 기록한 기사는 김태원 글로스퍼 대표의 안타까운 소식이었습니다. 올 상반기 코인데스크코리아에서 가장 많은 관심을 받은 기사 10개를 살펴봅니다. 1. 김태원 글로스퍼 대표 사망					</a>,
#  <a class="line-height-4-2x" href="/news/articleView.html?idxno=71149" target="_top">
#  					주요 소식밸런서 풀, 플래시론 공격으로 토큰 6억원어치 도난당해스마트계약의 허점을 이용한 해킹 사건이 또다시 발생했다. 탈중앙 금융 유동성 제공업체 밸런서 풀(Balancer Pool)은 29일 “범인은 스마트 계약의 허점을 악용해 50만달러, 약 6억원어치의 토큰을 빼돌렸다”며, “dYdX에서 플래시론을 통해 WETH 토큰 2300만달러어치를 빌린 뒤 이것을 다양한 투자 등급의 스트라테라(Stratera) 토큰으로 교환하는 수법을 사용했다”고 밝혔다. 지난 2월에는 bZx 거래소가 플래시론 공격을 당한 바 있다. 이런 공격 방식은					</a>,
#  <a class="line-height-4-2x" href="/news/articleView.html?idxno=71148" target="_top">
#  					러시아의 개헌 국민투표에 쓰이고 있는 블록체인 투표 시스템에 해킹 시도가 있었던 것으로 확인됐다.27일(현지시각) 러시아 타스통신에 따르면, 아르템 코스티르코 모스크바 정보기술부 장관은 블록체인의 감시 노드가 타깃이 됐으나 작동에는 이상이 없다고 밝혔다. 코스티르코 장관은 “현재로선 보안 모드가 강화됐으며, 투표는 방해받지 않고 있다”며 “모든 투표는 정확히 전달돼 블록체인에 기록되고 있다”고 말했다.해당 기사는 해커의 공격 의도가 무엇인지, 침입이 얼마나 성공했는지 등에서는 언급하지 않고 있다. 코스티르코는 공격받은 노드는 현재					</a>,
#  <a class="line-height-4-2x" href="/news/articleView.html?idxno=71147" target="_top">
#  					중국의 비트코인 채굴기 제조사 이방(Ebang)이 역외에 암호화폐 거래소 설립을 추진하고 있다. 이를 통해 2022년까지 매출을 2배 증대시키겠다는 계산이다.중국 항저우에 기반한 이방의 재무총괄(CFO) 천레이(陈磊)는 29일(현지시각) 블룸버그BNN과의 인터뷰에서, 중국 이외의 지역에서 규제에 부합하는 암호화폐 거래소를 설립할 계획이라고 밝혔다. 중국 정부는 국내 암호화폐 거래소 운영을 강하게 금지하고 있다.이방으로서는 지속적인 수입원 확보를 위해 현금화 통로를 확보해야 할 수요가 있는 게 사실이다. 그러나 그 밖에 이방의 거래소					</a>,
#  <a class="line-height-4-2x" href="/news/articleView.html?idxno=71146" target="_top">
#  					제 주변엔 각종 할인혜택을 찾아내 최저가로 결제하는 데 탁월한 능력을 보여주는 지인이 한 명 있습니다. 문화상품권부터 머지포인트까지 섭렵한 그는 일찌감치 티몬 등에서 '차이(Chai)'로 결제하면서 많은 할인을 받고 있었습니다. 그러던 그가 최근 차이스캔(Chaiscan) 이미지와 함께 "이거 문제가 많아 보이는데요?"라는 메시지를 보냈습니다. 차이스캔은 테라 블록체인에 모두 기록된 차이 결제내역을 보기 쉽게 시각화하고, 검색기능도 제공하는 서비스입니다. 그가 지적한 건 검색만으로도 자신의 지갑주소를 찾을 수 있었고, 결제내역이 모					</a>,
#  <a class="line-height-4-2x" href="/news/articleView.html?idxno=71145" target="_top">
#  					크랙·키젠 깔았던 내 컴퓨터, 타인의 채굴기 된다안랩이 상용 소프트웨어 블법 사용자를 노리는 암호화폐 채굴형 악성코드를 발견했다고 밝혔다. 이 악성코드 공격자는 우선 한글로 피싱 사이트를 만들고 '크랙(crack)'이나 '키젠(keygen)'을 검색하면 해당 사이트가 노출되게끔 설정한다. 사용자가 이 사이트에서 파일을 다운로드 받아 설치하면 모네로(Monero)를 채굴하는 악성코드가 PC에 설치된다. 암호화폐 수용한 싱가포르 규제도 빨라싱가포르는 선진화된 금융인프라와 개방적인 규제, 간단한 조세체계와 낮은 법인세 때문에 암호화폐 업					</a>,
#  <a class="line-height-4-2x" href="/news/articleView.html?idxno=71143" target="_top">
#  					편집자 주. 블록체인 기술이 실생활에 스며들어 다양한 IT 기술과 결합하고 있습니다. 새로 시작하는 보안업체 펜타시큐리티의 연재 기고 '쉽게 만나는 IT'는 이같은 현실을 풀어서 설명해 드립니다.공인인증서, 보안카드 등 번거로운 과정 없이 결제가 가능한 간편 결제 시장의 규모가 커지고 있습니다. 한국은행의 발표에 따르면 2019년 간편결제 일평균 이용금액은 약 1,600억 원, 사용 건수는 530만 건을 돌파했습니다. 이는 그 전년도 대비 2배 이상 증가한 규모입니다. 이런 추세에 맞춰 사용자의 편의성을 높일 수 있는 간편결제 서비					</a>,
#  <a class="line-height-4-2x" href="/news/articleView.html?idxno=71144" target="_top">
#  					부산 블록체인 규제자유특구에서 진행될 2차 실증 사업이 3개로 추려졌다.중소벤처기업부는 29일 개최한 제3차 규제자유특구 규제특례 등 심의위원회 회의에서, 지난해 7월 지정된 부산 블록체인 특구와 대전 바이오메디컬 특구에 실증 사업을 추가하는 계획을 심의했다. 중기부에 따르면 이날 심의를 거친 특구 계획의 최종 지정 여부는 오는 7월6일 국무총리 주재로 열리는 특구위원회에서 결정될 예정이다. 부산 블록체인 규제자유특구 계획엔 3가지 실증 사업이 추가됐다. 세종텔레콤 컨소시엄이 제안한 블록체인 기반 부동산 집합투자 서비스, 글로스퍼					</a>,
#  <a class="line-height-4-2x" href="/news/articleView.html?idxno=71142" target="_top">
#  					안랩이 상용 소프트웨어(SW) 불법 사용자를 노려 유포되는 '암호화폐 채굴형 악성코드'를 발견했다며 사용자의 주의를 당부했다.29일 안랩에 따르면, 공격자는 먼저 한글로 작성된 피싱 사이트를 제작했다. 사용자가 구글 검색창에 '크랙(crack)'이나 '키젠(Keygen)' 등의 상용 소프트웨어 불법사용을 위한 키워드를 입력하면 검색 결과 페이지에 해당 피싱 사이트가 노출된다. 크랙은 SW의 보호장치를 제거해 무단복제나 불법 다운로드를 허용하는 프로그램이며, 키젠은 SW의 인증키를 생성하는 프로그램이다.사용자가 검색창에 노출된 피싱					</a>]

# %%
soup.select('div.text-block > p > a')[0].text.strip()
# Out:
# '국제자금세탁방지기구(FATF)는 기술발전 속도를 볼 때 암호화폐 등 가상자산도 자금이동규칙(트래블룰)을 지킬 수 있다고 보고 기존 가이드라인을 유지했다.FATF는 지난 24일 온라인에서 열린 31기 3차 총회에서 "회원국의 법제 도입 및 민간의 트래블룰 이행을 위한 기술개발 등을 비춰 볼 때 민·관 모두 발전이 있었으며, 현 시점에서 추가 개정은 불필요하다고 판단했다"고 밝혔다. 한국 정부에서 FATF 관련 사항을 담당하는 금융위원회 금융정보분석원(FIU) 관계자는 "관련 기술의 진전이 있어서 가상자산도 자금이동규칙을 지킬 수 있다'

# %%
summary = soup.select('div.text-block > p > a')[0].text.strip()
summary
# Out:
# '국제자금세탁방지기구(FATF)는 기술발전 속도를 볼 때 암호화폐 등 가상자산도 자금이동규칙(트래블룰)을 지킬 수 있다고 보고 기존 가이드라인을 유지했다.FATF는 지난 24일 온라인에서 열린 31기 3차 총회에서 "회원국의 법제 도입 및 민간의 트래블룰 이행을 위한 기술개발 등을 비춰 볼 때 민·관 모두 발전이 있었으며, 현 시점에서 추가 개정은 불필요하다고 판단했다"고 밝혔다. 한국 정부에서 FATF 관련 사항을 담당하는 금융위원회 금융정보분석원(FIU) 관계자는 "관련 기술의 진전이 있어서 가상자산도 자금이동규칙을 지킬 수 있다'

# %% [markdown]
# ### URL 가져오기

# %%
soup.select('div.text-block > p > a')[0]
# Out:
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71169" target="_top">
# 					국제자금세탁방지기구(FATF)는 기술발전 속도를 볼 때 암호화폐 등 가상자산도 자금이동규칙(트래블룰)을 지킬 수 있다고 보고 기존 가이드라인을 유지했다.FATF는 지난 24일 온라인에서 열린 31기 3차 총회에서 "회원국의 법제 도입 및 민간의 트래블룰 이행을 위한 기술개발 등을 비춰 볼 때 민·관 모두 발전이 있었으며, 현 시점에서 추가 개정은 불필요하다고 판단했다"고 밝혔다. 한국 정부에서 FATF 관련 사항을 담당하는 금융위원회 금융정보분석원(FIU) 관계자는 "관련 기술의 진전이 있어서 가상자산도 자금이동규칙을 지킬 수 있다					</a>

# %%
soup.select('div.text-block > p > a')[0].attrs['href']
# Out:
# '/news/articleView.html?idxno=71169'

# %%
uri = soup.select('div.text-block > p > a')[0].attrs['href']
uri
# Out:
# '/news/articleView.html?idxno=71169'

# %% [markdown]
# ### Author 가져오기

# %%
soup.select('div.text-block > div.list-dated > strong')
# Out:
# [<strong class="list-name">김병철</strong>,
#  <strong class="list-name">Daniel Kuhn</strong>,
#  <strong class="list-name">박근모 기자</strong>,
#  <strong class="list-name">김동환 기자</strong>,
#  <strong class="list-name">김외현</strong>,
#  <strong class="list-name">김동환 기자</strong>,
#  <strong class="list-name">정인선 기자</strong>,
#  <strong class="list-name">Daniel Kuhn</strong>,
#  <strong class="list-name">William Foxley</strong>,
#  <strong class="list-name">김동환 기자</strong>,
#  <strong class="list-name">김병철</strong>,
#  <strong class="list-name">박근모 기자</strong>,
#  <strong class="list-name">Daniel Kuhn</strong>,
#  <strong class="list-name">Daniel Palmer</strong>,
#  <strong class="list-name">Paddy Baker</strong>,
#  <strong class="list-name">김병철</strong>,
#  <strong class="list-name">김동환 기자</strong>,
#  <strong class="list-name">펜타시큐리티</strong>,
#  <strong class="list-name">정인선 기자</strong>,
#  <strong class="list-name">박근모 기자</strong>]

# %%
soup.select('div.text-block > div.list-dated > strong')[0].text.strip()
# Out:
# '김병철'

# %% [markdown]
# ### result에 Data 담기

# %%
item_number = len(soup.select('div.text-block > div.list-titles > a > strong'))

# %%
result = []
for i in range(0, item_number):
    subject = soup.select('div.text-block > div.list-titles > a > strong')[i].get_text().strip()
    summary = soup.select('div.text-block > p > a')[i].text.strip()
    url = base_url + soup.select('div.text-block > p > a')[i].attrs['href']
    author = soup.select('div.text-block > div.list-dated > strong')[i].text.strip()

    article = {
        'subject': subject,
        'summary': summary,
        'url': url,
        'author': author
    }
    result.append(article)

# %%
result
# Out:
# [{'subject': 'FATF, 개발자 포함하는 고위 라운드테이블 꾸린다',
#   'summary': '국제자금세탁방지기구(FATF)는 기술발전 속도를 볼 때 암호화폐 등 가상자산도 자금이동규칙(트래블룰)을 지킬 수 있다고 보고 기존 가이드라인을 유지했다.FATF는 지난 24일 온라인에서 열린 31기 3차 총회에서 "회원국의 법제 도입 및 민간의 트래블룰 이행을 위한 기술개발 등을 비춰 볼 때 민·관 모두 발전이 있었으며, 현 시점에서 추가 개정은 불필요하다고 판단했다"고 밝혔다. 한국 정부에서 FATF 관련 사항을 담당하는 금융위원회 금융정보분석원(FIU) 관계자는 "관련 기술의 진전이 있어서 가상자산도 자금이동규칙을 지킬 수 있다',
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71169',
#   'author': '김병철'},
#  {'subject': '7/2 아침브리핑: 탈중앙금융·탈중앙거래소 선전, 비트코인 채굴 난이도 외',
#   'summary': "주요 소식탈중앙금융 '농업 혁명'에 탈중앙거래소 거래량도 늘었다탈중앙금융(DeFi) 거래가 급증하면서 탈중앙거래소도 급속히 성장하고 있다. 파라피 캐피털의 벤 포만은 탈중앙 암호화폐 대출 플랫폼 컴파운드(Compound)가 탈중앙 금융 시장을 선도하고 있다고 말했다.“컴파운드는 이른바 새로운 농업 혁명을 촉발했다. 이들 농부는 중앙 금융(CeFi) 거래소 대신 자동화 시스템을 통해 농산물을 거래한다. 물론 이상적인 모습이라고는 볼 수 없다. 그러나 기존 중앙 금융 거래를 이용하던 사람들이 효율성과 수익을 좇아 빠른 속도로 탈중앙금융",
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71168',
#   'author': 'Daniel Kuhn'},
#  {'subject': "온더, 이더리움 최적화시키는 '튜닝숍'을 꿈꾼다",
#   'summary': "많은 블록체인 기업들이 '크립토겨울'을 지나며, 로드맵을 이리저리 바꾸는 와중에서도 3년째 한 우물만 파는 블록체인 스타트업이 있다. 온더가 그 주인공이다.온더는 2017년 창업자 정순형 대표가 이더리움 블록체인의 기술 개발을 위해 만든 기업이다. 업계의 불황에도 불구하고 온더는 매년 지치지 않은 성장세를 기록했다. 정 대표는 그 원동력으로 '이더리움의 가능성'에 방점을 찍었다. 그리고 곧 완벽한 결과물을 공개할 계획이라고 강조했다. 온더가 개발 중인 이더리움 확장 솔루션 '토카막 네트워크(Tokamak network)'에 대한 이",
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71167',
#   'author': '박근모 기자'},
#  {'subject': '암호화폐 트래블룰, 화이트리스트 방안으로 풀자',
#   'summary': '암호화폐 거래소 등 가상자산사업자(VASP)들이 암호화폐의 송금인과 수취인을 모두 파악하도록 요구하는 국제자금세탁기구(FATF)의 자금이동규칙(travel rule) 준수 요구와 관련해, 실제 소유주 신원 확인이 완료된 지갑끼리의 전송만 허용하는 화이트리스트 방안이 논의되고 있다. 자금세탁 방지 차원에서 규제당국이 국내 거래소 계좌의 암호화폐가 국외 전송을 통제할 필요가 있다는 주장도 제기됐다.법무법인 태평양의 윤주호 변호사는 1일 열린 \'특금법(특정금융정보법) 컨퍼런스\' 행사에서, "지금의 암호화폐(가상자산) 거래소는 거래소 지갑',
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71166',
#   'author': '김동환 기자'},
#  {'subject': '‘못다 핀 꽃’ 리브라 1년',
#   'summary': '페이스북이 주도한 암호화폐 프로젝트 ‘리브라’는 애초 약속을 지키지 못했다. 1년 전인 2019년 6월18일 발표된 리브라 ‘백서’는 2020년 상반기 서비스 시작을 기약했지만 실현되지 않았다. 인프라 부족 등 원인으로 은행 계좌가 없는 전세계 금융소외층 17억명을 위해, 나아가 새로운 ‘글로벌 통화’를 위해 블록체인 기반 암호화폐를 만들겠다던 리브라의 꿈은 아직 유보된 상태다. 가장 큰 이유는 각국 규제 당국의 반대였다. 국제 질서는 통화 패권과 맞물려 있었고, 각국 국내 정치에서도 통화 정책은 민감했다. 국적 없는 새로운 통화의',
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71164',
#   'author': '김외현'},
#  {'subject': '7/1 오후브리핑: 이더리움 수수료 개선안, 삼성SDS',
#   'summary': "이더리움 “높은 거래 수수료 낮출 새로운 수수료 모델 고려”최근 이더리움의 높은 수수료가 문제로 등장하면서 채굴 수수료 방식을 변경하는 '이더리움 개선제안서(EIP) 1559 코드'가 주목받고 있다. 이더리움 이용자들이 네트워크에 정해진 기본료(base fee)를 내고, 채굴자들에게는 팁(tip)을 주는 방식으로 수수료 정책을 바꾸는 게 이 코드의 내용이다. 삼성SDS, 블록체인·AI 등 혁신기술 체험용 무료 솔루션 공개삼성SDS가 1일 고객의 디지털 트랜스포메이션(전환)을 지원하기 위한 클라우드 기반 엔진 체계를 공개하며 무료 체",
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71165',
#   'author': '김동환 기자'},
#  {'subject': '삼성SDS, 블록체인·AI 등 혁신기술 체험용 무료 솔루션 공개',
#   'summary': '삼성SDS가 1일 고객의 디지털 트랜스포메이션(전환)을 지원하기 위한 클라우드 기반 엔진 체계를 소개하고, 무료 체험 서비스 ‘마이트라이얼’을 공개했다. 삼성SDS에 따르면 디지털 트랜스포메이션 엔진은 크게 네 가지 플랫폼 및 서비스로 구성됐다. 블록체인: 신원인증, 결제, 유통이력 관리 등 분야에 적용 가능한 넥스레저(Nexledger)\t인공지능(AI) 및 사물인터넷(IoT): 데이터 수집 및 정제를 위한 사물인터넷 플랫폼 브라이틱스(Brightics) IoT, 수집된 데이터의 분석 및 지능화를 위한 통합 AI 플랫폼 브라이틱스A',
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71163',
#   'author': '정인선 기자'},
#  {'subject': '7/1 아침브리핑: 디지털달러, 이더리움 수수료, 호주 증권거래소 외',
#   'summary': '주요 소식미국 상원 “현금과 결제 수단의 디지털화” 주제로 청문회 개최미국 상원 은행·주택·도시위원회가 “현금과 결제 수단의 디지털화”를 주제로 청문회를 연다. 청문회에는 크리스토퍼 장칼로 전 상품선물거래위원회(CFTC) 위원장, 찰스 카스카릴라 팩소스(Paxos) CEO가 증인으로 출석해 중앙은행이 발행하는 디지털 화폐(CBDC)와 스테이블코인 개발에 관해 증언할 예정이다.국제결제은행(BIS)이 혁신허브센터(Innovation Hub Centre)를 토론토, 스톡홀름, 런던에 추가로 설립한다. 파리와 프랑크푸르트에는 공동 센터를',
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71162',
#   'author': 'Daniel Kuhn'},
#  {'subject': '이더리움 “높은 거래 수수료 낮출 새로운 수수료 모델 고려”',
#   'summary': '요약:\t이더리움(Ethereum) 블록체인의 거래 수요가 늘면서 거래 수수료도 엄청난 수준으로 증가했다.\t역동적인 방식으로 가격을 책정하는 신기술의 등장으로 높은 수수료 문제를 해결할 수 있게 됐다.\t이더리움 개선제안서(EIP) 1559 코드는 이더리움 이용자들이 네트워크에 정해진 기본료(base fee)를 내고, 채굴자들에게는 팁(tip)을 주는 방식이다.\t한 기술 애널리스트는 이를 “모든 블록체인을 통틀어, 네트워크 출시 이후 생긴 변화 중 가장 큰 변화”라고 평가했다. 이더리움 네트워크를 이용하는 비용이 지난 4월 이후 500',
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71161',
#   'author': 'William Foxley'},
#  {'subject': '6/30 오후브리핑: 특금법 토론회, 러시아 투표 해킹',
#   'summary': '러시아 개헌 블록체인 투표에 해킹 시도 확인27일(현지시각) 러시아 타스통신에 따르면 러시아 개헌 국민투표에 사용되고 있는 블록체인 투표 시스템에 해킹 시도가 있었던 것으로 확인됐다. 러시아 측은 블록체인의 감시 노드가 해킹 타깃이 됐으나 투표는 방해받지 않고 있다고 밝혔다. 블록체인의 투명성을 모두 좋아할까?블록체인 업계에서는 퍼블릭 블록체인의 투명성을 장점으로 생각한다. 그러나 블록체인에 관심이 없는 일반 소비자들은 코인을 이용한 자신의 거래 내역을 타인이 들여다볼 수 있다는 것에 기분나쁨을 느끼는 경우도 많다. 최근 일부 블록',
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71159',
#   'author': '김동환 기자'},
#  {'subject': '업비트 "암호화폐 거래소도 주민번호 수집 가능해야"',
#   'summary': '암호화폐 거래소 등 가상자산사업자(VASP)도 금융기관처럼 주민등록번호를 수집할 수 있어야 한다는 주장이 나왔다. 주민등록번호 수집기관은 매우 높은 수준의 보안과 내부통제가 필요해 암호화폐 업계에서도 논란이 될 것으로 보인다.황순호 두나무 대외협력팀장은 30일 국회에서 열린 \'가상자산(암호화폐) 거래 투명화를 위한 특금법 시행령 토론회\'에서 VASP의 주민등록번호 수집 필요성을 제기했다.발표자로 참가한 황 팀장은 "금융기관과 달리 (암호화폐) 거래소는 현행 법령에 따라 회원의 주민등록번호 수집이 불가능하다"면서 "고객 정보 수집의',
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71158',
#   'author': '김병철'},
#  {'subject': "'2020년의 절반' 상반기 인기기사 Top 10",
#   'summary': "편집자 주. 2020년 상반기에는 코로나19의 대유행으로 CBDC에 대한 논의가 본격적으로 이뤄졌고, 개정 특금법이 국회를 통과하면서 블록체인 기술과 제도의 만남을 고민하게 했습니다. 암호화폐 유튜버 스펑키의 피습 사건과 성착취 동영상을 유통시킨 'n번방', '박사방' 사건도 암호화폐 업계를 달궜습니다. 코인데스크코리아의 상반기 기사 가운데 가장 많은 조회수를 기록한 기사는 김태원 글로스퍼 대표의 안타까운 소식이었습니다. 올 상반기 코인데스크코리아에서 가장 많은 관심을 받은 기사 10개를 살펴봅니다. 1. 김태원 글로스퍼 대표 사망",
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71151',
#   'author': '박근모 기자'},
#  {'subject': '6/30 아침브리핑: 언스트앤영의 부실 회계감사, 비트코인 익명 개발자들 외',
#   'summary': '주요 소식밸런서 풀, 플래시론 공격으로 토큰 6억원어치 도난당해스마트계약의 허점을 이용한 해킹 사건이 또다시 발생했다. 탈중앙 금융 유동성 제공업체 밸런서 풀(Balancer Pool)은 29일 “범인은 스마트 계약의 허점을 악용해 50만달러, 약 6억원어치의 토큰을 빼돌렸다”며, “dYdX에서 플래시론을 통해 WETH 토큰 2300만달러어치를 빌린 뒤 이것을 다양한 투자 등급의 스트라테라(Stratera) 토큰으로 교환하는 수법을 사용했다”고 밝혔다. 지난 2월에는 bZx 거래소가 플래시론 공격을 당한 바 있다. 이런 공격 방식은',
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71149',
#   'author': 'Daniel Kuhn'},
#  {'subject': '러시아 개헌 블록체인 투표에 해킹 시도 확인',
#   'summary': '러시아의 개헌 국민투표에 쓰이고 있는 블록체인 투표 시스템에 해킹 시도가 있었던 것으로 확인됐다.27일(현지시각) 러시아 타스통신에 따르면, 아르템 코스티르코 모스크바 정보기술부 장관은 블록체인의 감시 노드가 타깃이 됐으나 작동에는 이상이 없다고 밝혔다. 코스티르코 장관은 “현재로선 보안 모드가 강화됐으며, 투표는 방해받지 않고 있다”며 “모든 투표는 정확히 전달돼 블록체인에 기록되고 있다”고 말했다.해당 기사는 해커의 공격 의도가 무엇인지, 침입이 얼마나 성공했는지 등에서는 언급하지 않고 있다. 코스티르코는 공격받은 노드는 현재',
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71148',
#   'author': 'Daniel Palmer'},
#  {'subject': "'채굴기 제조사' 이방, 암호화폐 거래소 설립 추진",
#   'summary': '중국의 비트코인 채굴기 제조사 이방(Ebang)이 역외에 암호화폐 거래소 설립을 추진하고 있다. 이를 통해 2022년까지 매출을 2배 증대시키겠다는 계산이다.중국 항저우에 기반한 이방의 재무총괄(CFO) 천레이(陈磊)는 29일(현지시각) 블룸버그BNN과의 인터뷰에서, 중국 이외의 지역에서 규제에 부합하는 암호화폐 거래소를 설립할 계획이라고 밝혔다. 중국 정부는 국내 암호화폐 거래소 운영을 강하게 금지하고 있다.이방으로서는 지속적인 수입원 확보를 위해 현금화 통로를 확보해야 할 수요가 있는 게 사실이다. 그러나 그 밖에 이방의 거래소',
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71147',
#   'author': 'Paddy Baker'},
#  {'subject': '블록체인의 투명성을 모두 좋아할까?',
#   'summary': '제 주변엔 각종 할인혜택을 찾아내 최저가로 결제하는 데 탁월한 능력을 보여주는 지인이 한 명 있습니다. 문화상품권부터 머지포인트까지 섭렵한 그는 일찌감치 티몬 등에서 \'차이(Chai)\'로 결제하면서 많은 할인을 받고 있었습니다. 그러던 그가 최근 차이스캔(Chaiscan) 이미지와 함께 "이거 문제가 많아 보이는데요?"라는 메시지를 보냈습니다. 차이스캔은 테라 블록체인에 모두 기록된 차이 결제내역을 보기 쉽게 시각화하고, 검색기능도 제공하는 서비스입니다. 그가 지적한 건 검색만으로도 자신의 지갑주소를 찾을 수 있었고, 결제내역이 모',
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71146',
#   'author': '김병철'},
#  {'subject': '6/29 오후브리핑: 특금법 시행령, 키젠 해킹, ㅇㅇ페이 안전?',
#   'summary': "크랙·키젠 깔았던 내 컴퓨터, 타인의 채굴기 된다안랩이 상용 소프트웨어 블법 사용자를 노리는 암호화폐 채굴형 악성코드를 발견했다고 밝혔다. 이 악성코드 공격자는 우선 한글로 피싱 사이트를 만들고 '크랙(crack)'이나 '키젠(keygen)'을 검색하면 해당 사이트가 노출되게끔 설정한다. 사용자가 이 사이트에서 파일을 다운로드 받아 설치하면 모네로(Monero)를 채굴하는 악성코드가 PC에 설치된다. 암호화폐 수용한 싱가포르 규제도 빨라싱가포르는 선진화된 금융인프라와 개방적인 규제, 간단한 조세체계와 낮은 법인세 때문에 암호화폐 업",
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71145',
#   'author': '김동환 기자'},
#  {'subject': '쏟아지는 OO페이, 간편결제 안전한가?',
#   'summary': "편집자 주. 블록체인 기술이 실생활에 스며들어 다양한 IT 기술과 결합하고 있습니다. 새로 시작하는 보안업체 펜타시큐리티의 연재 기고 '쉽게 만나는 IT'는 이같은 현실을 풀어서 설명해 드립니다.공인인증서, 보안카드 등 번거로운 과정 없이 결제가 가능한 간편 결제 시장의 규모가 커지고 있습니다. 한국은행의 발표에 따르면 2019년 간편결제 일평균 이용금액은 약 1,600억 원, 사용 건수는 530만 건을 돌파했습니다. 이는 그 전년도 대비 2배 이상 증가한 규모입니다. 이런 추세에 맞춰 사용자의 편의성을 높일 수 있는 간편결제 서비",
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71143',
#   'author': '펜타시큐리티'},
#  {'subject': '부산 블록체인특구 추가사업자 최종 심의 오른 기업은 누구?',
#   'summary': '부산 블록체인 규제자유특구에서 진행될 2차 실증 사업이 3개로 추려졌다.중소벤처기업부는 29일 개최한 제3차 규제자유특구 규제특례 등 심의위원회 회의에서, 지난해 7월 지정된 부산 블록체인 특구와 대전 바이오메디컬 특구에 실증 사업을 추가하는 계획을 심의했다. 중기부에 따르면 이날 심의를 거친 특구 계획의 최종 지정 여부는 오는 7월6일 국무총리 주재로 열리는 특구위원회에서 결정될 예정이다. 부산 블록체인 규제자유특구 계획엔 3가지 실증 사업이 추가됐다. 세종텔레콤 컨소시엄이 제안한 블록체인 기반 부동산 집합투자 서비스, 글로스퍼',
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71144',
#   'author': '정인선 기자'},
#  {'subject': '크랙·키젠 깔았던 내 컴퓨터, 타인의 채굴기 된다',
#   'summary': "안랩이 상용 소프트웨어(SW) 불법 사용자를 노려 유포되는 '암호화폐 채굴형 악성코드'를 발견했다며 사용자의 주의를 당부했다.29일 안랩에 따르면, 공격자는 먼저 한글로 작성된 피싱 사이트를 제작했다. 사용자가 구글 검색창에 '크랙(crack)'이나 '키젠(Keygen)' 등의 상용 소프트웨어 불법사용을 위한 키워드를 입력하면 검색 결과 페이지에 해당 피싱 사이트가 노출된다. 크랙은 SW의 보호장치를 제거해 무단복제나 불법 다운로드를 허용하는 프로그램이며, 키젠은 SW의 인증키를 생성하는 프로그램이다.사용자가 검색창에 노출된 피싱",
#   'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71142',
#   'author': '박근모 기자'}]

# %%
result[0]
# Out:
# {'subject': 'FATF, 개발자 포함하는 고위 라운드테이블 꾸린다',
#  'summary': '국제자금세탁방지기구(FATF)는 기술발전 속도를 볼 때 암호화폐 등 가상자산도 자금이동규칙(트래블룰)을 지킬 수 있다고 보고 기존 가이드라인을 유지했다.FATF는 지난 24일 온라인에서 열린 31기 3차 총회에서 "회원국의 법제 도입 및 민간의 트래블룰 이행을 위한 기술개발 등을 비춰 볼 때 민·관 모두 발전이 있었으며, 현 시점에서 추가 개정은 불필요하다고 판단했다"고 밝혔다. 한국 정부에서 FATF 관련 사항을 담당하는 금융위원회 금융정보분석원(FIU) 관계자는 "관련 기술의 진전이 있어서 가상자산도 자금이동규칙을 지킬 수 있다',
#  'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71169',
#  'author': '김병철'}

# %%
import pandas as pd

# %%
df = pd.DataFrame(result)
df
# Out:
#                                        subject  \
# 0                 FATF, 개발자 포함하는 고위 라운드테이블 꾸린다
# 1    7/2 아침브리핑: 탈중앙금융·탈중앙거래소 선전, 비트코인 채굴 난이도 외
# 2                   온더, 이더리움 최적화시키는 '튜닝숍'을 꿈꾼다
# 3                    암호화폐 트래블룰, 화이트리스트 방안으로 풀자
# 4                              ‘못다 핀 꽃’ 리브라 1년
# 5               7/1 오후브리핑: 이더리움 수수료 개선안, 삼성SDS
# 6          삼성SDS, 블록체인·AI 등 혁신기술 체험용 무료 솔루션 공개
# 7       7/1 아침브리핑: 디지털달러, 이더리움 수수료, 호주 증권거래소 외
# 8            이더리움 “높은 거래 수수료 낮출 새로운 수수료 모델 고려”
# 9               6/30 오후브리핑: 특금법 토론회, 러시아 투표 해킹
# 10                업비트 "암호화폐 거래소도 주민번호 수집 가능해야"
# 11                 '2020년의 절반' 상반기 인기기사 Top 10
# 12  6/30 아침브리핑: 언스트앤영의 부실 회계감사, 비트코인 익명 개발자들 외
# 13                    러시아 개헌 블록체인 투표에 해킹 시도 확인
# 14                '채굴기 제조사' 이방, 암호화폐 거래소 설립 추진
# 15                         블록체인의 투명성을 모두 좋아할까?
# 16        6/29 오후브리핑: 특금법 시행령, 키젠 해킹, ㅇㅇ페이 안전?
# 17                       쏟아지는 OO페이, 간편결제 안전한가?
# 18            부산 블록체인특구 추가사업자 최종 심의 오른 기업은 누구?
# 19                 크랙·키젠 깔았던 내 컴퓨터, 타인의 채굴기 된다
#
#                                               summary  \
# 0   국제자금세탁방지기구(FATF)는 기술발전 속도를 볼 때 암호화폐 등 가상자산도 자금...
# 1   주요 소식탈중앙금융 '농업 혁명'에 탈중앙거래소 거래량도 늘었다탈중앙금융(DeFi)...
# 2   많은 블록체인 기업들이 '크립토겨울'을 지나며, 로드맵을 이리저리 바꾸는 와중에서도...
# 3   암호화폐 거래소 등 가상자산사업자(VASP)들이 암호화폐의 송금인과 수취인을 모두 ...
# 4   페이스북이 주도한 암호화폐 프로젝트 ‘리브라’는 애초 약속을 지키지 못했다. 1년 ...
# 5   이더리움 “높은 거래 수수료 낮출 새로운 수수료 모델 고려”최근 이더리움의 높은 수...
# 6   삼성SDS가 1일 고객의 디지털 트랜스포메이션(전환)을 지원하기 위한 클라우드 기반...
# 7   주요 소식미국 상원 “현금과 결제 수단의 디지털화” 주제로 청문회 개최미국 상원 은...
# 8   요약:\t이더리움(Ethereum) 블록체인의 거래 수요가 늘면서 거래 수수료도 엄...
# 9   러시아 개헌 블록체인 투표에 해킹 시도 확인27일(현지시각) 러시아 타스통신에 따르...
# 10  암호화폐 거래소 등 가상자산사업자(VASP)도 금융기관처럼 주민등록번호를 수집할 수...
# 11  편집자 주. 2020년 상반기에는 코로나19의 대유행으로 CBDC에 대한 논의가 본...
# 12  주요 소식밸런서 풀, 플래시론 공격으로 토큰 6억원어치 도난당해스마트계약의 허점을 ...
# 13  러시아의 개헌 국민투표에 쓰이고 있는 블록체인 투표 시스템에 해킹 시도가 있었던 것...
# 14  중국의 비트코인 채굴기 제조사 이방(Ebang)이 역외에 암호화폐 거래소 설립을 추...
# 15  제 주변엔 각종 할인혜택을 찾아내 최저가로 결제하는 데 탁월한 능력을 보여주는 지인...
# 16  크랙·키젠 깔았던 내 컴퓨터, 타인의 채굴기 된다안랩이 상용 소프트웨어 블법 사용자...
# 17  편집자 주. 블록체인 기술이 실생활에 스며들어 다양한 IT 기술과 결합하고 있습니다...
# 18  부산 블록체인 규제자유특구에서 진행될 2차 실증 사업이 3개로 추려졌다.중소벤처기업...
# 19  안랩이 상용 소프트웨어(SW) 불법 사용자를 노려 유포되는 '암호화폐 채굴형 악성코...
#
#                                                   url          author
# 0   http://www.coindeskkorea.com/news/articleView....             김병철
# 1   http://www.coindeskkorea.com/news/articleView....     Daniel Kuhn
# 2   http://www.coindeskkorea.com/news/articleView....          박근모 기자
# 3   http://www.coindeskkorea.com/news/articleView....          김동환 기자
# 4   http://www.coindeskkorea.com/news/articleView....             김외현
# 5   http://www.coindeskkorea.com/news/articleView....          김동환 기자
# 6   http://www.coindeskkorea.com/news/articleView....          정인선 기자
# 7   http://www.coindeskkorea.com/news/articleView....     Daniel Kuhn
# 8   http://www.coindeskkorea.com/news/articleView....  William Foxley
# 9   http://www.coindeskkorea.com/news/articleView....          김동환 기자
# 10  http://www.coindeskkorea.com/news/articleView....             김병철
# 11  http://www.coindeskkorea.com/news/articleView....          박근모 기자
# 12  http://www.coindeskkorea.com/news/articleView....     Daniel Kuhn
# 13  http://www.coindeskkorea.com/news/articleView....   Daniel Palmer
# 14  http://www.coindeskkorea.com/news/articleView....     Paddy Baker
# 15  http://www.coindeskkorea.com/news/articleView....             김병철
# 16  http://www.coindeskkorea.com/news/articleView....          김동환 기자
# 17  http://www.coindeskkorea.com/news/articleView....          펜타시큐리티
# 18  http://www.coindeskkorea.com/news/articleView....          정인선 기자
# 19  http://www.coindeskkorea.com/news/articleView....          박근모 기자

# %% [markdown]
# ### 2페이지 크롤링

# %%
base_url
# Out:
# 'http://www.coindeskkorea.com'

# %%
uri = '/news/articleList.html?page=2&total=4864&box_idxno=&view_type=sm'

# %%
url = base_url + uri
url
# Out:
# 'http://www.coindeskkorea.com/news/articleList.html?page=2&total=4864&box_idxno=&view_type=sm'

# %%
response = session.get(url)
response
# Out:
# <Response [200]>

# %%
html = response.text
html
# Out:
# '<!doctype html>\n<html class="no-js" lang="ko" dir="ltr">\n<head>\n<meta charset="utf-8">\n<meta http-equiv="x-ua-compatible" content="ie=edge">\n<meta name="viewport" content="width=device-width, initial-scale=1.0">\n<meta name="theme-color" content="#f8c400">\n<!-- 메타태그정보 //-->\n<meta name="description" content="코인데스크코리아"/>\n<meta property="og:title" content="코인데스크코리아 "/>\n<meta property="og:site_name" content="코인데스크코리아 "/>\n<meta property="og:image" content="http://www.coindeskkorea.com/image/logo/snslogo_20191211100329.jpg" />\n<meta property="og:url"\tcontent="http://www.coindeskkorea.com" />\n<meta property="og:description" content="코인데스크코리아" />\n<meta name="twitter:card" content="summary"/>\n<meta name="twitter:title" content="코인데스크코리아 "/>\n<meta name="twitter:description" content="코인데스크코리아"/>\n<meta name="twitter:image:src" content="http://www.coindeskkorea.com/image/logo/snslogo_20191211100329.jpg"/>\n<!--// 메타태그정보 -->\n<title>CoinDesk Korea 신뢰 그 이상의 가치</title>\n<link rel="apple-touch-icon-precomposed" href="/image/logo/snslogo_20191211100329.jpg" />\n<link rel="stylesheet" href="/css/jquery-ui.min.css">\n<link rel="stylesheet" href="/css/foundation.min.css">\n<link rel="stylesheet" href="/css/custom.foundation.min.css">\n<link rel="stylesheet" href="/css/slick.min.css">\n<link rel="stylesheet" href="/css/webfonts.min.css">\n<link rel="stylesheet" href="/css/aos.min.css">\n<link rel="stylesheet" href="/css/style.min.css">\n<link rel="stylesheet" href="/css/design.style.css">\n<link rel="stylesheet" href="/menuskin/md_01/menubar.css">\n<link rel="shortcut icon" href="/image/logo/favicon_20191211100547.ico">\n<script src="/script/jquery.min.js"></script>\n<script src="/script/jquery-ui.min.js"></script>\n<script src="/script/slick.min.js"></script>\n<script src="/script/jquery.rwdImageMaps.min.js"></script>\n<script src="/script/what-input.js"></script>\n<script src="/script/foundation.min.js"></script>\n<script src="/menuskin/md_01/menubar.js"></script>\n<script src="/script/user.style.js"></script>\n<script src="/script/clipboard.min.js"></script>\n<script src="/script/jquery.tabslet.min.js"></script>\n<script src="/script/aos.min.js"></script>\n<script src="/script/aos.nd.js"></script>\n<script src="/script/common.js"></script>\n\n<script type="text/javascript">\n\n\t// 이미지맵\n\t$(document).ready(function(e) {\n\t\t$(\'img[usemap]\').rwdImageMaps();\n\n\t\tbannerpop.banner(".banner_event_box");\t\t\t\t\t// 기능성배너 이벤트\n\t\tbannerpopMulti.bannerLoad();                            // 멀티 기능성 배너 이벤트\n\n\t\t// 기사뷰 이미지관련\n\t\t\t});\n\n\t// domain\n\tvar SITE_DOMAIN = \'http://www.coindeskkorea.com\'\n\t,___currentTime\t= 1593671666;\n\n</script>\n<style type="text/css">\n/* 사이트 기본 색 */\n.user-point,a.user-point,\n.poll-columns .poll-state.going,\n.auto-hr04-2 .auto-nav .slick-slide.slick-current .auto-fontA,.auto-hr05 .auto-nav .slick-slide.slick-current .auto-fontA,\n.info-social .fonts-option-panel li input[type="radio"]:checked + label\n{color:#f8c400 !important}\n.user-bg,.user-bg:hover,.user-bg:active,.user-bg:focus,li[id*="slick-"].slick-active button[data-role],.checkbox-group > input[type="radio"]:checked + label, .checkbox-group > input[type="checkbox"]:checked + label,\n.radio-group > input[type="radio"]:checked + label, .radio-group > input[type="checkbox"]:checked + label,\n.article-list .article-list-content.type-tm .list-block .links:hover,.tabs .tabs-title.is-active a,\n.poll-view .poll-view-state.going,.poll-view .poll-radio input[type="radio"]:checked + label::before,.poll-view .poll-radio input[type="checkbox"]:checked + label::before,\n.auto-dl04 .auto-column::after,.auto-mr01::before,.auto-hp02 a:hover .photo-titbg,.auto-hr04 .auto-nav .slick-slide.slick-current,.auto-hr04-1 .auto-nav .slick-slide.slick-current,\n.nd-switch.user-bg input[type="checkbox"]:checked + label,.nd-switch.user-bg input[type="radio"]:checked + label,\n.nd-switch.user-bg input[type="checkbox"]:checked + label::before,.nd-switch.user ...

# %%
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" dir="ltr" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="ie=edge" http-equiv="x-ua-compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="#f8c400" name="theme-color"/>
# <!-- 메타태그정보 //-->
# <meta content="코인데스크코리아" name="description">
# <meta content="코인데스크코리아 " property="og:title">
# <meta content="코인데스크코리아 " property="og:site_name">
# <meta content="http://www.coindeskkorea.com/image/logo/snslogo_20191211100329.jpg" property="og:image">
# <meta content="http://www.coindeskkorea.com" property="og:url"/>
# <meta content="코인데스크코리아" property="og:description"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="코인데스크코리아 " name="twitter:title"/>
# <meta content="코인데스크코리아" name="twitter:description"/>
# <meta content="http://www.coindeskkorea.com/image/logo/snslogo_20191211100329.jpg" name="twitter:image:src"/>
# <!--// 메타태그정보 -->
# <title>CoinDesk Korea 신뢰 그 이상의 가치</title>
# <link href="/image/logo/snslogo_20191211100329.jpg" rel="apple-touch-icon-precomposed"/>
# <link href="/css/jquery-ui.min.css" rel="stylesheet"/>
# <link href="/css/foundation.min.css" rel="stylesheet"/>
# <link href="/css/custom.foundation.min.css" rel="stylesheet"/>
# <link href="/css/slick.min.css" rel="stylesheet"/>
# <link href="/css/webfonts.min.css" rel="stylesheet"/>
# <link href="/css/aos.min.css" rel="stylesheet"/>
# <link href="/css/style.min.css" rel="stylesheet"/>
# <link href="/css/design.style.css" rel="stylesheet"/>
# <link href="/menuskin/md_01/menubar.css" rel="stylesheet"/>
# <link href="/image/logo/favicon_20191211100547.ico" rel="shortcut icon"/>
# <script src="/script/jquery.min.js"></script>
# <script src="/script/jquery-ui.min.js"></script>
# <script src="/script/slick.min.js"></script>
# <script src="/script/jquery.rwdImageMaps.min.js"></script>
# <script src="/script/what-input.js"></script>
# <script src="/script/foundation.min.js"></script>
# <script src="/menuskin/md_01/menubar.js"></script>
# <script src="/script/user.style.js"></script>
# <script src="/script/clipboard.min.js"></script>
# <script src="/script/jquery.tabslet.min.js"></script>
# <script src="/script/aos.min.js"></script>
# <script src="/script/aos.nd.js"></script>
# <script src="/script/common.js"></script>
# <script type="text/javascript">
#
# 	// 이미지맵
# 	$(document).ready(function(e) {
# 		$('img[usemap]').rwdImageMaps();
#
# 		bannerpop.banner(".banner_event_box");					// 기능성배너 이벤트
# 		bannerpopMulti.bannerLoad();                            // 멀티 기능성 배너 이벤트
#
# 		// 기사뷰 이미지관련
# 			});
#
# 	// domain
# 	var SITE_DOMAIN = 'http://www.coindeskkorea.com'
# 	,___currentTime	= 1593671666;
#
# </script>
# <style type="text/css">
# /* 사이트 기본 색 */
# .user-point,a.user-point,
# .poll-columns .poll-state.going,
# .auto-hr04-2 .auto-nav .slick-slide.slick-current .auto-fontA,.auto-hr05 .auto-nav .slick-slide.slick-current .auto-fontA,
# .info-social .fonts-option-panel li input[type="radio"]:checked + label
# {color:#f8c400 !important}
# .user-bg,.user-bg:hover,.user-bg:active,.user-bg:focus,li[id*="slick-"].slick-active button[data-role],.checkbox-group > input[type="radio"]:checked + label, .checkbox-group > input[type="checkbox"]:checked + label,
# .radio-group > input[type="radio"]:checked + label, .radio-group > input[type="checkbox"]:checked + label,
# .article-list .article-list-content.type-tm .list-block .links:hover,.tabs .tabs-title.is-active a,
# .poll-view .poll-view-state.going,.poll-view .poll-radio input[type="radio"]:checked + label::before,.poll-view .poll-radio input[type="checkbox"]:checked + label::before,
# .auto-dl04 .auto-column::after,.auto-mr01::before,.auto-hp02 a:hover .photo-titbg,.auto-hr04 .auto-nav .slick-slide.slick-current,.auto-hr04-1 .auto-nav .slick-slide.slick-current,
# .nd-switch.user-bg input[type="checkbox"]:checked + label,.nd-switch.user-bg input[type="radio"]:checked + label,
# .nd-switch.user-bg input[type="checkbox"]:checked + label::before,.nd-switch.user-bg input[type="radio"]:checked + label::before,
# .switch-group.user-bg > .nd-switch input[type="checkbox"]:checked + label,.switch-group.user-bg > .nd-switch input[type="radio"]:checked + label,
# .switch-group.user-bg > .nd-switch input[type="checkbox"]:checked + label::before,.switch-group.user-bg > .nd-switch input[type="radio"]:checked + label::before,
# .switch-group.for-ios > .nd-switch.user-bg input[type="checkbox"]:checked + label,.switch-group.for-ios > .nd-switch.user-bg input[type="radio"]:checked + label,
# .switch-group.for-ios > .nd-switch.user-bg input[type="checkbox"]:checked + label::before,.switch-group.for-ios > .nd-switch.user-bg input[type="radio"]:checked + label::before
# {background-color:#f8c400 !important}
# .user-border,.button.user-bg,
# .poll-view .poll-radio input[type="radio"] + label:hover strong::before,.poll-view .poll-radio input[type="checkbox"] + label:hover strong::before,
# .poll-view .poll-radio input[type="radio"]:checked + label  strong::before,.poll-view .poll-radio input[type="checkbox"]:checked + label  strong::before,
# .auto-pa01 .auto-nav .slick-current .auto-images::before,.auto-hr05-1 .auto-content a:hover .auto-images.line::before,
# #gallery-wrap .gallery-content.view-page .gallery-thumb .nav-content.slick-current::before,
# .info-social .fonts-option-panel li input[type="radio"]:checked + label
# {border-color:#f8c400 !important}
# .user-border-top {border-top-color:#f8c400 !important}
# .user-border-bottom {border-bottom-color:#f8c400 !important}
# .user-border-left {border-left-color:#f8c400 !important}
# .user-border-right {border-right-color:#f8c400 !important}
# .mobile-tabs .tabs .is-active a {color:#f8c400 !important;background:#fff !important}
# </style>
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#   window.googletag = window.googletag || {cmd: []};
#   googletag.cmd.push(function() {
#     googletag.defineSlot('/21699126583/Coindesk_Apage_top_RightRail', [300, 250], 'div-gpt-ad-1579684795977-0').addService(googletag.pubads());
#     googletag.defineSlot('/21699126583/Coindesk_Apage_top_Leaderboard', [[728, 90], [970, 90]], 'div-gpt-ad-1579685034481-0').addService(googletag.pubads());
# 	googletag.defineSlot('/21699126583/Coindesk_Apage_Right_Skyscraper', [160, 600], 'div-gpt-ad-1579685096730-0').addService(googletag.pubads());
# 	googletag.defineSlot('/21699126583/Coindesk_Bpage_article_Middle', [300, 250], 'div-gpt-ad-1579685131805-0').addService(googletag.pubads());
# 	googletag.defineSlot('/21699126583/Coindesk_Bpage_Right_Skyscraper', [160, 600], 'div-gpt-ad-1579685161281-0').addService(googletag.pubads());
# 	googletag.defineSlot('/21699126583/Coindesk_Bpage_top_Leaderboard', [[728, 90], [970, 90]], 'div-gpt-ad-1579685182114-0').addService(googletag.pubads());
# 	googletag.defineSlot('/21699126583/Coindesk_Bpage_top_RightRail', [300, 250], 'div-gpt-ad-1579685216165-0').addService(googletag.pubads());
# 	googletag.defineSlot('/21699126583/Coindesk_Mobile_Apage_Leaderboard', [320, 50], 'div-gpt-ad-1579685239708-0').addService(googletag.pubads());
# 	googletag.defineSlot('/21699126583/Coindesk_Mobile_Bpage_article_Middle', [300, 250], 'div-gpt-ad-1579685262086-0').addService(googletag.pubads());
# 	googletag.defineSlot('/21699126583/Coindesk_Mobile_Bpage_Leaderboard', [320, 50], 'div-gpt-ad-1579685298003-0').addService(googletag.pubads());
# 	googletag.defineSlot('/21699126583/Coindesk_Mobile_footer_Leaderboard', [320, 50], 'div-gpt-ad-1579685319293-0').addService(googletag.pubads());
# 	googletag.pubads().enableSingleRequest();
#     googletag.enableServices();
#   });
# </script>
# <script async="" src="https://www.google-analytics.com/plugins/ua/linkid.js" type="text/javascript"></script>
# <script async="" src="https://www.google-analytics.com/analytics.js" type="text/javascript"></script>
# <!-- <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-NSNFWH9"></script> -->
# <!-- Dable 스크립트 시작 / 문의 support@dable.io -->
# <script>
# (function(d,a,b,l,e,_) {
# d[b]=d[b]||function(){(d[b].q=d[b].q||[]).push(arguments)};e=a.createElement(l);
# e.async=1;e.charset='utf-8';e.src='//static.dable.io/dist/plugin.min.js';
# _=a.getElementsByTagName(l)[0];_.parentNode.insertBefore(e,_);
# })(window,document,'dable','script');
# dable('setService', 'coindeskkorea.com');
# dable('sendLog');
# </script>
# <!-- Dable 스크립트 종료 / 문의 support@dable.io -->
# <!-- Global site tag (gtag.js) - Google Analytics -->
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-156669016-1"></script>
# <script>
#   window.dataLayer = window.dataLayer || [];
#   function gtag(){dataLayer.push(arguments);}
#   gtag('js', new Date());
#
#   gtag('config', 'UA-156669016-1');
# </script>
# <!-- Facebook Pixel Code -->
# <script>
#   !function(f,b,e,v,n,t,s)
#   {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#   n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#   if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#   n.queue=[];t=b.createElement(e);t.async=!0;
#   t.src=v;s=b.getElementsByTagName(e)[0];
#   s.parentNode.insertBefore(t,s)}(window, document,'script',
#   'https://connect.facebook.net/en_US/fbevents.js');
#   fbq('init', '2012614539007426');
#   fbq('track', 'PageView');
# </script>
# <noscript><img height="1" src="https://www.facebook.com/tr?id=2012614539007426&amp;ev=PageView&amp;noscript=1" style="display:none" width="1"/></noscript>
# <!-- Naver Analytics -->
# <script src="https://wcs.naver.net/wcslog.js" type="text/javascript"></script>
# <script type="text/javascript">
# if(!wcs_add) var wcs_add = {};
# wcs_add["wa"] = "11c6340f97fbc";
# wcs_do();
# </script>
# </meta></meta></meta></meta></head>
# <body>
# <!-- wrap //-->
# <div class="mobile" data-effect="fade-up" data-effect-time="300" id="user-wrap">
# <div class="row expanded">
# <style type="text/css">
# #header-wrapper.basic, #header-wrapper .mode-inner {width:1250px}
# #header-wrapper #user-nav .mode-inner {width:100%}
#
# @media screen and (max-width: 78.125em) {
# 	#header-wrapper .mode-inner {width:100%;padding-left:1.25rem;padding-right:1.25rem}
# }
#
# /* 1차 */
# #user-nav .user-menu .secline > a.a-active,
# #m-nav-box .user-all-menu .secline > a.a-active {color:#f8c400}
# #user-nav .user-menu .secline.is-sub > a.a-active::after {border-bottom-color:#f8c400}
# #user-nav .user-menu .secline > a[href*="MOBILE_12"],
# #m-nav-box .user-all-menu .secline > a[href*="MOBILE_12"] {background-color:#f8c400}
#
# /* 2차 */
# #nav-header .sub-fixed .sub-inner {width:1250px}
# #nav-header .sub-fixed .sub > a::before {background-color:#f8c400}
#
# /* 2차 - 배경 slideDown */
# #header-wrapper.horizon #user-nav.active::before {background-color:#f8c400}
#
# /* 2차 - vertical & use autobox */
# #header-wrapper.vertical.nav-autobox #user-nav .user-menu .secline > ul {width:1250px;padding-right:calc(1250px - 300px);border-color:#f8c400}
# #header-wrapper.vertical.nav-autobox #user-nav .user-menu .secline .sub > a.a-sub-hover,
# #header-wrapper.vertical.nav-autobox #user-nav .user-menu .secline .sub > a:hover {color:#fff;background-color:#f8c400}
#
# /* 모바일 메뉴 */
# #m-nav-box .user-all-menu .secline > a::after {color:#f8c400}
# #m-nav-box .user-all-menu .secline ul > li::before {background-color:#f8c400}
# </style>
# <!-- 메뉴시작 //-->
# <div class="vertical full left" data-main-code="/news/articleList.html" data-serial-code="/news/articleList.html" data-sub-code="/news/articleList.html" id="header-wrapper">
# <!-- 최종편집
# 	<div class="user-intro">UPDATED. 2020-07-02 15:30 (목) </div> -->
# <header id="nav-header">
# <div id="user-top">
# <div class="mode-inner">
# <!-- sns //-->
# <div class="user-sns">
# <a data-tooltip="" href="https://t.me/coindesk_korea" target="_blank" title="텔레그램"><i class="fa fa-telegram"></i></a>
# <a data-tooltip="" href="http://www.facebook.com/coindeskkorea" target="_blank" title="페이스북"><i class="icon-facebook"></i></a>
# <a data-tooltip="" href="https://www.youtube.com/channel/UCzxDMBaqJHhTHphiFxCCgxQ" target="_blank" title="유튜브"><i class="icon-youtube"></i></a>
# <a data-tooltip="" href="https://twitter.com/coindeskkorea" target="_blank" title="트위터"><i class="icon-twitter"></i></a>
# </div>
# <!--// sns -->
# <!-- 해외사이트 //-->
# <div id="m-drop-site">
# <ul class="no-bullet" id="drop-menu-all">
# <li>
# <a class="drop-tit">한국 <i aria-hidden="true" class="fa fa-caret-down"></i></a>
# <ul class="no-bullet" id="drop-menu">
# <li><a href="http://www.coindesk.com" target="_blank">English</a></li>
# <li><a href="http://www.coindeskchinese.com" target="_blank">Chinese</a></li>
# <li><a href="http://www.coindeskjapan.com" target="_blank">Japanese</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <script type="text/javascript">
# $(function(){
#
# 	$("ul#drop-menu-all > li").each(function(idx, ele){
#
# 		// 1차 클릭
# 		$(ele).children("a").on("click", function(e){
#
# 			if($(ele).find("ul > li").length <= 0) return;	// 2차 메뉴가 없으면 return
#
# 			e.preventDefault();		// 링크기능 제거
#
# 			if($(this).hasClass("sub-active")){
# 				$(ele).children("a").removeClass("sub-active");
# 				$(ele).children("ul").slideUp();
# 			} else {
# 				$("ul#user-all-menu > li > a").removeClass("sub-active");
# 				$(ele).children("a").addClass("sub-active");
# 				$("ul#user-all-menu > li > ul").slideUp();
# 				$(ele).children("ul").slideDown();
# 			}
# 		});
#
# 	});
#
# });
# </script> <!--// 해외사이트 -->
# <!-- 이전검색위치 -->
# <div class="search-menu user-menu" id="user-menu">
# <!-- 검색 //-->
# <div class="secline sub-active search">
# <a class="search-btn"><i class="s7-search"></i></a>
# <div class="sub-fixed">
# <div class="sub-inner">
# <button class="sub-close" onclick="subClose(this)" type="button"><img src="/menuskin/md_01/close-btn.png"/></button>
# <fieldset class="user-search-form">
# <form action="/news/articleList.html" method="post" name="head-search">
# <input name="sc_area" type="hidden" value="A"/>
# <input name="view_type" type="hidden" value="sm"/>
# <label class="show-for-sr" for="search">기사검색</label>
# <input id="search" name="sc_word" onkeydown="if(event.keyCode==13){if(this.form.sc_word.value != ''){this.form.submit();}else{alert('검색어를 입력해주세요');return false;}}" placeholder="Search" title="Search" type="text"/>
# <button onclick="if(this.form.sc_word.value != ''){this.form.submit();}else{alert('검색어를 입력해주세요');this.form.sc_word.focus();return false;}" title="기사검색" type="button"><i class="s7-search"></i><span class="show-for-sr">검색</span></button>
# </form>
# </fieldset>
# <!-- follow us11 //-->
# <div class="for-menu">
# <iframe frameborder="0" height="420" noresize="" src="http://www.coindeskkorea.com/menuskin/md_01/followus.php" width="525"></iframe>
# </div>
# <!--// follow us -->
# </div>
# </div>
# </div>
# <!--// 검색 -->
# </div>
# </div>
# </div>
# <!--// 최상단영역 -->
# <div class="mode-inner">
# <!-- logo //-->
# <div class="user-logo text-left"><a href="http://www.coindeskkorea.com" target="_top"><img alt="코인데스크코리아 " src="/image/logo/mobilelogo_20191211103546.png"/></a></div>
# <!--// logo -->
# <nav class="user-nav" id="user-nav">
# <!-- 1차 섹션 //-->
# <ul class="user-menu no-bullet" id="user-menu">
# <li class="secline">
# <a data-code="sm" href="/news/articleList.html?view_type=sm" target="_top">News</a>
# <div class="sub-fixed">
# <div class="sub-inner">
# <button class="sub-close" type="button"><img src="/menuskin/md_01/close-btn.png"/></button>
# <!-- follow us22 //-->
# <div class="for-menu">
# <iframe frameborder="0" height="420" noresize="" src="https://www.coindeskkorea.com/menuskin/md_01/followus.php" width="525"></iframe>
# </div>
# <!--// follow us -->
# </div>
# </div>
# </li>
# <li class="secline">
# <a data-code="K" href="/news/articleList.html?sc_area=K&amp;sc_word=에디터스픽&amp;view_type=sm" target="_blank">Editor’s Pick</a>
# <div class="sub-fixed">
# <div class="sub-inner">
# <button class="sub-close" type="button"><img src="/menuskin/md_01/close-btn.png"/></button>
# <!-- follow us22 //-->
# <div class="for-menu">
# <iframe frameborder="0" height="420" noresize="" src="https://www.coindeskkorea.com/menuskin/md_01/followus.php" width="525"></iframe>
# </div>
# <!--// follow us -->
# </div>
# </div>
# </li>
# <li class="secline">
# <a data-code="https://events.bizzabo.com/daxpo" href="https://events.bizzabo.com/daxpo" target="_blank"><span style="background-color:#f8c400;color:#000;padding:10px">Events</span></a>
# <div class="sub-fixed">
# <div class="sub-inner">
# <button class="sub-close" type="button"><img src="/menuskin/md_01/close-btn.png"/></button>
# <!-- follow us22 //-->
# <div class="for-menu">
# <iframe frameborder="0" height="420" noresize="" src="https://www.coindeskkorea.com/menuskin/md_01/followus.php" width="525"></iframe>
# </div>
# <!--// follow us -->
# </div>
# </div>
# </li>
# <div class="menu-line user-menu" id="user-menu">
# <!-- 검색 //-->
# <div class="secline sub-active search">
# <a class="search-btn"><i class="s7-search"></i></a>
# <div class="sub-fixed">
# <div class="sub-inner">
# <button class="sub-close" onclick="subClose(this)" type="button"><img src="/menuskin/md_01/close-btn.png"/></button>
# <fieldset class="user-search-form">
# <form action="/news/articleList.html" method="post" name="head-search">
# <input name="sc_area" type="hidden" value="A"/>
# <input name="view_type" type="hidden" value="sm"/>
# <label class="show-for-sr" for="search">기사검색</label>
# <input id="search" name="sc_word" onkeydown="if(event.keyCode==13){if(this.form.sc_word.value != ''){this.form.submit();}else{alert('검색어를 입력해주세요');return false;}}" placeholder="Search" title="Search" type="text"/>
# <button onclick="if(this.form.sc_word.value != ''){this.form.submit();}else{alert('검색어를 입력해주세요');this.form.sc_word.focus();return false;}" title="기사검색" type="button"><i class="s7-search"></i><span class="show-for-sr">검색</span></button>
# </form>
# </fieldset>
# <!-- follow us11 //-->
# <div class="for-menu">
# <iframe frameborder="0" height="420" noresize="" src="http://www.coindeskkorea.com/menuskin/md_01/followus.php" width="525"></iframe>
# </div>
# <!--// follow us -->
# </div>
# </div>
# </div>
# <!--// 검색 -->
# </div>
# <!-- 해외사이트 //-->
# <!--// 해외사이트 -->
# </ul>
# <!--// 섹션 -->
# </nav>
# <!--// 메뉴바 -->
# <!-- menu button //-->
# <button class="menu-btn" id="menu-btn" type="button"><i class="s7-search"></i><span class="sr-only">메뉴</span></button>
# <!--// menu button -->
# <!-- mobile nav //-->
# <div id="m-nav-box">
# <!-- 검색 //-->
# <fieldset class="user-search-form">
# <form action="/news/articleList.html" method="post" name="head-search">
# <input name="sc_area" type="hidden" value="A"/>
# <input name="view_type" type="hidden" value="sm"/>
# <label class="show-for-sr" for="search">기사검색</label>
# <input id="search" name="sc_word" onkeydown="if(event.keyCode==13){if(this.form.sc_word.value != ''){this.form.submit();}else{alert('검색어를 입력해주세요');return false;}}" placeholder="Search" title="Search" type="text"/>
# <button onclick="if(this.form.sc_word.value != ''){this.form.submit();}else{alert('검색어를 입력해주세요');this.form.sc_word.focus();return false;}" title="기사검색" type="button"><i class="s7-search"></i><span class="show-for-sr">검색</span></button>
# </form>
# </fieldset>
# <!--// 검색 -->
# <!-- 섹션 //-->
# <ul class="user-all-menu" id="user-all-menu">
# <li class="secline">
# <a data-code="sm" href="/news/articleList.html?view_type=sm" target="_top">News</a>
# <ul class="no-bullet">
# </ul>
# </li>
# <li class="secline">
# <a data-code="K" href="/news/articleList.html?sc_area=K&amp;sc_word=에디터스픽&amp;view_type=sm" target="_blank">Editor’s Pick</a>
# <ul class="no-bullet">
# </ul>
# </li>
# <li class="secline">
# <a data-code="https://events.bizzabo.com/daxpo" href="https://events.bizzabo.com/daxpo" target="_blank"><span style="background-color:#f8c400;color:#000;padding:10px">Events</span></a>
# <ul class="no-bullet">
# </ul>
# </li>
# </ul>
# <!--// 섹션 -->
# <button class="nav-all-close" id="nav-all-close" type="button"><img src="/menuskin/md_01/close-btn.png"/></button>
# </div>
# <script type="text/javascript">
# $(function(){
# 	var userAllNav = $(".user-all-nav");
#
# 	/* 전체메뉴 버튼 클릭
# 	navAllBtn.on("click", function(){
# 		if(navAllBox.css("display") == "none"){
# 			navAllBtn.addClass("close");
# 			navAllBox.slideDown();
# 		} else {
# 			navAllBtn.removeClass("close");
# 			navAllBox.slideUp();
# 		}
# 	});
#
# 	// 전체메뉴 영역 외 클릭시 감추기
# 	$(document).mouseup(function(e) {
# 		if (!userAllNav.is(e.target) && userAllNav.has(e.target).length === 0) {
# 			navAllBtn.removeClass("close");
# 			navAllBox.css("left", "-300px");
# 		}
# 	});
# 	*/
#
# 	$("ul#user-all-menu > li").each(function(idx, ele){
#
# 		// 2차가 있을 경우 클래스추가
# 		if($(ele).find("ul > li").length > 0) {
# 			$(ele).addClass("is-sub");
# 		}
#
# 		// 1차 클릭
# 		$(ele).children("a").on("click", function(e){
#
# 			if($(ele).find("ul > li").length <= 0) return;	// 2차 메뉴가 없으면 return
#
# 			e.preventDefault();		// 링크기능 제거
#
# 			if($(this).hasClass("sub-active")){
# 				$(ele).children("a").removeClass("sub-active");
# 				$(ele).children("ul").slideUp();
# 			} else {
# 				$("ul#user-all-menu > li > a").removeClass("sub-active");
# 				$(ele).children("a").addClass("sub-active");
# 				$("ul#user-all-menu > li > ul").slideUp();
# 				$(ele).children("ul").slideDown();
# 			}
# 		});
#
# 	});
#
# });
# </script> <!--// mobile nav -->
# </div>
# <!-- 하단영역 /
# 		<div id="user-gnb">
# 			<div class="mode-inner">
#
# 				<div class="coindesk-area">
# 					<strong class="tit-area">코인데스크 BPI</strong><span class="point-area"> $8,662.80 -0.41</span>
# 				</div>
# 			</div>
# 		</div>
# 		//-->
# <div id="user-gnb">
# <div class="mode-inner">
# <!-- 코인시세 //-->
# <div class="coindesk-area">
# <a href="https://www.coindesk.com/price/bitcoin" target="_blank"><strong class="tit-area">Bitcoin</strong><span class="point-area"> $9,197.42</span></a>
# </div>
# <!-- 수동롤링 -->
# <div class="livenews-wrap">
# <style type="text/css">
# #skin-bbs_2_MOBILE_TR04-3 {overflow:hidden;position:relative;padding:10px 8px}
# #skin-bbs_2_MOBILE_TR04-3::after {content:'';position:absolute;z-index:1;right:0;top:0;width:50%;height:100%}
# #skin-bbs_2_MOBILE_TR04-3 .auto-btns, #skin-bbs_2_MOBILE_TR04-3 .container {float:left;position:relative;z-index:2}
# #skin-bbs_2_MOBILE_TR04-3 .auto-btns {overflow:hidden;width:60px;height:27px;line-height:27px;letter-spacing:-.05em;color:#e73f72;background-color:rgba(255,255,255,.9);border-radius:32px;text-align:center}
# #skin-bbs_2_MOBILE_TR04-3 .container {width:calc(100% - 60px);padding-left:12px}
# #skin-bbs_2_MOBILE_TR04-3 .auto-titles {overflow:hidden;height:25px;line-height:25px;text-overflow:ellipsis;white-space:nowrap}
# </style>
# <div class="auto-article" id="skin-bbs_2_MOBILE_TR04-3">
# <div class="container" id="roll-bbs_2_MOBILE_TR04-3">
# <div class="item dis-none">
# <a class="auto-titles size-14 auto-fontF" href="https://bit.ly/2yN8FRR" target="_blank">DAXPO 2020 | 부산 파라다이스 호텔, 2020년 9월 3-4일</a>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# (function() {
#
# 	$('#roll-bbs_2_MOBILE_TR04-3').slick({
# 		arrows: false, // 화살표표시
# 		dots: false, // pager
# 		vertical: true, // 세로방향
# 		verticalSwiping: true, // 세로swiping
# 		infinite: true, // 무한넘기기
# 		autoplay: true, // 자동전환
# 		//autoplaySpeed: 4000, // 자동전환속도
# 		speed: 600, // 넘기는 속도
# 	});
#
# })();
# </script>
# </div>
# </div>
# </div>
# </header>
# </div>
# <!--// 메뉴 끝 -->
# <script type="text/javascript">
# <!--
# //메뉴 스타일 불러옴 : 메뉴 /script/menubar.js 와 같이 사용되어야 함
# //submenuStyle	: 서브메뉴 펼침 스타일 (horizon : 가로로, vertical : 세로 슬라이딩)
# var menuIndexHold = false,
# menuOverHold = true,
# submenuStyle = "vertical",
# sizeMode = "full",
# subShow = "hold",
# submenuPosi = "left",
# effectSwitch = "on",
# subSlideSpeed = 150,
# subFadeSpeed = 150;
#
# $(document).ready(function(){
#
# 	// 메뉴바 스크롤 시 fixed
#
# 	var nowScrool = $(document).scrollTop(); //현재 스크롤값
#
# 	$(window).scroll(function(){
# 		var navHeight = $("#nav-header").outerHeight();
# 		if($(document).scrollTop() > navHeight){
# 			if(nowScrool > $(document).scrollTop()){
# 				$("#nav-header").addClass("scroll");
# 				//$("#user-gnb").css("display","block");
# 			} else {
# 				$("#nav-header").removeClass("scroll");
# 			}
# 			nowScrool = $(document).scrollTop();
# 			$("#nav-header").addClass("scroll");
# 		}else{
# 			$("#nav-header").removeClass("scroll");
# 		}
# 	});
#
# 	// 1차 클릭 (2차 펼침)
# 	$("#user-menu > .secline.sub-active > a").on("click",function(){
# 		if($(this).siblings(".sub-fixed").css("display") == "none") {
# 			$(".sub-fixed").hide();
# 			$("#user-menu > .secline > a").removeClass("a-active");
# 			$(this).addClass("a-active");
# 			$(this).siblings(".sub-fixed").slideDown();
# 			$('body, html').css('overflow','hidden');
# 		} else {
# 			$(this).removeClass("a-active");
# 			$(this).siblings(".sub-fixed").slideUp();
# 			$('body, html').css('overflow','initial');
# 		}
# 	});
#
# 	// 2차 닫기
# 	var subCloseBtn = $(".sub-close");
# 	subCloseBtn.on("click", function(){
# 		$(this).parent().parent(".sub-fixed").slideUp();
# 		$("#user-menu > .secline > a").removeClass("a-active");
# 		$('body, html').css('overflow','initial');
# 	});
#
#
# 	// 모바일 메뉴 open
# 	$("#menu-btn").on("click", function(){
# 		if($("#m-nav-box").css("display") == "none"){
# 			$("#m-nav-box").slideDown();
# 			$('body, html').css('overflow','hidden');
# 		} else {
# 			$("#m-nav-box").slideUp();
# 			$('body, html').css('overflow','initial');
# 		}
# 	});
#
# 	// 모바일 메뉴 close
# 	$("#nav-all-close").on("click", function(){
# 		$("#m-nav-box").slideUp();
# 		$('body, html').css('overflow','initial');
# 	});
#
# });
# //-->
# </script>
# <!-- container //-->
# <section id="user-container">
# <!-- layer popup position  -->
# <div id="layer-popups"></div>
# <!-- 플로팅 좌우 HTML //-->
# <div class="floating-banner-layout posi-re float-center width-1250"></div> <!--// 플로팅 좌우 HTML -->
# <div class="float-center custom-m mobile template list max-width-1250">
# <!-- 편집패널 //-->
# <div class="clearfix">
# </div>
# <!--// 편집패널 -->
# <!-- article view wrapper //-->
# <div class="user-content">
# <!-- 기사본문 좌측 //-->
# <aside class="custom-aside">
# </aside>
# <!--// 기사본문 좌측 -->
# <!-- 기사본문 내용 //-->
# <section class="custom-snb">
# <!-- contents //-->
# <article class="article-veiw-body">
# <!-- 편집패널 //-->
# <div class="clearfix">
# <div class="box-margins height-20"></div>
# </div>
# <!--// 편집패널 -->
# <div class="text-center">
# <div class="float-center">
# <div class="search-box">
# <form action="/news/articleList.html" method="get" name="search_form">
# <input name="sc_area" type="hidden" value="A"/>
# <input name="view_type" type="hidden" value="sm"/>
# <div class="input-box">
# <fieldset class="row expanded small-collapse medium-uncollapse">
# <div class="small-12 medium-8 large-9 columns"><input class="top-input" name="sc_word" type="text" value=""/></div>
# <div class="small-12 medium-4 large-3 columns"><button class="search-btn2" style="cursor:pointer" type="submit">검색</button></div>
# </fieldset>
# </div>
# <div class="category float-left">
# <div class="data">
# <div class="small-12 width-180 columns">
# <span>정렬</span>
# <select class="width-100 auto-marbtm-1" name="sc_order_by">
# <option selected="" value="E">최신순
# 								<option value="ER">오래된순
# 							</option></option></select>
# </div>
# <div class="small-12">
# <a class="date-link" href="/news/articleList.html?sc_day=&amp;sc_word=&amp;sc_area=&amp;view_type=sm&amp;sc_order_by=E">전체</a>
# <a class="date-link" href="/news/articleList.html?sc_day=1&amp;sc_word=&amp;sc_area=&amp;view_type=sm&amp;sc_order_by=E">1일</a>
# <a class="date-link" href="/news/articleList.html?sc_day=7&amp;sc_word=&amp;sc_area=&amp;view_type=sm&amp;sc_order_by=E">1주</a>
# <a class="date-link" href="/news/articleList.html?sc_day=30&amp;sc_word=&amp;sc_area=&amp;view_type=sm&amp;sc_order_by=E">1개월</a>
# <a class="date-link" href="/news/articleList.html?sc_day=365&amp;sc_word=&amp;sc_area=&amp;view_type=sm&amp;sc_order_by=E">1년</a>
# <a class="date-link" href="javascript:;" id="date-input-box-view">직접입력</a>
# </div>
# </div>
# <div class="small-12 medium-9 large-10 columns dis-none" id="date-input-box">
# <div class="row expanded collapse small-up-1 medium-up-2">
# <div class="columns">
# <label class="show-for-sr" for="sc_sdate">시작 년월일</label>
# <div class="input-group small-width-calc-1 auto-marbtm-1">
# <input class="input-group-field" id="sc_sdate" name="sc_sdate" placeholder="2011-01-01" title="시작 년월일" type="text" value=""/>
# <span class="input-group-label">부터</span>
# </div>
# </div>
# <div class="columns">
# <label class="show-for-sr" for="sc_edate">마지막 년월일</label>
# <div class="input-group">
# <input class="input-group-field" id="sc_edate" name="sc_edate" placeholder="2017-01-01" title="마지막 년월일" type="text" value=""/>
# <span class="input-group-label">까지</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </form>
# </div>
# </div>
# </div>
# <script>
# 	//datepicker
# 	$.datepicker.setDefaults($.datepicker.regional['ko']);
# 	$('#sc_sdate, #sc_edate').datepicker({
# 		dateFormat : "yy-mm-dd"
# 	});
#
# 	$('#date-input-box-view').click(function(e){
# 		if($('#date-input-box').hasClass("dis-none")){
# 			$('#date-input-box').removeClass("dis-none");
# 		} else {
# 			$('#date-input-box').addClass("dis-none");
# 		}
# 	});
# </script>
# <div class="box-margins height-20"></div>
# <!-- 기사리스트 //-->
# <div class="article-list">
# <!-- 웹진형 //-->
# <section class="article-list-content type-sm text-left">
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71135_7428_3411_v150.jpg)">
# <a href="/news/articleView.html?idxno=71135" target="_top">
# <span class="show-for-sr">암호화폐 수용한 싱가포르 규제도 빨라</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=싱가포르&amp;view_type=sm" target="_top">#싱가포르</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71135" target="_top"><strong>암호화폐 수용한 싱가포르 규제도 빨라</strong></a></div>
# <div class="list-dated"><strong class="list-name">권오훈</strong> 2020-06-29 08:00</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71135" target="_top">
# 					1. 싱가포르 암호화폐 라이선스싱가포르가 2019년 초 제정했던 지불서비스법(PSA, Payment Services Act)이 2020년 1월28일 시행되었습니다.싱가포르의 금융당국인 MAS(Monetary Authority of Singapore)는 2019년 12월5일에 암호화폐를 포함한 가상자산이 경제에 미칠 부정적 영향에 대해 우려하면서 ‘자금세탁방지 및 테러자금조달방지(Prevention of Money Laundering and Countering the Financing of Terrorism)’에 관한 방안을 발표했습					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71140_7435_2420_v150.jpg)">
# <a href="/news/articleView.html?idxno=71140" target="_top">
# <span class="show-for-sr">[단독]"금융범죄 사범 대주주인 거래소에 은행계좌 발급 말라"</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=특금법&amp;view_type=sm" target="_top">#특금법</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71140" target="_top"><strong>[단독]"금융범죄 사범 대주주인 거래소에 은행계좌 발급 말라"</strong></a></div>
# <div class="list-dated"><strong class="list-name">김병철</strong> 2020-06-29 08:00</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71140" target="_top">
# 					암호화폐 기업의 생사를 정하는 특정금융정보법(특금법) 시행령 개정을 앞두고 금융당국이 업계와 전문가들의 의견을 모으고 있다. 코인데스크코리아는 최근 금융당국 특금법 TF의 일부 자문위원들이 만든 시행령 초안을 입수했다. 이와는 별도로 블록체인협회가 금융정보분석원(FIU)에 최종 전달한 제안서의 일부도 확보했다. 양쪽 문서의 내용을 합쳐서 보면, 현 단계에서 논의중인 시행령의 밑그림을 대략 그려볼 수 있다. 1. 사업자 범위 (특금법 2조1호, 7조1항)FIU가 가장 먼저 정해야 하는 건 특금법 규제대상인 가상자산 사업자(VASP)의					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71141_7438_592_v150.jpg)">
# <a href="/news/articleView.html?idxno=71141" target="_top">
# <span class="show-for-sr">암호화폐가 표준 되려면 다양성 갖춰야</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=돈을 다시 생각하다&amp;view_type=sm" target="_top">#돈을 다시 생각하다</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71141" target="_top"><strong>암호화폐가 표준 되려면 다양성 갖춰야</strong></a></div>
# <div class="list-dated"><strong class="list-name">Michael J Casey</strong> 2020-06-29 07:00</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71141" target="_top">
# 					몇 해 전, MIT 미디어 랩(MIT Media Lab) 연구원 조이 부올라뮈니는 인터랙티브 디지털 아트 프로젝트를 총괄하며 얼굴인식 기술이 피부색이 밝은 동료를 훨씬 더 잘 인식한다는 사실을 알아냈다.이후 그는 알고리듬 정의 연맹(Algorithmic Justice League)을 설립하고 소프트웨어 알고리듬에 내재한 편견에 관한 인식을 재고하기 위한 연구를 시작한다. 그는 구글(Google)에서 윤리적 AI팀(Ethical Artificial Intelligence Team) 공동 기술팀장을 맡고 있는 팀닛 게브루와 함께 집필한					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71137_7433_4615_v150.jpg)">
# <a href="/news/articleView.html?idxno=71137" target="_top">
# <span class="show-for-sr">트위터 CEO가 찬성한 탈중앙화 사실 검증</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=잭 도시&amp;view_type=sm" target="_top">#잭 도시</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71137" target="_top"><strong>트위터 CEO가 찬성한 탈중앙화 사실 검증</strong></a></div>
# <div class="list-dated"><strong class="list-name">Benjamin Powers</strong> 2020-06-28 11:30</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71137" target="_top">
# 					트위터 CEO 잭 도시는 최근 트위터 같은 중개자 없이 오픈소스 기술로 사실을 검증하자는 내용의 트윗을 리트윗했다.지난달 말 트위터에서 도널드 트럼프 대통령의 우편투표 관련 트윗에 팩트 체크가 필요하다는 표시를 단 뒤 트럼프가 통신품위법 230조(쌍방향 컴퓨터 서비스를 제공하거나 사용하는 자는 또 다른 정보 콘텐츠 공급자가 제공한 정보의 출판자나 발화자로서 책임을 지지 않는다는 내용의 법) 개정을 발표하고 플랫폼 기업의 권리를 제한하겠다는 행정 명령에 서명한 직후였다. 통신품위법 230조는 플랫폼 기업이 플랫폼상의 콘텐츠에 법적 책					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71139_7434_377_v150.jpg)">
# <a href="/news/articleView.html?idxno=71139" target="_top">
# <span class="show-for-sr">6/27 아침브리핑: 크립토닷컴의 환불, 소브린의 정리해고 외</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=블록체인 바이트&amp;view_type=sm" target="_top">#블록체인 바이트</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71139" target="_top"><strong>6/27 아침브리핑: 크립토닷컴의 환불, 소브린의 정리해고 외</strong></a></div>
# <div class="list-dated"><strong class="list-name">Daniel Kuhn</strong> 2020-06-27 12:20</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71139" target="_top">
# 					주요 소식 뉴욕주 금융감독청, 비트라이선스 승인에 삼진아웃제 적용 검토뉴욕주 금융감독청(NYDFS)이 암호화폐 회사가 3회 이상 규제 당국이 지적한 문제를 해결하지 못하면 비트라이선스(BitLicense) 승인을 반려할 수 있다고 경고했다. 반면, 유럽연합은 리브라(Libra)와 같은 ‘글로벌 스테이블코인’ 프로젝트에 더 엄격한 요건을 적용하는 새로운 암호화폐 체계를 준비하고 있다.미국 법무부와 증권거래위원회(SEC)가 자금세탁방지를 위한 보호장치가 포함된 암호화폐라고 주장한 ‘AML 비트코인(AML Bitcoin)’의 창립자를 고					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71136_7430_3259_v150.jpg)">
# <a href="/news/articleView.html?idxno=71136" target="_top">
# <span class="show-for-sr">이주의 암호화폐 거래소 및 채굴자 동향(6/22~6/26)</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=이주의 동향&amp;view_type=sm" target="_top">#이주의 동향</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71136" target="_top"><strong>이주의 암호화폐 거래소 및 채굴자 동향(6/22~6/26)</strong></a></div>
# <div class="list-dated"><strong class="list-name">크립토퀀트</strong> 2020-06-26 20:00</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71136" target="_top">
# 					암호화폐 데이터 분석 플랫폼 크립토퀀트(CryptoQuant)의 온체인 분석에 따르면 지난 25일 23시 59분 기준 글로벌 주요 거래소 19곳의 비트코인(BTC) 보유량은 240만 6480개(한화 약 26조 3219억원)로 조사됐다. 25일 기준 비트코인 보유량 상위 거래소는 코인베이스(91만 2277개), 후오비글로벌(29만 4397개), 바이낸스(27만 6304개), 비트멕스(21만 9194개), 제미니(13만 8790개) 순이다. 이중 후오비글로벌은 전주에 비해 보유량이 3.06% 증가했고 비트멕스는 1.07% 감소했다. 비					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71091_7427_576_v150.jpg)">
# <a href="/news/articleView.html?idxno=71091" target="_top">
# <span class="show-for-sr">차이로 사면 왜 물건값이 내려가는 거죠?</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=테라&amp;view_type=sm" target="_top">#테라</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71091" target="_top"><strong>차이로 사면 왜 물건값이 내려가는 거죠?</strong></a></div>
# <div class="list-dated"><strong class="list-name">김동환 기자</strong> 2020-06-26 14:00</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71091" target="_top">
# 					편집자 주. 종이에 갇혀있던 돈이 자유로워지고 있습니다. 20년 전 싸이월드 도토리로 미니홈피를 꾸미던 사람들이 이제는 암호화폐로 물건을 삽니다. 다음 20년에는 어떤 일들이 펼쳐질까요. 새로운 돈과 함께 하는 우리의 일상을 '내 주머니 속 디지털자산'이라는 연재로 소개합니다.지난 2017년 암호화폐 열풍이 전 세계를 강타하자 수많은 코인들이 시장으로 튀어나왔다. 실체가 없는 스타트업도 블록체인을 활용한 사업 계획과 자체 코인만 있으면 암호화폐공개(ICO)를 통해 손쉽게 자금을 조달할 수 있었다.상황이 이렇자 기존 산업의 강자들도					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71127_7425_1622_v150.jpg)">
# <a href="/news/articleView.html?idxno=71127" target="_top">
# <span class="show-for-sr">6/26 아침브리핑: 국제결제은행 “CBDC 열기, 리브라 때문 아니야” 외</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=블록체인 바이트&amp;view_type=sm" target="_top">#블록체인 바이트</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71127" target="_top"><strong>6/26 아침브리핑: 국제결제은행 “CBDC 열기, 리브라 때문 아니야” 외</strong></a></div>
# <div class="list-dated"><strong class="list-name">Daniel Kuhn</strong> 2020-06-26 09:25</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71127" target="_top">
# 					주요 소식국제결제은행 “CBDC 열기, 리브라 때문 아니야”국제결제은행(BIS)이 최근 펴낸 보고서에서 “전 세계적으로 중앙은행이 발행하는 디지털 통화(CBDC)에 대한 연구가 활발해지고 있는 것은 리브라(Libra) 같은 민간 부문이 발행하는 스테이블코인 때문이 아니라, 편리성을 담보한 CBDC가 미래의 주요 결제 수단이 될 것이라는 기대 때문”이라고 전했다.미국 중앙은행인 연방준비제도는 최근 보고서를 내고 “리브라처럼 주요 국가의 법정화폐와 국채에 연동한 스테이블코인은 특정 경제 상황에서 소비자 복지를 대폭 개선할 것”으로 전망					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71120_7420_720_v150.jpg)">
# <a href="/news/articleView.html?idxno=71120" target="_top">
# <span class="show-for-sr">6/25 오후브리핑: ABS, 블록체인확산전략, 텐센트 등</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=오후브리핑&amp;view_type=sm" target="_top">#오후브리핑</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71120" target="_top"><strong>6/25 오후브리핑: ABS, 블록체인확산전략, 텐센트 등</strong></a></div>
# <div class="list-dated"><strong class="list-name">정인선 기자</strong> 2020-06-25 16:20</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71120" target="_top">
# 					아시아블록체인서밋 2020, 7월15일부터 닷새 동안 온라인 개최‘크립토 대모’ 헤스터 퍼스 SEC 위원, 탕펑(오드리 탕) 대만 디지털 정무위원(장관) 등이 참가하는 '아시아 블록체인 서밋(ABS) 2020'이 7월15일부터 온라인으로 5일간 열린다. 아시아 블록체인 서밋은 아시아 블록체인 얼라이언스가 매년 대만에서 주최하는 국제 블록체인 컨퍼런스다. 올해는 크리스티나 로마조 유니세프 블록체인 리드, 압둘아지즈 알칼리파 카타르개발은행(QDB) CEO , 쉴라 워렌 세계경제포럼 블록체인 소장, 글렌 웨일 마이크로소프트 책임 연구원					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71118_7419_3931_v150.jpg)">
# <a href="/news/articleView.html?idxno=71118" target="_top">
# <span class="show-for-sr">'블록체인 플러스' 위한 텐센트의 투트랙 전략</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=텐센트&amp;view_type=sm" target="_top">#텐센트</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71118" target="_top"><strong>'블록체인 플러스' 위한 텐센트의 투트랙 전략</strong></a></div>
# <div class="list-dated"><strong class="list-name">정인선 기자</strong> 2020-06-25 16:00</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71118" target="_top">
# 					한때 중국에선 ‘인터넷 플러스(互联网+)’라는 말이 유행했다. 리커창 전 총리가 2015년 처음 쓴 표현으로, 전통 산업이 인터넷을 만나 새로운 부가가치를 만들어 낼 수 있다는 의미다. 최근에는 ‘블록체인 플러스(区块链+)’가 그 자리를 대체했다. 마찬가지로 블록체인 기술이 기존 산업과 서비스를 만나 혁신을 이룰 수 있다는 기대가 담겼다. 중국 최대 모바일 메신저 위챗(微信) 운영사 텐센트(腾讯)의 블록체인 전략도 ‘블록체인 플러스’와 닿아 있다. 블록체인 플러스는 '연결'과 더불어 텐센트가 지난해 10월 발간한 블록체인 백서의 핵					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71117_7415_249_v150.jpg)">
# <a href="/news/articleView.html?idxno=71117" target="_top">
# <span class="show-for-sr">6/25 아침브리핑: 뉴욕 비트라이선스 5주년 외</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=블록체인 바이트&amp;view_type=sm" target="_top">#블록체인 바이트</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71117" target="_top"><strong>6/25 아침브리핑: 뉴욕 비트라이선스 5주년 외</strong></a></div>
# <div class="list-dated"><strong class="list-name">Daniel Kuhn</strong> 2020-06-25 10:10</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71117" target="_top">
# 					주요 소식비트라이선스 시행 5주년뉴욕주 금융감독청(NYDFS)이 가상화폐 인가 제도 비트라이선스(BitLicense)를 시행한 지 5주년을 맞았다. 이 제도는 여러 스타트업이 이미 인가를 받은 기존의 업체와 제휴를 맺고 뉴욕에서 암호화폐 관련 사업을 시작하는 버팀목 역할을 했다. 또 각종 ICO에 대한 최종 지침이 되기도 했다. 금융감독청은 뉴욕 주립대학교와 양해각서를 체결하고, 사업 인가를 신청하고 기다리는 신생 업체들이 학교의 관리 감독하에 다양한 실험을 진행할 수 있도록 지원했다. 이 모든 장치는 암호화폐 기업들이 규제 당국의					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71115_7410_2833_v150.jpg)">
# <a href="/news/articleView.html?idxno=71115" target="_top">
# <span class="show-for-sr">AI 얼굴 인식 자료 수집을 피하는 또다른 AI</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=인공지능&amp;view_type=sm" target="_top">#인공지능</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71115" target="_top"><strong>AI 얼굴 인식 자료 수집을 피하는 또다른 AI</strong></a></div>
# <div class="list-dated"><strong class="list-name">Benjamin Powers</strong> 2020-06-25 08:00</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71115" target="_top">
# 					합성 미디어 기업 알레시아 AI(Alethea AI)가 얼굴인식 기술을 이용해 사용자의 프라이버시를 보호해주는 디지털 마스크를 개발해 파일럿 테스트에 착수했다.이번 소식은 IBM, 마이크로소프트, 아마존이 경찰 등 사법 기관에 얼굴인식 기술 판매를 중단하겠다고 발표한 이후 전해졌다.“AI 알고리듬으로 얼굴을 가려주는 기술을 개발했다. 이 ‘마스크’ 기술을 사용해 프라이버시 보호 수준을 한층 강화할 수 있다.” – 아리프 칸, 알레시아 AI CEO로스앤젤레스에 위치한 알레시아 AI는 2019년에 라이선스용 아바타 기업으로 탄생했다.					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71116_7411_5847_v150.jpg)">
# <a href="/news/articleView.html?idxno=71116" target="_top">
# <span class="show-for-sr">정부, 블록체인 7대 분야 선정·지원한다</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=과학기술정보통신부&amp;view_type=sm" target="_top">#과학기술정보통신부</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71116" target="_top"><strong>정부, 블록체인 7대 분야 선정·지원한다</strong></a></div>
# <div class="list-dated"><strong class="list-name">김병철</strong> 2020-06-24 18:40</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71116" target="_top">
# 					정부가 온라인 투표 등 국민이 체감할 수 있는 블록체인 7대 분야를 선정했다. 또한 비대면 경제에 필요한 블록체인 기반 분산신원증명(DID) 등을 활성화하겠다고 밝혔다. 이를 위해 관련 법제도를 개선하고 부산규제자유특구와 연계한 시범사업을 추진할 예정이다.과학기술정보통신부(장관 최기영)는 24일 대통령직속 4차산업혁명위원회 전체회의에서 초연결·비대면 신뢰사회를 위한 '블록체인 기술 확산 전략'을 발표했다. 블록체인은 정보의 투명성을 제고하고, 위변조를 방지해 거래신뢰를 높이는 기술로, 비대면 경제의 핵심 인프라라고 과기부는 설명했다					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71114_7409_1636_v150.jpg)">
# <a href="/news/articleView.html?idxno=71114" target="_top">
# <span class="show-for-sr">6/24 오후브리핑: 시대전환, 바이프로스트, 블록체인협회 외</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=오후브리핑&amp;view_type=sm" target="_top">#오후브리핑</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71114" target="_top"><strong>6/24 오후브리핑: 시대전환, 바이프로스트, 블록체인협회 외</strong></a></div>
# <div class="list-dated"><strong class="list-name">정인선 기자</strong> 2020-06-24 16:17</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71114" target="_top">
# 					[인터뷰] 조정훈 시대전환 의원 "암호화폐 투자상품 허용해야”최근 기본소득 논쟁을 주도하는 조정훈 시대전환 의원은 블록체인 기반의 암호화폐를 금융투자상품으로 간주해야 한다고 주장했다. 조 의원은 22일 코인데스크코리아와 인터뷰에서 "전환적 기술인 블록체인을 선점하기 위해 암호화폐의 금융상품화를 허용해야 한다"며 이렇게 말했다.SK㈜ C&amp;C, 기업용 블록체인 플랫폼 출시SK㈜ C&amp;C가 기업용 블록체인 플랫폼 체인제트 포 이더리움(ChainZ for Ethereum)을 출시했다. SK C&amp;C는 24일 자료를 통해, 체인제트 포 이더리움					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71113_7408_2733_v150.jpg)">
# <a href="/news/articleView.html?idxno=71113" target="_top">
# <span class="show-for-sr">아시아블록체인서밋 2020, 7월15일부터 닷새 동안 온라인 개최</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=아시아블록체인서밋&amp;view_type=sm" target="_top">#아시아블록체인서밋</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71113" target="_top"><strong>아시아블록체인서밋 2020, 7월15일부터 닷새 동안 온라인 개최</strong></a></div>
# <div class="list-dated"><strong class="list-name">김병철</strong> 2020-06-24 16:00</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71113" target="_top">
# 					‘크립토 대모’ 헤스터 퍼스 SEC 위원, 탕펑(오드리 탕) 대만 디지털 정무위원(장관) 등이 참가하는 '아시아 블록체인 서밋(ABS) 2020'이 7월15일부터 온라인으로 5일간 열린다.아시아 블록체인 서밋은 아시아 블록체인 얼라이언스가 매년 대만에서 주최하는 국제 블록체인 컨퍼런스다. 올해는 크리스티나 로마조 유니세프 블록체인 리드, 압둘아지즈 알칼리파 카타르개발은행(QDB) CEO , 쉴라 워렌 세계경제포럼 블록체인 소장, 글렌 웨일 마이크로소프트 책임 연구원 등이 발표자로 참가한다.기조연설을 맡은 캐나다 출신 전직 우주비행사					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# <div class="list-block">
# <div class="list-image" style="background-image:url(./thumbnail/202006/71112_7407_156_v150.jpg)">
# <a href="/news/articleView.html?idxno=71112" target="_top">
# <span class="show-for-sr">'블록체인 해외송금' 모인, 과기부 육성대상 선정</span>
# </a>
# </div>
# <div class="text-block">
# <div class="list-tag"><span class='\"auto-section' line-2x1="" size-14="" user-point\"=""><a href="http://t691.ndsoftnews.com/news/articleList.html?sc_area=K&amp;sc_word=모인&amp;view_type=sm" target="_top">#모인</a></span></div>
# <div class="list-titles"><a href="/news/articleView.html?idxno=71112" target="_top"><strong>'블록체인 해외송금' 모인, 과기부 육성대상 선정</strong></a></div>
# <div class="list-dated"><strong class="list-name">정인선 기자</strong> 2020-06-24 15:30</div>
# <p class="list-summary">
# <a class="line-height-4-2x" href="/news/articleView.html?idxno=71112" target="_top">
# 					블록체인 기반 해외 송금 서비스 기업 모인이 과학기술정보통신부의 2020년도 민관협력 기반 ITC 스타트업 육성사업 지원 대상에 선정됐다. 과기부는 24일 모인을 포함한 16개 스타트업을 최종 선정했다고 밝혔다. 과기부가 올해부터 추진하는 민관협력 기반 ICT 스타트업 육성사업은 정부와 대기업이 ICT 분야의 혁신적 기술과 아이디어를 가진 스타트업을 3년간 협력 지원하는 프로그램이다. 선정된 기업들에겐 정부가 3년간 총 5억원의 연구 개발 자금을 지원한다. 또 SKT와 KT, 삼성전자 등 대기업이 자체 운영하는 창업 보육 프로그램을					</a>
# </p>
# </div>
# </div>
# <!--// group -->
# <!-- group //-->
# ...
# <!--// container -->
# <!-- 모바일 하단 -->
# <!-- footer //-->
# <style type="text/css">
# #user-footer.skin-9 {position:relative;overflow:hidden;padding:0;padding-top:80px;background:#172341;border-top:none}
# #user-footer.skin-9 .footer-menu {margin-bottom:0}
# #user-footer.skin-9 .has-tip {border-bottom:none}
# #user-footer.skin-9 .footer-columns {padding:0 585px 75px 80px;vertical-align:bottom}
#
# /* logo */
# #user-footer.skin-9 .user-logo {float:inherit;margin-bottom:30px}
#
# /* nav */
# #user-footer.skin-9 .user-nav {display:block;margin-bottom:20px;font-size:16px;font-weight:400}
# #user-footer.skin-9 .user-nav a {font-size:15px;color:#fefefe}
# #user-footer.skin-9 .user-nav a::before {border-left:none;border-color:rgba(255,255,255,.15)}
#
# /* address */
# #user-footer.skin-9 .user-address ul li,#user-footer.skin-9 .user-address ul li a {color:rgba(255,255,255,.5)}
# #user-footer.skin-9 .user-address ul li.bars::before {color:rgba(255,255,255,.25)}
# #user-footer.skin-9 .user-address ul li {line-height:1.75em}
# #user-footer.skin-9 .user-address ul li.copy-p {max-width:660px}
#
# /* 해외사이트 */
# #user-footer.skin-9 #footer-drop-site {position:relative;display:inline-block;vertical-align:middle}
# #user-footer.skin-9 #footer-drop-site #footer-drop {margin:0}
# #user-footer.skin-9 #footer-drop-site .drop-tit {position:relative;overflow:hidden;display:block;font-size:15px;font-weight:400;color:#fff;line-height:1;text-decoration:none;text-align:center;white-space:nowrap}
# #user-footer.skin-9 #footer-drop-site #drop-menu {display:none;z-index:10;position:absolute;top:30px;min-width:100%;padding:4px 0;max-height:215px;background-color:#161f36;overflow-y:auto;overflow-x:hidden}
# #user-footer.skin-9 #footer-drop-site #drop-menu > li > a {width:100%;display:inline-block;padding:8px 17px;font-size:14px;line-height:1;white-space:nowrap;text-overflow:ellipsis;color:#fff;text-align:left;text-decoration:none;opacity:.4;cursor:pointer}
# #user-footer.skin-9 #footer-drop-site #drop-menu > li > a:hover {opacity:1}
#
# /**********************************************
# note : Follow us
# **********************************************/
# #user-footer.skin-9 .footer-columns.footer-sns {position:absolute;right:0;bottom:0;padding:36px 40px;height:355px;width:585px;background:#fcc117;vertical-align:middle}
# #user-footer.skin-9 .footer-sns header {display:inline-block;margin-bottom:13px;font-size:24px;font-weight:700;color:#161f36;letter-spacing:-.03em}
#
# /* sns */
# #user-footer.skin-9 .footer-sns .user-sns {margin-bottom:18px}
# #user-footer.skin-9 .footer-sns .user-sns section {display:inline-block;margin-left:20px}
# #user-footer.skin-9 .footer-sns .user-sns a {display:inline-block;margin-left:15px;font-size:20px;color:#161f36}
# #user-footer.skin-9 .footer-sns .user-sns a:first-child {margin-left:0}
# #user-footer.skin-9 .footer-sns .user-sns a > i {vertical-align:middle}
#
# /* letter */
# #user-footer.skin-9 .footer-sns .user-letter {width:465px;margin-top:10px}
# #user-footer.skin-9 .footer-sns .user-letter .input-group {margin-bottom:19px}
# #user-footer.skin-9 .footer-sns .user-letter .nd-checked {font-weight:300;text-align:left;color:#161f36}
# #user-footer.skin-9 .footer-sns .user-letter .nd-checked::before {float:left;margin:10px 10px 20px 0}
#
# #user-footer.skin-9 .footer-sns .user-letter-form {margin:10px 0}
# #user-footer.skin-9 .footer-sns .user-letter-form input {float:left;width:70%;height:40px;margin:0;font-size:13px;border:0;box-shadow:0}
# #user-footer.skin-9 .footer-sns .user-letter-form input::-webkit-input-placeholder {color:rgba(0,0,0,.6)} /* 크롬 4–56 */
# #user-footer.skin-9 .footer-sns .user-letter-form input:-moz-placeholder {color:rgba(0,0,0,.6)} /* 파이어폭스 4–18 */
# #user-footer.skin-9 .footer-sns .user-letter-form input::-moz-placeholder {color:rgba(0,0,0,.6)} /* 파이어폭스 19–50 */
# #user-footer.skin-9 .footer-sns .user-letter-form input:-ms-input-placeholder {color:rgba(0,0,0,.6)} /* 인터넷 익스플로러 10+ */
# #user-footer.skin-9 .footer-sns .user-letter-form input::placeholder {color:rgba(0,0,0,.6)} /* 파이어폭스 51+, 크롬 57+ */
# #user-footer.skin-9 .footer-sns .user-letter-form button {float:left;width:30%;height:40px;font-size:13px;font-weight:500;color:#fff;letter-spacing:-.06em;background-color:#19284d;font-family: 'Roboto','Noto Sans KR', sans-serif;cursor:pointer}
# .nd-checkbox input[type="checkbox"] ~ .nd-checked::before {border:none}
# .nd-checkbox.check-dark input[type="checkbox"]:checked ~ .nd-checked::before {background-color:#161f36}
#
# @media screen and (max-width: 63.9375em) {
# 	#user-footer.skin-9 {padding-top:30px}
# 	#user-footer.skin-9 .footer-columns {display:block;padding:30px 20px;width:100%;vertical-align:top;text-align:center}
# 	#user-footer.skin-9 .user-nav {display:inline-block;text-align:center}
# 	#user-footer.skin-9 .user-address ul {text-align:center}
# 	#user-footer.skin-9 .user-address ul li {display:inline-block;float:inherit}
# 	#user-footer.skin-9 .user-address ul li.copy {display:block}
# 	#user-footer.skin-9 .user-address ul li.m-none {display:none}
# 	#user-footer.skin-9 .user-address ul li.m-top-0 {margin-top:0 !important}
# 	#user-footer.skin-9 .user-address {position:inherit}
# 	#user-footer.skin-9 .ndsoft {position:absolute;right:20px;bottom:20px}
# 	#user-footer.skin-9 .footer-columns.footer-sns {position:relative;height:auto;text-align:center;width:100%;border-left:none}
# 	#user-footer.skin-9 .footer-sns .user-letter {width:100%}
# 	#user-footer.skin-9 .footer-sns .user-letter .nd-checked::before {float:none;margin-bottom:0}
# 	#user-footer.skin-9 .footer-sns .user-letter-form {float:inherit;width:100%;margin:0 auto}
# }
#
# @media screen and (max-width: 39.9375em) {
# 	#user-footer.skin-9 .user-nav {display:inline-block;text-align:center}
# 	#user-footer.skin-9 .user-nav a {padding:0 5px;float:inherit;text-align:center}
# 	#user-footer.skin-9 .user-nav a::before,#user-footer.skin-9 .user-nav a::after,#user-footer.skin-9 .user-nav a.m-none {display:none}
# 	#user-footer.skin-9 .footer-sns .user-letter .nd-checked::before {float:left;margin-bottom:20px}
# </style>
# <!-- footer //-->
# <footer class="skin-9 font-noto" id="user-footer">
# <div class="float-center">
# <div class="footer-menu">
# <!-- footer sns //-->
# <div class="footer-columns footer-sns">
# <!-- sns //-->
# <div class="user-sns">
# <header>Follow us</header>
# <section>
# <!--<a href="#" target="_blank" title="인스타그램" data-tooltip><i class="icon-instagram"></i></a>
# 						 <a href="#" target="_blank" title="핀터레스트" data-tooltip><i class="icon-pinterest"></i></a>
# 						<a href="#" target="_blank" title="네이버포스트" data-tooltip><i class="size-19 icon-naver"></i></a>-->
# <a data-tooltip="" href="https://t.me/coindesk_korea" target="_blank" title="텔레그램"><i class="fa fa-telegram"></i></a>
# <a data-tooltip="" href="http://www.facebook.com/coindeskkorea" target="_blank" title="페이스북"><i class="icon-facebook"></i></a>
# <a data-tooltip="" href="https://www.youtube.com/channel/UCzxDMBaqJHhTHphiFxCCgxQ" target="_blank" title="유튜브"><i class="icon-youtube"></i></a>
# <a data-tooltip="" href="https://twitter.com/coindeskkorea" target="_blank" title="트위터"><i class="icon-twitter"></i></a>
# </section>
# </div>
# <!--// sns -->
# <!--
# 				<div class="user-letter">
# 					<header>코인데스크 뉴스레터</header>
# 					<section>
# 						<label class="nd-checkbox check-dark" for="useagree">
# 							<input type="checkbox" id="useagree" name="useagree">
# 							<span class="nd-checked">뉴스레터 발송을 위한 이메일주소를 수집하는데 동의하며, 수집된 이메일주소는 뉴스레터 구독 취소하는 즉시 삭제됩니다.</span>
# 						</label>
# 						<fieldset class="user-letter-form" id="newsletterForm">
# 							<input type="text" name="email" id="email" placeholder="이메일주소 입력" title="뉴스레터신청">
# 							<button type="button" title="신청" id="btn_newsletter_reg" data-tooltip>구독</button>
# 						</fieldset>
# 					</section>
# 				</div>
# 				-->
# <!-- letter //-->
# <div class="user-letter" id="mc_embed_signup">
# <div id="mc_embed_signup_scroll">
# <header>뉴스레터 신청하기</header>
# <label class="nd-checkbox check-dark" for="usercheck">
# <input id="usercheck" name="usercheck" type="checkbox" value="1"/>
# <span class="nd-checked">뉴스레터 발송을 위한 이메일 주소 수집에 동의합니다. 구독 취소시 삭제됩니다.</span>
# </label>
# <form action="https://coindeskkorea.us20.list-manage.com/subscribe/post?u=021280a65c5335b9e3f0f48d6&amp;id=fd0800c586" class="validate" id="mc-embedded-subscribe-form" method="post" name="mc-embedded-subscribe-form" novalidate="" target="_blank">
# <div class="mc-field-group input-group">
# <fieldset class="user-letter-form" id="newsletterForm" style="display: none; ">
# <input class="required email" id="MERGE1" name="MERGE1" placeholder="이름 입력" type="text" value=""/>
# <input class="required email" id="mce-EMAIL" name="EMAIL" placeholder="이메일주소 입력" type="email" value=""/>
# <button class="button" id="mc-embedded-subscribe" name="subscribe" type="submit" value="Subscribe">구독</button>
# </fieldset>
# <div class="clear" id="mce-responses">
# <div class="response" id="mce-error-response" style="display:none"></div>
# <div class="response" id="mce-success-response" style="display:none"></div>
# </div> <!-- real people should not fill this in and expect good things - do not remove this or risk form bot signups-->
# <div aria-hidden="true" style="position: absolute; left: -5000px;"><input name="b_021280a65c5335b9e3f0f48d6_fd0800c586" tabindex="-1" type="text" value=""/></div>
# <div aria-hidden="true" style="position: absolute; left: -5000px;"><input name="b_021280a65c5335b9e3f0f48d6_fd0800c586" tabindex="-1" type="text" value=""/></div>
# </div>
# </form>
# </div>
# <script src="//s3.amazonaws.com/downloads.mailchimp.com/js/mc-validate.js" type="text/javascript"></script>
# <script type="text/javascript">(function($) {window.fnames = new Array(); window.ftypes = new Array();fnames[0]='EMAIL';ftypes[0]='email';}(jQuery));var $mcj = jQuery.noConflict(true);</script>
# </div>
# <!--// letter -->
# <script type="text/javascript">
# 				$(document).ready(function(){
# 					$("#usercheck").attr("checked", false);
#
# 					$("#usercheck").change(function(){
# 						if($("#usercheck").is(":checked")){
# 							$("#newsletterForm").slideToggle(600);
# 						} else {
# 							$("#newsletterForm").slideToggle(600);
# 						}
# 					});
# 				});
# 				</script>
# </div>
# <!--// footer sns -->
# <div class="footer-columns">
# <!-- logo //-->
# <div class="user-logo"><img alt="코인데스크코리아 " src="/image/logo/downlogo_20191211103545.png"/></div>
# <!--// logo -->
# <!-- nav //-->
# <nav class="user-nav">
# <a class="deco-none m-none" href="/rss/" target="_blank">RSS</a>
# <a class="deco-none" href="/com/com-1.html" target="_blank">회사소개</a>
# <a class="deco-none" href="/com/com-4.html" target="_blank">편집원칙</a>
# <a class="deco-none" href="https://www.coindeskkorea.com/com/ad.html" target="_blank">문의</a>
# <a class="deco-none" href="/com/privacy.html" target="_blank">개인정보처리방침</a>
# <a class="deco-none m-none" href="/com/service.html" target="_blank">이용약관</a>
# <a class="deco-none m-none" href="/com/com-3.html" target="_blank">채용</a>
# <!--<a href="#" class="deco-none m-none">Contact Us</a>
# 					<a href="https://www.coindeskkorea.com/com/jh.html" class="deco-none m-none">제휴문의</a>
# 					<a href="/com/youthpolicy.html" class="deco-none">청소년보호정책</a>
# 					 <a href="/com/copyright.html" class="deco-none">저작권보호정책</a>
# 					<a href="/com/emailno.html" class="deco-none">이메일무단수집거부</a>-->
# <div id="footer-drop-site">
# <ul class="no-bullet" id="footer-drop">
# <li>
# <a class="drop-tit">한국 <i aria-hidden="true" class="fa fa-caret-down"></i></a>
# <ul class="no-bullet" id="drop-menu">
# <li><a href="http://www.coindesk.com" target="_blank">English</a></li>
# <li><a href="http://www.coindeskchinese.com" target="_blank">Chinese</a></li>
# <li><a href="http://www.coindeskjapan.com" target="_blank">Japanese</a></li>
# </ul>
# </li>
# </ul>
# </div>
# <script type="text/javascript">
# 					$(function(){
#
# 						$("ul#footer-drop > li").each(function(idx, ele){
#
# 							// 1차 클릭
# 							$(ele).children("a").on("click", function(e){
#
# 								if($(ele).find("ul > li").length <= 0) return;	// 2차 메뉴가 없으면 return
#
# 								e.preventDefault();		// 링크기능 제거
#
# 								if($(this).hasClass("sub-active")){
# 									$(ele).children("a").removeClass("sub-active");
# 									$(ele).children("ul").slideUp();
# 								} else {
# 									$("ul#user-all-menu > li > a").removeClass("sub-active");
# 									$(ele).children("a").addClass("sub-active");
# 									$("ul#user-all-menu > li > ul").slideUp();
# 									$(ele).children("ul").slideDown();
# 								}
# 							});
#
# 						});
#
# 					});
# 					</script>
# </nav>
# <!--// nav  -->
# <!-- address //-->
# <address class="user-address">
# <ul class="no-bullet">
# <li class="bars m-none">22세기미디어㈜   </li>
# <li class="bars m-none">서울특별시 서초구 강남대로 311, 1010호</li>
# <li class="m-none">등록번호 : 서울, 자00548  </li>
# <li class="clear bars m-none">등록일 : 2018-02-26</li>
# <li class="bars m-none">발행인 : 유신재</li>
# <li class="m-none">편집인 : 김외현</li>
# <li class="clear bars m-none">개인정보보호책임자 : 김외현</li>
# <li class="bars m-none">청소년보호책임자 : 김외현</li>
# <li class="m-none">대표 전화 : 070-7774-7906</li>
# <!-- <li class="bars m-none">팩스 : 02-520-1589</li>
# 						<li class="m-none">대표 메일 : <a href="mailto:master@coindeskkorea.com" class="deco-none">master@coindeskkorea.com</a></li>
# 						<li class="m-none">제호 : 코인데스크코리아 </li>
# 						<li class="m-none">발행일 : 2018-02-26</li> -->
# <li class="clear copy-p auto-martop-20 m-top-0">Coindesk Korea™️ is owned and operated by 22nd Century Media Co., subsidiary of Hankyoreh Co., Ltd., in collaboration with Coindesk, Inc., the leading digital news, events and information services company for the crypto asset and blockchain technology.</li>
# <li class="clear copy">C<a class="deco-none" href="https://www.coindeskkorea.com/admin/adminLoginForm.html">o</a>pyright
# 												<a class="deco-none" href="https://www.coindeskkorea.com/member/login.html">©</a>
# 												2020 22nd Century Media. <a href="http://www.coindeskkorea.com/news/articleList.html?page=2&amp;total=4864&amp;box_idxno=&amp;view_type=sm" onclick="setCookie('view_pc', 'n', 1);">All</a> rights reserved.</li>
# </ul>
# <a class="ndsoft" href="http://www.ndsoft.co.kr/" target="_blank"><img alt="ND소프트" src="/image/ndsoft.gif"/></a>
# </address>
# <!--// address -->
# </div>
# </div>
# </div>
# </footer>
# <!--// footer -->
# <!--// footer -->
# </div>
# </div>
# <!--// wrap -->
# <!-- back to the top //-->
# <button class="back-to-top for-mobile" id="back-to-top" title="위로" type="button"><i class="s7-angle-up"><span class="show-for-sr">위로</span></i></button>
# <!--// back to the top -->
# <script type="text/javascript">
# <!--
# // back to the top
# $(document).scroll(function(){
# 	var sDocumentHeight = $(document).height() - $(window).height();
# 	if($(document).scrollTop() > 0){
# 		$('#back-to-top').fadeIn();
# 	}else{
# 		$('#back-to-top').fadeOut();
# 	}
# });
#
# $('#back-to-top').click(function(){
# 	$('html, body').animate( {scrollTop:0}, 100);
# });
# //-->
# </script>
# <script>
# // Popup Json
# var ___popup = [];
# bannerpop.popup();
# </script>
# <!-- 구글 애드센스 S -->
# <script src="/adManager/js/lab.js"></script>
# <script>
# jQuery(function($) {
# 	setTimeout(function() {
# 		$LAB
# 		.script("//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js")
# 		.wait(function () {
# 			var adn = jQuery('.adsbygoogle').length;
# 			if (adn > 0) {
# 				for (var i = 0; i < adn; i++) {
# 					(adsbygoogle = window.adsbygoogle || []).push({});
# 				}
# 			}
# 		});
# 	}, 1000);
# });
# </script>
# <!-- 구글 애드센스 E -->
# <link href="/adManager/css/adManager.css" rel="stylesheet"/>
# <script src="/library/isND/" type="text/javascript"></script>
# <script>
# $(document).ready(function(){
# 	// 닫기 버튼 자동 노출
# 	$('.ad-template.ad-close .ad-view').each(function(){
# 		$(this).append('<div class="ad-close-btn"><i class="fa fa-close"></i></div>');
# 	})
#
# 	// 닫기 버튼 클릭 시 이벤트
# 	$('body').on('click', '.ad-close-btn', function(){
# 		$(this).closest('.ad-view').slideUp();
# 	})
#
#
# 	if(____is_nd) {
#
# 				// ND IP만 광고 ID 보이기
# 		$('.ad-template').each(function(){
# 			$(this).append('<div class="ad-code-id">'+$(this).attr('id')+'</div>');
# 		})
#
# 				// 광고 ID 자동 숨김 설정 시
# 		$('.ad-code-id').hide();
#
# 		$('.ad-template').mouseenter(function(){
# 			$(this).find('.ad-code-id').show();
# 		}).mouseleave(function(){
# 			$(this).find('.ad-code-id').hide();
# 		})
#
#
# 			}
#
# 	})
# </script>
# </body>
# </html>

# %%
subject = soup.select('div.text-block > div.list-titles > a > strong')[0].get_text().strip()
subject
# Out:
# '암호화폐 수용한 싱가포르 규제도 빨라'

# %%
summary = soup.select('div.text-block > p > a')[0].text.strip()
summary
# Out:
# '1. 싱가포르 암호화폐 라이선스싱가포르가 2019년 초 제정했던 지불서비스법(PSA, Payment Services Act)이 2020년 1월28일 시행되었습니다.싱가포르의 금융당국인 MAS(Monetary Authority of Singapore)는 2019년 12월5일에 암호화폐를 포함한 가상자산이 경제에 미칠 부정적 영향에 대해 우려하면서 ‘자금세탁방지 및 테러자금조달방지(Prevention of Money Laundering and Countering the Financing of Terrorism)’에 관한 방안을 발표했습'

# %%
url = base_url + soup.select('div.text-block > p > a')[0].attrs['href']
url
# Out:
# 'http://www.coindeskkorea.com/news/articleView.html?idxno=71135'

# %%
author = soup.select('div.text-block > div.list-dated > strong')[0].text.strip()
author
# Out:
# '권오훈'

# %%
item_num = len(soup.select('div.text-block > div.list-titles > a > strong'))
item_num
# Out:
# 20

# %% [markdown]
# ### result에 Data 담기

# %%
result = []
for i in range(0, item_num):
    subject = soup.select('div.text-block > div.list-titles > a > strong')[i].get_text().strip()
    summary = soup.select('div.text-block > p > a')[i].text.strip()
    url = base_url + soup.select('div.text-block > p > a')[i].attrs['href']
    author = soup.select('div.text-block > div.list-dated > strong')[i].text.strip()
    
    article = {
        'subject' : subject,
        'summary': summary,
        'url': url,
        'author': author
    }
    
    result.append(article)

# %%
result[0]
# Out:
# {'subject': '암호화폐 수용한 싱가포르 규제도 빨라',
#  'summary': '1. 싱가포르 암호화폐 라이선스싱가포르가 2019년 초 제정했던 지불서비스법(PSA, Payment Services Act)이 2020년 1월28일 시행되었습니다.싱가포르의 금융당국인 MAS(Monetary Authority of Singapore)는 2019년 12월5일에 암호화폐를 포함한 가상자산이 경제에 미칠 부정적 영향에 대해 우려하면서 ‘자금세탁방지 및 테러자금조달방지(Prevention of Money Laundering and Countering the Financing of Terrorism)’에 관한 방안을 발표했습',
#  'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=71135',
#  'author': '권오훈'}

# %% [markdown]
# ### 1~10페이지 기사 크롤링 하기

# %%
soup.select('#user-container > div.float-center.custom-m.mobile.template.list.max-width-1250 > div.user-content > section > article > div.article-list > div.clearfix > ul > li')[0]
# Out:
# <li class="pagination-start"><a href="/news/articleList.html?page=1&amp;total=4864&amp;box_idxno=&amp;view_type=sm" title="처음"><i class="fa fa-angle-double-left fa-fw"><span class="show-for-sr">처음</span></i><span class="show-static-small-only">처음</span></a></li>

# %%
url = 'http://www.coindeskkorea.com/news/articleList.html?page=2&total=4864&box_idxno=&view_type=sm'

# %%
result = []
for page_num in range(1, 11):
    url = 'http://www.coindeskkorea.com/news/articleList.html?page='+ str(page_num) +'&total=4864&box_idxno=&view_type=sm'
    response = session.get(url)
    html = response.text
    soup = BeautifulSoup(html, 'html.parser')
    for i in range(0, item_num):
        subject = soup.select('div.text-block > div.list-titles > a > strong')[i].get_text().strip()
        summary = soup.select('div.text-block > p > a')[i].text.strip()
        url = base_url + soup.select('div.text-block > p > a')[i].attrs['href']
        author = soup.select('div.text-block > div.list-dated > strong')[i].text.strip()

        article = {
            'subject' : subject,
            'summary': summary,
            'url': url,
            'author': author
        }

        result.append(article)

# %%
result[-1]
# Out:
# {'subject': '거래소 팔콘X, $1700만 시드 투자 유치…15년 전 페이스북 규모',
#  'summary': '암호화폐 거래소 팔콘X(FalconX)가 지난 13일 “시드 투자를 통해 1700만달러(약 200억원)를 유치했다”고 밝혔다. 이번 투자는 악셀(Accel)이 주도했으며, 코인베이스 벤처스(Coinbase Ventures), 펜부시 캐피털(Fenbushi Capital), 아본 벤처스(Avon Ventures) 등이 참여했다. 팔콘X는 이어 “페이스북(Facebook)과 슬랙(Slack)도 투자에 참여할 예정”이라고 전했다.팔콘X는 암호화폐 거래소의 인위적인 거래량 조작 척결을 내세우는 업체다. 악셀 같은 유명 투자자들의 주도로 시',
#  'url': 'http://www.coindeskkorea.com/news/articleView.html?idxno=70911',
#  'author': 'Paddy Baker'}
