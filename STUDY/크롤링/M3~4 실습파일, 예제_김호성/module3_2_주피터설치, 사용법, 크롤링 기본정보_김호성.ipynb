# %% [markdown]
# # Jupyter 설치

# %% [markdown]
# 1. python이 설치된 후 시작메뉴에서 cmd를 검색하여 실행한다. (명령프롬프트)
# 2. pip3 install jupyter 라고 입력한다.
# 3. 설치가 완료되면 jupyter notebook이라고 치면 실행된다.
#
# *파이썬이 설치되어있어야한다.
#
# *강의에서 사용되는 파이썬의 버전은 3.68로 최소 3.xx버전의 python을 권장한다

# %% [markdown]
# ### 파이썬 버전확인

# %%
from platform import python_version

print(python_version())
# Out:
# 3.9.7

# %%
Image('img/install.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_33880/2792814910.py in <module>
# ----> 1 Image('img/install.png')
#
# NameError: name 'Image' is not defined

# %% [markdown]
# ### 주피터실행

# %%
Image('img/run2.png')

# %%
print('test')
# Out:
# test

# %% [markdown]
# ### 단축키

# %% [markdown]
# 단축키
#
# Command Mode (press Esc to enable)
#
# Enter : 편집모드
#
# Shift-Enter : 실행 후 다음셀
#
# Ctrl-Enter : 실행
#
# Alt-Enter : 실행 후 바로 밑 추가
#
# Y : 코드를 작성할 수 있는 모드
#
# M : 마크다운 작성을 위한 모드
#
# 1 : h1 크기의 형태의 제목
#
# 2 : h2 크기의 형태의 제목
#
# 3 : h3 크기의 형태의 제목
#
# 4 : h4 크기의 형태의 제목
#
# 5 : h5 크기의 형태의 제목
#
# 6 : h6 크기의 형태의 제목
#
# Up : 위에 있는 셀로이동
#
# K : 위에 있는 셀로이동
#
# Down : 밑의 셀로 이동
#
# J : 밑의 셀로 이동
#
# A : 위로 셀 추가하기
#
# B : 밑으로 셀 추가하기
#
# X : 잘라내기
#
# C : 복사
#
# Shift-V : 위로 붙여넣기
#
# V : 밑으로 붙여넣기
#
# Z : 되돌리기
#
# D,D : 삭제하기
#
# Shift-M : 셀합치기
#
# S : 저장
#
# Ctrl-S : 저장
#
# L : 라인만들기
#
# Esc : 해당셀에서 벗어나기
#
# H : 도움말
#
# I,I : 정지
#
# 0,0 : 재시작
#
# Space : 스크롤 내리기
#
# Shift-Space : 스크롤올리기
#
# Ctrl-] : 들여쓰기
#
# Ctrl-[ : 내어쓰기
#
# Ctrl-A : 모두쓰기
#
# Ctrl-Z : 되돌리기
#
# Ctrl-Shift-Z : 앞으로가기
#
# Ctrl-Y : 다시하기
#
# Ctrl-Home : 셀 처음으로보내기

# %% [markdown]
# ### 크롤링준비

# %% [markdown]
# > 준비할 것들..
# - Chrome 개발자도구 사용법
# - python 기본문법
# - jupyter notebook 기본사용법
# - api사용을 위한 key 발급
# - 크롤링 유의사항

# %% [markdown]
# ###### Chrome 개발자도구
# - F12또는 또는 ctrl+shift+I를 누르면 나타남.
# - 개발자도구를 통해서 네트워크 통신과 html정보를 알아낼 수 있어야 함

# %%
Image('img/chrome.png')

# %%
Image('img/chrome2.png')

# %% [markdown]
# ###### python 기본문법
# - 반복문, 조건문 등의 기본적이해
# - python 자료구조에 대한 기본적인 이해
# - python 라이브러리 사용법

# %% [markdown]
# ###### jupyter notebook  기본 사용법
# - 실행하기, cell추가하기 등 기본 단축키
# - 라이브러리설치법

# %% [markdown]
# ###### api사용을 위한 key 발급
# - api를 사용하기 위해서 회원가입을 하고 인증키를 발급하는 시간이 걸림
# - 따라서 M4를 수강하기 전에 미리 api를 사용할 사이트에서 key를 준비해야함

# %% [markdown]
# ###### 크롤링 유의사항
# - robots.txt 확인하기
# - 서버에 부하주지 않기
# - 크롤링 데이터 사용 유의

# %% [markdown]
# ## (추가설명)robots.txt

# %% [markdown]
# ###### robots.txt란?
#
# - 개발한 웹 페이지에서 로봇들이 크롤링을 할 수 있는 접근 권한을 제한하는 문서
# - 물리적으로 제한하지는 않지만 권고하는 것으로 로봇이 파일을 읽고 접근하는 것을 중지하길 바라는 것에서 설정함
# - 접근하지 못하도록 써놓더라도 다른사람들이 접근할 수는 있음
# - 위치는 항상 사이트의 루트 디렉토리에 위치한다. ex) www.naver.com/robots.txt

# %% [markdown]
# >User-agent: *
# >
# >Allow: /
#
# 모든 로봇들이 모든 페이지에 접근이 가능한 것

# %% [markdown]
# >User-agent: *
# >
# >Disallow: /
#
# 모든 로봇들이 접근하지 못하게 하는 것

# %% [markdown]
# > User-agent: MaderiBot
# >
# > Disallow: /
#
# Maderi bot은 접근할 수 없다. (특정 로봇만 거부)

# %% [markdown]
# > User-agent: *
# >
# > Disallow: /board/
#
# 모든 로봇에 대해서 board 디렉토리의 접근을 거부한다

# %% [markdown]
# ## (추가설명2) 서버에 부하주지 않기

# %% [markdown]
# 크롤링으로 서버에 부하를 주는 것은 네트워크 요청을 많이 준다는 것인데
# 요청이 너무 많아서 서버가 견딜 수 없다면 다른 요청들을 처리하기 힘들거나
# 심지어는 서버가 다운되서 서비스를 이용할 수 없게 될지도 모른다.
#
# 유명한 게임을 해본사람들은 알겠지만 대규모 이벤트로 사람들이 몰리면 서버가
# 제대로 작동하지 못하고 게임이 느려지거나 심지어는 로그아웃되는 경우도 있을 것을
# 경험한 적이 있을 것이다.
#
# 네트워크를 요청하는것도 같은 방식으로 요청 받는 사이트에 문제가 생길 수 있다

# %% [markdown]
# 일반적으로 서비스에서 크롤링을 바라는 경우는 없다.
# 크롤링은 일반적으로 대량으로 데이터를 가져가기 위해서 수많은 요청들을 짧은 시간동안 하게 된다.
#
# 반복문을 통해서 요청을 계속하게되면 서비스에 문제가 생길 수 있기 때문에
# 가급적 요청마다 일정 간격을 주는 것이 필요하기도 하다.
#
# 방법은 실제로 크롤링을 할 때 설명하도록 한다.

# %% [markdown]
# ### (추가설명3) 크롤링 데이터 사용 유의
# 크롤링을 하는 이유는 모두가 다르다.
# 마케팅 성과를 측정하기 위해서,
# 새로운 제품을 기획하기 위해서 등 모두가 데이터를 사용하는 목적이 다르다.
#
# 하지만 크롤링을 통해 데이터를 수집하는 것은 조금은 조심해야할 필요가 있다.
#
# 종종 경쟁사의 사이트의 데이터를 크롤링하다가 소송까지 가는 경우들도 있고,
# 특정 api에서 정책상 데이터를 직접, 재가공판매해서는 안 된다라고 명시해두기도 한다.
#
# 물론 크롤링이 법적인 문제가 된다고 명확하게 말할 수는 없지만 특정 경우에는 문제가
# 될 수 있기때문에 위에 추가설명에서 말한 2가지는 확인해서 최대한 문제가 되지 않도록
# 크롤링하는 것이 좋다.
