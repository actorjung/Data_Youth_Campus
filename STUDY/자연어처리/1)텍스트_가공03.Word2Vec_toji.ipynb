# %% [markdown]
# ## Word2vec

# %% [markdown]
# ### 토지

# %%
#konlpy 설치

# %%
# 필요한 모듈 불러오기
# 한글 깨짐 현상 해결을 위한 codecs
# 웹스크롤링을 위한 BeautifulSoup
# 한글 형태소 분석을 위한 okt
# 단어 임베딩을 위한 gensim 의 Word2Vec

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# codecs의 open 함수를 이용해 "BEXX0003.txt"파일을 utf-16 인코딩으로 열기
# 읽어온 파일을 Beautifulsoup 함수를 이용해 html 형식으로 변환
# body 태그의 text 태그 중 첫번째 결과를 body 변수에 저장
# getText 함수로 앞뒤 태그를 없애고 문자열만 text 변수로 저장

# %% [markdown]
# #### 형태소 분석기 연습

# %%
# pos 함수로 품사 태깅
# norm : 정규화. 표현 방법이 다른 단어를 통합시켜 같은 단어로 만들어줌
# stem : 어간 추출

# %%
# text를 \n 기준으로 분할하여 lines 에 할당
# okt 형태소를 이용해 분할한 문장을 품사태깅하여 malist 로 할당
# norm을 True로 stem 을 True 로 지정하여 정규화, 어간추출하여 단어의 기본형을 사용해 품사태깅
# 문장에서 조사, 어미, 구두점인 단어는 제외하고 r에 추가
# results에 문장별로 전처리된 결과 추가

# %%
# result 결과 확인
# 문장별로 토큰화된 결과 확인

# %%
# 단어 임베딩
# results 를 이용해 Word2Vec 모델 생성
# vector_size 를 200으로 지정해 임베딩 된 벡터의 차원을 200으로 지정. window로 윈도우 크기를 5로 지정
# min_count를 2으로 지정해 단어의 최소 빈도수를 제한하여 빈도가 2 미만이면 학습하지 않음
# sg을 1로 지정하여 skip-gram 사용

# %%
# similarity 를 이용해 두 단어의 유사도 계산

# %%
# most_similar 를 이용해 지정한 단어와 유사한 단어를 확인
